# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

# %%
df = pd.read_csv('cleaned_car_data.csv', index_col = False)

# %%
def get_sentiment_score(text):
    return sid.polarity_scores(text)['compound']

df['Sentiment Score'] = df['Review'].apply(get_sentiment_score)

# %%
df['Sentiment Score'].hist()
# Out:
# <Axes: >

# %%
df['Rating'].hist()
# Out:
# <Axes: >

# %%
df.to_csv('cleaned_car_data_w_sentiment.csv')

# %%
df
# Out:
#        Unnamed: 0      Car Brand Car Model  Year  \
# 0               0          honda    accord  2010
# 1               1          honda    accord  2010
# 2               2          honda    accord  2010
# 3               3          honda    accord  2010
# 4               4          honda    accord  2010
# ...           ...            ...       ...   ...
# 15255       15261  mercedes-benz   a-class  2019
# 15256       15262  mercedes-benz   a-class  2019
# 15257       15263  mercedes-benz   a-class  2019
# 15258       15264  mercedes-benz   a-class  2019
# 15259       15265  mercedes-benz   a-class  2019
#
#                                                   Review  Rating  \
# 0      I've driven my LX over 13 years and the only t...     5.0
# 1      I have this car for 10 years have given me no ...     5.0
# 2      My 2012 Honda Accord is great, It handles grea...     5.0
# 3      My sibling has this car. I may be a computer p...     5.0
# 4      I've had this car for 7 years, it's dependable...     5.0
# ...                                                  ...     ...
# 15255  I just traded in my 2016 Mercedes GLA 250 for ...     5.0
# 15256  Great car, fun to drive and very quick. I had ...     5.0
# 15257  Awesome car. Really smooth drive satisfying lo...     5.0
# 15258  I got this car just because I have always boug...     1.0
# 15259                         I love this car! Thank You     5.0
#
#        Value Rating  Performance Rating  Quality Rating  Comfort Rating  ...  \
# 0               5.0                 5.0             5.0             5.0  ...
# 1               5.0                 5.0             5.0             5.0  ...
# 2               4.0                 5.0             5.0             5.0  ...
# 3               5.0                 5.0             5.0             5.0  ...
# 4               5.0                 5.0             5.0             5.0  ...
# ...             ...                 ...             ...             ...  ...
# 15255           5.0                 5.0             5.0             5.0  ...
# 15256           4.5                 4.0             5.0             4.5  ...
# 15257           5.0                 3.0             5.0             3.0  ...
# 15258           2.0                 1.0             2.0             1.0  ...
# 15259           5.0                 5.0             5.0             5.0  ...
#
#              Model Full Name  Horsepower (hp) Curb Weight (lbs) Combined MPG  \
# 0               Honda Accord            190.0            3327.0         25.0
# 1               Honda Accord            190.0            3327.0         25.0
# 2               Honda Accord            190.0            3327.0         25.0
# 3               Honda Accord            190.0            3327.0         25.0
# 4               Honda Accord            190.0            3327.0         25.0
# ...                      ...              ...               ...          ...
# 15255  Mercedes-benz A-class            188.0            3285.0         28.0
# 15256  Mercedes-benz A-class            188.0            3285.0         28.0
# 15257  Mercedes-benz A-class            188.0            3285.0         28.0
# 15258  Mercedes-benz A-class            188.0            3285.0         28.0
# 15259  Mercedes-benz A-class            188.0            3285.0         28.0
#
#        Fuel Capacity (gallons)  Drivetrain  Recommended Fuel  \
# 0                         18.5         FWD           Regular
# 1                         18.5         FWD           Regular
# 2                         18.5         FWD           Regular
# 3                         18.5         FWD           Regular
# 4                         18.5         FWD           Regular
# ...                        ...         ...               ...
# 15255                     13.5         FWD           Premium
# 15256                     13.5         FWD           Premium
# 15257                     13.5         FWD           Premium
# 15258                     13.5         FWD           Premium
# 15259                     13.5         FWD           Premium
#
#        Average MSRP Price ($) Average KBB Fair Price ($) Sentiment Score
# 0                     25117.5                     6605.0          0.7650
# 1                     25117.5                     6605.0          0.0772
# 2                     25117.5                     6605.0          0.9793
# 3                     25117.5                     6605.0          0.8513
# 4                     25117.5                     6605.0          0.6682
# ...                       ...                        ...             ...
# 15255                 34495.0                    20708.5          0.9358
# 15256                 34495.0                    20708.5          0.9674
# 15257                 34495.0                    20708.5          0.9713
# 15258                 34495.0                    20708.5          0.8020
# 15259                 34495.0                    20708.5          0.7901
#
# [15260 rows x 23 columns]
