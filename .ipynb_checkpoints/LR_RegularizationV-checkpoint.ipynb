# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
#from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
current_year = datetime.now().year
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/TimmyRen/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = pd.read_csv('final_cleaned.csv', index_col = False)
car_data_encoded = pd.get_dummies(df, columns=['Model Full Name', 'Drivetrain', 'Vehicle Class'], drop_first=True)
selected_topics = ['Topic_0', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_7', 'Topic_8', 'Topic_9']

for topic in selected_topics:
    car_data_encoded[f'{topic}_Weighted'] = car_data_encoded[topic] * car_data_encoded['Sentiment Score']

weighted_topic_features = [f'{topic}_Weighted' for topic in selected_topics]

# %%
results_list = []

# %% [markdown]
# # Functional

# %%
functional_features = [
    'Horsepower (hp)', 'Curb Weight (lbs)', 'Combined MPG', 'Fuel Capacity (gallons)', 'Age'
] + [col for col in car_data_encoded.columns if col.startswith('Drivetrain_')]

vehicle_class_features = [col for col in car_data_encoded.columns if col.startswith('Vehicle Class_')]

functional_features += vehicle_class_features

features = functional_features

# %% [markdown]
# ### Functional Unaggregated

# %%
#unaggregated

y_price = car_data_encoded['Average KBB Fair Price ($)']
X = car_data_encoded[features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional Unaggregated"
model_type = "Linear Regression"

# Append the results to the list as a dictionary
results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.7800
#
# RMSE: 4123.7972
#
# Model Coefficients:
#   Horsepower (hp): 47.0750
#   Curb Weight (lbs): -2.1557
#   Combined MPG: -7.0564
#   Fuel Capacity (gallons): 185.2962
#   Age: -1750.4193
#   Drivetrain_4WD: 4185.8522
#   Drivetrain_AWD: -854.1422
#   Drivetrain_FWD: -2477.9903
#   Drivetrain_RWD: 578.9442
#   Vehicle Class_compact-suv: -935.3245
#   Vehicle Class_electric-car: 3351.7157
#   Vehicle Class_electric-suv: 4715.5914
#   Vehicle Class_full-size: -1152.8683
#   Vehicle Class_full-size-truck: -1012.8441
#   Vehicle Class_hybrid-car: 559.6436
#   Vehicle Class_hybrid-suv: -3184.6762
#   Vehicle Class_luxury-hybrid-suv: 3100.9584
#   Vehicle Class_mid-size: 1234.1979
#   Vehicle Class_mid-size-suv: 967.6763
#   Vehicle Class_mid-size-truck: 2313.9656
#   Vehicle Class_minivan: 1583.3936
#
# Intercept: 25117.5797

# %% [markdown]
# #### Functional Unaggregated Lasso

# %%
alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Unaggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.7800
#   RMSE: 4123.7876
#
# Alpha: 1.0
#   R^2: 0.7800
#   RMSE: 4123.8508
#
# Alpha: 10.0
#   R^2: 0.7789
#   RMSE: 4133.9503
#
# Alpha: 100
#   R^2: 0.7631
#   RMSE: 4279.5725
#
# Alpha: 200
#   R^2: 0.7520
#   RMSE: 4378.6120
#
# Alpha: 300
#   R^2: 0.7434
#   RMSE: 4454.1856
#
# Alpha: 500
#   R^2: 0.7307
#   RMSE: 4562.9037
#
# Alpha: 1000
#   R^2: 0.7281
#   RMSE: 4584.6565
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.7800
# Best RMSE: 4123.7876
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 47.0864
#   Curb Weight (lbs): -2.1578
#   Combined MPG: -6.7547
#   Fuel Capacity (gallons): 185.1604
#   Age: -1750.1532
#   Drivetrain_4WD: 4188.3909
#   Drivetrain_AWD: -850.3292
#   Drivetrain_FWD: -2474.4769
#   Drivetrain_RWD: 581.1720
#   Vehicle Class_compact-suv: -946.0962
#   Vehicle Class_electric-car: 3316.0092
#   Vehicle Class_electric-suv: 4678.1378
#   Vehicle Class_full-size: -1160.8719
#   Vehicle Class_full-size-truck: -1013.9349
#   Vehicle Class_hybrid-car: 540.3572
#   Vehicle Class_hybrid-suv: -3189.2031
#   Vehicle Class_luxury-hybrid-suv: 3085.8788
#   Vehicle Class_mid-size: 1220.9219
#   Vehicle Class_mid-size-suv: 957.6606
#   Vehicle Class_mid-size-truck: 2304.5045
#   Vehicle Class_minivan: 1571.2753
#
# Intercept: 25123.1054

# %% [markdown]
# #### Functional Unaggregated Ridge

# %%
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    Ridge_model = Ridge(alpha=alpha)
    Ridge_model.fit(X_train, y_train)
    y_pred = Ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Unaggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.7800
#   RMSE: 4123.7975
#
# Alpha: 1.0
#   R^2: 0.7800
#   RMSE: 4123.8085
#
# Alpha: 10.0
#   R^2: 0.7799
#   RMSE: 4124.4610
#
# Alpha: 100
#   R^2: 0.7786
#   RMSE: 4137.2946
#
# Alpha: 200
#   R^2: 0.7770
#   RMSE: 4152.0822
#
# Alpha: 300
#   R^2: 0.7755
#   RMSE: 4166.3254
#
# Alpha: 500
#   R^2: 0.7726
#   RMSE: 4192.3920
#
# Alpha: 1000
#   R^2: 0.7669
#   RMSE: 4244.7912
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.7800
# Best RMSE: 4123.7975
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 54.9404
#   Curb Weight (lbs): -0.8939
#   Combined MPG: 16.6959
#   Fuel Capacity (gallons): 50.7800
#   Age: -1623.9290
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 0.0000
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#
# Intercept: 18759.0061

# %% [markdown]
# ### Functional Aggregated

# %%
#aggregated
aggregated_data = df.groupby(['Model Full Name', 'Year']).agg({
    'Horsepower (hp)': 'mean',
    'Curb Weight (lbs)': 'mean',
    'Combined MPG': 'mean',
    'Fuel Capacity (gallons)': 'mean',
    'Age': 'mean',
    'Average KBB Fair Price ($)': 'mean',
    'Vehicle Class': 'first',
    'Car Brand': 'first',
    'Car Model': 'first',
    'Drivetrain': 'first'
}).reset_index()

car_data_encoded_agg = pd.get_dummies(aggregated_data, columns=['Car Brand', 'Car Model', 'Drivetrain', 'Vehicle Class'], drop_first=True)

y_price = car_data_encoded_agg['Average KBB Fair Price ($)']
X = car_data_encoded_agg[functional_features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print("Model Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional Aggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.6385
#
# RMSE: 5149.0639
# Model Coefficients:
#   Horsepower (hp): 45.7558
#   Curb Weight (lbs): -0.8214
#   Combined MPG: 11.3679
#   Fuel Capacity (gallons): 190.6051
#   Age: -2057.9485
#   Drivetrain_4WD: 3148.6491
#   Drivetrain_AWD: -2380.2253
#   Drivetrain_FWD: -3474.6153
#   Drivetrain_RWD: -453.2229
#   Vehicle Class_compact-suv: -229.2713
#   Vehicle Class_electric-car: 6718.1756
#   Vehicle Class_electric-suv: 4723.7591
#   Vehicle Class_full-size: -673.6605
#   Vehicle Class_full-size-truck: -3125.2154
#   Vehicle Class_hybrid-car: 1138.7061
#   Vehicle Class_hybrid-suv: -2870.1388
#   Vehicle Class_luxury-hybrid-suv: 5894.6217
#   Vehicle Class_mid-size: 2429.0707
#   Vehicle Class_mid-size-suv: 1234.6862
#   Vehicle Class_mid-size-truck: 1678.9081
#   Vehicle Class_minivan: 2773.7374
#
# Intercept: 23573.2972

# %% [markdown]
# #### Functional Aggregated Lasso

# %%
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Aggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6385
#   RMSE: 5148.5454
#
# Alpha: 1.0
#   R^2: 0.6392
#   RMSE: 5143.9452
#
# Alpha: 10.0
#   R^2: 0.6456
#   RMSE: 5097.6044
#
# Alpha: 100
#   R^2: 0.6615
#   RMSE: 4981.9476
#
# Alpha: 200
#   R^2: 0.6496
#   RMSE: 5068.7710
#
# Alpha: 300
#   R^2: 0.6413
#   RMSE: 5128.5129
#
# Alpha: 500
#   R^2: 0.6410
#   RMSE: 5130.6323
#
# Alpha: 1000
#   R^2: 0.6505
#   RMSE: 5062.9034
#
# Best Alpha based on RMSE: 100
# Best R^2: 0.6615
# Best RMSE: 4981.9476
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 49.8100
#   Curb Weight (lbs): -0.5408
#   Combined MPG: 60.2715
#   Fuel Capacity (gallons): 121.7582
#   Age: -1981.5986
#   Drivetrain_4WD: 2389.6341
#   Drivetrain_AWD: -721.1558
#   Drivetrain_FWD: -1735.8183
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -455.5424
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 0.0000
#   Vehicle Class_full-size: -436.3474
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 1432.3028
#   Vehicle Class_mid-size: 736.6302
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: 0.0000
#
# Intercept: 20731.8138

# %% [markdown]
# #### Functional Aggregated Ridge

# %%
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Aggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6397
#   RMSE: 5140.4791
#
# Alpha: 1.0
#   R^2: 0.6469
#   RMSE: 5088.8217
#
# Alpha: 10.0
#   R^2: 0.6616
#   RMSE: 4981.1846
#
# Alpha: 100
#   R^2: 0.6538
#   RMSE: 5038.9718
#
# Alpha: 200
#   R^2: 0.6539
#   RMSE: 5038.0079
#
# Alpha: 300
#   R^2: 0.6562
#   RMSE: 5020.7598
#
# Alpha: 500
#   R^2: 0.6611
#   RMSE: 4985.4243
#
# Alpha: 1000
#   R^2: 0.6654
#   RMSE: 4953.3072
#
# Best Alpha based on RMSE: 1000
# Best R^2: 0.6654
# Best RMSE: 4953.3072
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 55.3304
#   Curb Weight (lbs): 0.1221
#   Combined MPG: 54.3327
#   Fuel Capacity (gallons): 25.2373
#   Age: -1903.6774
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 0.0000
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#
# Intercept: 17568.8074

# %% [markdown]
# # Functional and Experiential

# %% [markdown]
# ### Functional and Experiental Unaggregated

# %%
features = functional_features + weighted_topic_features + [col for col in car_data_encoded.columns if col.startswith('Model Full Name_')]

X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.9119
#
# RMSE: 2610.2975
#
# Model Coefficients:
#   Horsepower (hp): 5.6206
#   Curb Weight (lbs): -4.1024
#   Combined MPG: -39.8883
#   Fuel Capacity (gallons): -70.7154
#   Age: -1818.9156
#   Drivetrain_4WD: 408.0897
#   Drivetrain_AWD: -1565.4837
#   Drivetrain_FWD: -4207.0758
#   Drivetrain_RWD: -2462.8222
#   Vehicle Class_compact-suv: -375379290838.9056
#   Vehicle Class_electric-car: -989468512746.6051
#   Vehicle Class_electric-suv: -767464473718.1483
#   Vehicle Class_full-size: -1190367864526.7673
#   Vehicle Class_full-size-truck: -2743636871254.4028
#   Vehicle Class_hybrid-car: 1411733363057.9629
#   Vehicle Class_hybrid-suv: -1411697931.9679
#   Vehicle Class_luxury-hybrid-suv: 501548094270.0939
#   Vehicle Class_mid-size: -679967966240.3243
#   Vehicle Class_mid-size-suv: -580398962017.1594
#   Vehicle Class_mid-size-truck: 30130800828.7567
#   Vehicle Class_minivan: -1462356663564.4062
#   Topic_0_Weighted: -7599.1862
#   Topic_2_Weighted: -1092.6232
#   Topic_3_Weighted: 5602.0678
#   Topic_4_Weighted: -1684.7956
#   Topic_5_Weighted: -3175.9654
#   Topic_7_Weighted: -639.9737
#   Topic_8_Weighted: 716.6951
#   Topic_9_Weighted: -86.9912
#   Model Full Name_Acura Tlx: 99569003421.0072
#   Model Full Name_Alfa-romeo Giulia: 99569003525.1004
#   Model Full Name_Alfa-romeo Stelvio: -2780.3956
#   Model Full Name_Audi A4: 99569003880.6382
#   Model Full Name_Audi A6: 99569004524.4011
#   Model Full Name_Audi Q3: -205019674776.7357
#   Model Full Name_Audi Q5: -1081947056416.6606
#   Model Full Name_Audi Q7: -580398958435.6509
#   Model Full Name_Bmw 3-series: 99569003268.1684
#   Model Full Name_Bmw 5-series: 609968902563.4153
#   Model Full Name_Bmw X3: -205019672101.1318
#   Model Full Name_Bmw X5: 5803.1566
#   Model Full Name_Buick Enclave: -580398958924.1293
#   Model Full Name_Buick Encore: -205019678269.6302
#   Model Full Name_Buick Encore-gx: -205019679035.8082
#   Model Full Name_Cadillac Ct4: 99569006081.9434
#   Model Full Name_Cadillac Xt5: 1243.2875
#   Model Full Name_Chevrolet Blazer: -451.8171
#   Model Full Name_Chevrolet Camaro: 99569005560.1788
#   Model Full Name_Chevrolet Colorado: -610529766306.8239
#   Model Full Name_Chevrolet Corvette: 99569022412.6758
#   Model Full Name_Chevrolet Equinox: -205019674070.0289
#   Model Full Name_Chevrolet Impala: 609968902554.8705
#   Model Full Name_Chevrolet Malibu: 99569000646.5429
#   Model Full Name_Chevrolet Silverado-1500: 2163237907930.1519
#   Model Full Name_Chevrolet Ss: 609968915421.5520
#   Model Full Name_Chevrolet Suburban: -580398951775.0452
#   Model Full Name_Chevrolet Tahoe: -580398949447.9768
#   Model Full Name_Chevrolet Trailblazer: -205019675110.2964
#   Model Full Name_Chevrolet Traverse: -580398961386.5685
#   Model Full Name_Chevrolet Trax: -205019682022.5839
#   Model Full Name_Chrysler 200: 99569000042.3158
#   Model Full Name_Chrysler 300: 609968903792.9707
#   Model Full Name_Chrysler Pacifica: 881957699015.0709
#   Model Full Name_Dodge Challenger: 99569009179.9056
#   Model Full Name_Dodge Charger: 609968903545.4001
#   Model Full Name_Dodge Durango: -580398959661.3289
#   Model Full Name_Fiat 500x: -205019682150.0967
#   Model Full Name_Ford Bronco: 13813.7659
#   Model Full Name_Ford Bronco-sport: -205019677181.6375
#   Model Full Name_Ford Escape: -205019678508.4335
#   Model Full Name_Ford Expedition: -580398956155.2780
#   Model Full Name_Ford Explorer: -578987265429.4822
#   Model Full Name_Ford F150: 2163237908776.8994
#   Model Full Name_Ford Focus: 409069547844.2991
#   Model Full Name_Ford Fusion: 99569001872.4118
#   Model Full Name_Ford Maverick: -610529763904.5885
#   Model Full Name_Ford Mustang: 99569009466.8758
#   Model Full Name_Ford Ranger: -610529766516.4243
#   Model Full Name_Ford Taurus: 609968905671.0686
#   Model Full Name_Genesis G70: 99569001617.0080
#   Model Full Name_Genesis G80: 609968904076.0322
#   Model Full Name_Genesis Gv80: 11347.8484
#   Model Full Name_Gmc Acadia: 209.5765
#   Model Full Name_Gmc Canyon: -610529765006.0620
#   Model Full Name_Gmc Hummer-ev: 187065554508.6512
#   Model Full Name_Gmc Sierra-1500: 2163237911740.2981
#   Model Full Name_Gmc Terrain: -205019674868.0360
#   Model Full Name_Gmc Yukon-xl: 609968913830.7976
#   Model Full Name_Honda Accord: 99569003180.2066
#   Model Full Name_Honda Insight: -1992132330035.7769
#   Model Full Name_Honda Odyssey: 881957705108.7013
#   Model Full Name_Honda Passport: -533.2447
#   Model Full Name_Honda Pilot: 146.4335
#   Model Full Name_Honda Ridgeline: -610529759457.7994
#   Model Full Name_Hyundai Azera: 609968901192.6998
#   Model Full Name_Hyundai Elantra: -1992132332684.1528
#   Model Full Name_Hyundai Genesis: 609968900732.4846
#   Model Full Name_Hyundai Ioniq-5: 187065511949.1605
#   Model Full Name_Hyundai Ioniq-6: 409069570744.2485
#   Model Full Name_Hyundai Palisade: 2217.3240
#   Model Full Name_Hyundai Sonata: 99569000957.9027
#   Model Full Name_Hyundai Tucson: -205019678087.0126
#   Model Full Name_Hyundai Venue: -205019683028.0361
#   Model Full Name_Infiniti Q50: 99569002382.0203
#   Model Full Name_Infiniti Qx60: -1081947056572.4592
#   Model Full Name_Infiniti Qx80: 609968907411.8160
#   Model Full Name_Jaguar E-pace: -205019673879.2835
#   Model Full Name_Jaguar F-pace: -1744.6433
#   Model Full Name_Jaguar I-pace: 187065518047.7044
#   Model Full Name_Jeep Cherokee: -205019680051.9828
#   Model Full Name_Jeep Compass: -205019679263.2302
#   Model Full Name_Jeep Gladiator: -610529751285.4850
#   Model Full Name_Jeep Grand-wagoneer: -580398931002.8944
#   Model Full Name_Jeep Renegade: -205019683306.5484
#   Model Full Name_Jeep Wagoneer: -580398948149.9868
#   Model Full Name_Jeep Wrangler: -205019669655.7547
#   Model Full Name_Kia Cadenza: 609968898722.3291
#   Model Full Name_Kia Carnival: 881957709604.6652
#   Model Full Name_Kia Ev6: 187065516339.6696
#   Model Full Name_Kia K5: 99568998955.2780
#   Model Full Name_Kia K900: 609968901290.0476
#   Model Full Name_Kia Optima: 99569000275.0150
#   Model Full Name_Kia Sedona: 881957702325.9103
#   Model Full Name_Kia Seltos: -205019683576.2390
#   Model Full Name_Kia Sorento: -222.4796
#   Model Full Name_Kia Sportage: -205019677386.2017
#   Model Full Name_Kia Stinger: 609968900229.4779
#   Model Full Name_Kia Telluride: 2764.7735
#   Model Full Name_Land-rover Discovery: -580398968185.0616
#   Model Full Name_Land-rover Range-rover-evoque: -205019673188.9074
#   Model Full Name_Lexus Es: 99569007642.6904
#   Model Full Name_Lexus Gx: -580398949877.0800
#   Model Full Name_Lexus Nx: -1081947053185.2540
#   Model Full Name_Lexus Rx: -1081947048348.2717
#   Model Full Name_Lexus Ux: -1081947058982.0499
#   Model Full Name_Mazda Cx-5: -205019674570.5712
#   Model Full Name_Mazda Cx-50: -205019668035.0521
#   Model Full Name_Mazda Cx-9: 740.4627
#   Model Full Name_Mazda Mazda6: 99569002330.7374
#   Model Full Name_Mazda Mx-5-miata: 99568998764.9736
#   Model Full Name_Mercedes-benz A-class: 99569002020.0041
#   Model Full Name_Mercedes-benz C-class: 99569006778.7862
#   Model Full Name_Mercedes-benz E-class: 609968904082.2933
#   Model Full Name_Mercedes-benz Glc: -205019674046.5986
#   Model Full Name_Mercedes-benz Gle: 9676.9449
#   Model Full Name_Mini Countryman: -205019674906.6841
#   Model Full Name_Mitsubishi Outlander: -205019678122.2297
#   Model Full Name_Nissan Altima: 99568999853.8171
#   Model Full Name_Nissan Ariya: 187065537724.4767
#   Model Full Name_Nissan Armada: -580398959378.7874
#   Model Full Name_Nissan Frontier: -610529763946.2954
#   Model Full Name_Nissan Kicks: -205019684332.9427
#   Model Full Name_Nissan Leaf: 409069549476.7983
#   Model Full Name_Nissan Maxima: 609968899374.2585
#   Model Full Name_Nissan Murano: -3322.8505
#   Model Full Name_Nissan Pathfinder: -2584.9222
#   Model Full Name_Nissan Quest: 881957702522.6147
#   Model Full Name_Nissan Rogue: -205019675920.2818
#   Model Full Name_Nissan Titan: 2163237912762.0928
#   Model Full Name_Porsche Cayenne: 9903.1226
#   Model Full Name_Porsche Macan: -205019669838.1779
#   Model Full Name_Subaru Ascent: -1671.4893
#   Model Full Name_Subaru Brz: 99568997601.5190
#   Model Full Name_Subaru Crosstrek: -578987271338.5482
#   Model Full Name_Subaru Forester: -205019676484.9217
#   Model Full Name_Subaru Legacy: 99568999365.3627
#   Model Full Name_Subaru Outback: -4434.8159
#   Model Full Name_Subaru Solterra: 187065532642.0467
#   Model Full Name_Tesla Model-3: 409069555541.9027
#   Model Full Name_Tesla Model-s: 409069565777.6470
#   Model Full Name_Tesla Model-x: 187065519873.5082
#   Model Full Name_Tesla Model-y: 187065520089.8351
#   Model Full Name_Toyota 4runner: 11189.8496
#   Model Full Name_Toyota Avalon: 609968903704.1193
#   Model Full Name_Toyota Camry: 99569003542.7114
#   Model Full Name_Toyota Corolla: 99568999253.0878
#   Model Full Name_Toyota Crown: 99569018361.2247
#   Model Full Name_Toyota Highlander: 5131.3228
#   Model Full Name_Toyota Land-cruiser: 609968926753.0925
#   Model Full Name_Toyota Prius: -1992132325247.8777
#   Model Full Name_Toyota Rav4: -205019672161.3563
#   Model Full Name_Toyota Sienna: 881957710719.9177
#   Model Full Name_Toyota Tacoma: -610529762055.7876
#   Model Full Name_Toyota Tundra: 2163237918746.3013
#   Model Full Name_Toyota Venza: 3370.0622
#   Model Full Name_Volkswagen Arteon: 609968899255.5121
#   Model Full Name_Volkswagen Atlas: -580398960839.2913
#   Model Full Name_Volkswagen Golf-gti: 99568998122.7791
#   Model Full Name_Volkswagen Id-4: 187065514958.5681
#   Model Full Name_Volkswagen Jetta: -1992132330474.1699
#   Model Full Name_Volkswagen Passat: 99569000718.8084
#   Model Full Name_Volkswagen Tiguan: -205019673695.8170
#   Model Full Name_Volvo Xc40: -205019673868.0610
#   Model Full Name_Volvo Xc60: 738.6912
#   Model Full Name_Volvo Xc90: -580398960548.9318
#
# Intercept: 580399012804.6849

# %% [markdown]
# #### Functional and Experiental Unaggregated Lasso

# %%
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# /Users/TimmyRen/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.042e+10, tolerance: 1.017e+08
#   model = cd_fast.enet_coordinate_descent(
# Alpha: 0.1
#   R^2: 0.9118
#   RMSE: 2611.2940
#
# Alpha: 1.0
#   R^2: 0.9091
#   RMSE: 2650.4459
#
# Alpha: 10.0
#   R^2: 0.8666
#   RMSE: 3211.5834
#
# Alpha: 100
#   R^2: 0.7631
#   RMSE: 4279.5725
#
# Alpha: 200
#   R^2: 0.7520
#   RMSE: 4378.6120
#
# Alpha: 300
#   R^2: 0.7434
#   RMSE: 4454.1856
#
# Alpha: 500
#   R^2: 0.7307
#   RMSE: 4562.9037
#
# Alpha: 1000
#   R^2: 0.7281
#   RMSE: 4584.6565
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.9118
# Best RMSE: 2611.2940
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 6.7497
#   Curb Weight (lbs): -4.0500
#   Combined MPG: -39.2794
#   Fuel Capacity (gallons): -54.4724
#   Age: -1818.6749
#   Drivetrain_4WD: 448.9855
#   Drivetrain_AWD: -1574.2018
#   Drivetrain_FWD: -4224.6725
#   Drivetrain_RWD: -2386.4345
#   Vehicle Class_compact-suv: -5657.8783
#   Vehicle Class_electric-car: 1566.9592
#   Vehicle Class_electric-suv: 6584.0864
#   Vehicle Class_full-size: -311.2188
#   Vehicle Class_full-size-truck: 795.0186
#   Vehicle Class_hybrid-car: -6235.9042
#   Vehicle Class_hybrid-suv: -2913.0119
#   Vehicle Class_luxury-hybrid-suv: -122.2227
#   Vehicle Class_mid-size: -2992.1144
#   Vehicle Class_mid-size-suv: -1397.7358
#   Vehicle Class_mid-size-truck: -2455.2268
#   Vehicle Class_minivan: -0.0000
#   Topic_0_Weighted: -6970.0892
#   Topic_2_Weighted: -770.7813
#   Topic_3_Weighted: 4990.3344
#   Topic_4_Weighted: -1305.8269
#   Topic_5_Weighted: -2794.5308
#   Topic_7_Weighted: -448.9659
#   Topic_8_Weighted: 325.2508
#   Topic_9_Weighted: -0.0000
#   Model Full Name_Acura Tlx: 776.9665
#   Model Full Name_Alfa-romeo Giulia: 730.6445
#   Model Full Name_Alfa-romeo Stelvio: -2826.9367
#   Model Full Name_Audi A4: 1273.3234
#   Model Full Name_Audi A6: 1785.7307
#   Model Full Name_Audi Q3: 637.6497
#   Model Full Name_Audi Q5: -1490.0521
#   Model Full Name_Audi Q7: 1953.3949
#   Model Full Name_Bmw 3-series: 581.7786
#   Model Full Name_Bmw 5-series: -1171.7861
#   Model Full Name_Bmw X3: 3261.7976
#   Model Full Name_Bmw X5: 5489.5041
#   Model Full Name_Buick Enclave: 1497.6361
#   Model Full Name_Buick Encore: -2633.5981
#   Model Full Name_Buick Encore-gx: -3388.3205
#   Model Full Name_Cadillac Ct4: 3213.9927
#   Model Full Name_Cadillac Xt5: 1061.4942
#   Model Full Name_Chevrolet Blazer: -436.4409
#   Model Full Name_Chevrolet Camaro: 2685.6597
#   Model Full Name_Chevrolet Colorado: -2406.3074
#   Model Full Name_Chevrolet Corvette: 19440.0378
#   Model Full Name_Chevrolet Equinox: 1418.8976
#   Model Full Name_Chevrolet Impala: -990.3341
#   Model Full Name_Chevrolet Malibu: -1865.0384
#   Model Full Name_Chevrolet Silverado-1500: -3736.9684
#   Model Full Name_Chevrolet Ss: 11435.1150
#   Model Full Name_Chevrolet Suburban: 8395.5033
#   Model Full Name_Chevrolet Tahoe: 10795.4072
#   Model Full Name_Chevrolet Trailblazer: 350.6271
#   Model Full Name_Chevrolet Traverse: -959.5625
#   Model Full Name_Chevrolet Trax: -6371.7544
#   Model Full Name_Chrysler 200: -2493.6491
#   Model Full Name_Chrysler 300: 0.0000
#   Model Full Name_Chrysler Pacifica: -4035.3854
#   Model Full Name_Dodge Challenger: 6378.5026
#   Model Full Name_Dodge Charger: -148.9522
#   Model Full Name_Dodge Durango: 663.7893
#   Model Full Name_Fiat 500x: -6513.5911
#   Model Full Name_Ford Bronco: 13635.0992
#   Model Full Name_Ford Bronco-sport: -1419.4196
#   Model Full Name_Ford Escape: -2987.7831
#   Model Full Name_Ford Expedition: 4049.4064
#   Model Full Name_Ford Explorer: -0.0000
#   Model Full Name_Ford F150: -2903.2227
#   Model Full Name_Ford Focus: -5659.3549
#   Model Full Name_Ford Fusion: -713.0903
#   Model Full Name_Ford Maverick: 0.0000
#   Model Full Name_Ford Mustang: 6722.6531
#   Model Full Name_Ford Ranger: -2580.4973
#   Model Full Name_Ford Taurus: 1962.4318
#   Model Full Name_Genesis G70: -1057.3070
#   Model Full Name_Genesis G80: 181.7214
#   Model Full Name_Genesis Gv80: 11020.5921
#   Model Full Name_Gmc Acadia: 85.3379
#   Model Full Name_Gmc Canyon: -1105.1686
#   Model Full Name_Gmc Hummer-ev: 33396.9410
#   Model Full Name_Gmc Sierra-1500: 0.0000
#   Model Full Name_Gmc Terrain: 609.4027
#   Model Full Name_Gmc Yukon-xl: 9744.6040
#   Model Full Name_Honda Accord: 608.8364
#   Model Full Name_Honda Insight: -0.0000
#   Model Full Name_Honda Odyssey: 2030.5949
#   Model Full Name_Honda Passport: -637.6747
#   Model Full Name_Honda Pilot: -0.0000
#   Model Full Name_Honda Ridgeline: 4249.0181
#   Model Full Name_Hyundai Azera: -2460.3107
#   Model Full Name_Hyundai Elantra: -2571.7247
#   Model Full Name_Hyundai Genesis: -3133.8151
#   Model Full Name_Hyundai Ioniq-5: -7766.1110
#   Model Full Name_Hyundai Ioniq-6: 15708.0870
#   Model Full Name_Hyundai Palisade: 2066.7990
#   Model Full Name_Hyundai Sonata: -1634.1639
#   Model Full Name_Hyundai Tucson: -2547.5872
#   Model Full Name_Hyundai Venue: -7287.2660
#   Model Full Name_Infiniti Q50: -361.0729
#   Model Full Name_Infiniti Qx60: -1638.5491
#   Model Full Name_Infiniti Qx80: 3321.5911
#   Model Full Name_Jaguar E-pace: 1233.8489
#   Model Full Name_Jaguar F-pace: -1669.9536
#   Model Full Name_Jaguar I-pace: -1855.0589
#   Model Full Name_Jeep Cherokee: -4534.2987
#   Model Full Name_Jeep Compass: -3741.6996
#   Model Full Name_Jeep Gladiator: 12333.0909
#   Model Full Name_Jeep Grand-wagoneer: 28897.8971
#   Model Full Name_Jeep Renegade: -7751.2673
#   Model Full Name_Jeep Wagoneer: 12012.7484
#   Model Full Name_Jeep Wrangler: 5672.1682
#   Model Full Name_Kia Cadenza: -4943.2171
#   Model Full Name_Kia Carnival: 6459.8482
#   Model Full Name_Kia Ev6: -3384.5843
#   Model Full Name_Kia K5: -3516.7910
#   Model Full Name_Kia K900: -2560.1518
#   Model Full Name_Kia Optima: -2286.3393
#   Model Full Name_Kia Sedona: -742.1640
#   Model Full Name_Kia Seltos: -8015.0773
#   Model Full Name_Kia Sorento: -188.1815
#   Model Full Name_Kia Sportage: -1833.3538
#   Model Full Name_Kia Stinger: -3454.2897
#   Model Full Name_Kia Telluride: 2617.3586
#   Model Full Name_Land-rover Discovery: -7733.6671
#   Model Full Name_Land-rover Range-rover-evoque: 2117.3802
#   Model Full Name_Lexus Es: 4979.1746
#   Model Full Name_Lexus Gx: 10393.3780
#   Model Full Name_Lexus Nx: 1811.6418
#   Model Full Name_Lexus Rx: 6533.5291
#   Model Full Name_Lexus Ux: -3716.4639
#   Model Full Name_Mazda Cx-5: 960.6348
#   Model Full Name_Mazda Cx-50: 7221.9680
#   Model Full Name_Mazda Cx-9: 625.4595
#   Model Full Name_Mazda Mazda6: -214.0753
#   Model Full Name_Mazda Mx-5-miata: -3731.1748
#   Model Full Name_Mercedes-benz A-class: -380.3003
#   Model Full Name_Mercedes-benz C-class: 4042.2025
#   Model Full Name_Mercedes-benz E-class: 338.4871
#   Model Full Name_Mercedes-benz Glc: 1238.1893
#   Model Full Name_Mercedes-benz Gle: 9384.4625
#   Model Full Name_Mini Countryman: 731.7153
#   Model Full Name_Mitsubishi Outlander: -2611.9518
#   Model Full Name_Nissan Altima: -2706.1834
#   Model Full Name_Nissan Ariya: 17644.7814
#   Model Full Name_Nissan Armada: 817.8555
#   Model Full Name_Nissan Frontier: -28.5277
#   Model Full Name_Nissan Kicks: -8601.8281
#   Model Full Name_Nissan Leaf: -4147.7006
#   Model Full Name_Nissan Maxima: -4303.3349
#   Model Full Name_Nissan Murano: -3422.8763
#   Model Full Name_Nissan Pathfinder: -2731.7683
#   Model Full Name_Nissan Quest: -519.0669
#   Model Full Name_Nissan Rogue: -377.5072
#   Model Full Name_Nissan Titan: 923.0583
#   Model Full Name_Porsche Cayenne: 9663.3685
#   Model Full Name_Porsche Macan: 5366.9389
#   Model Full Name_Subaru Ascent: -1763.8043
#   Model Full Name_Subaru Brz: -4963.8110
#   Model Full Name_Subaru Crosstrek: -5663.0595
#   Model Full Name_Subaru Forester: -956.3823
#   Model Full Name_Subaru Legacy: -3209.2657
#   Model Full Name_Subaru Outback: -4394.2833
#   Model Full Name_Subaru Solterra: 12454.5373
#   Model Full Name_Tesla Model-3: 1645.5683
#   Model Full Name_Tesla Model-s: 11764.0051
#   Model Full Name_Tesla Model-x: 0.0000
#   Model Full Name_Tesla Model-y: 241.5576
#   Model Full Name_Toyota 4runner: 10890.8868
#   Model Full Name_Toyota Avalon: 53.3892
#   Model Full Name_Toyota Camry: 969.9165
#   Model Full Name_Toyota Corolla: -3164.0655
#   Model Full Name_Toyota Crown: 15473.2279
#   Model Full Name_Toyota Highlander: 4991.4667
#   Model Full Name_Toyota Land-cruiser: 22674.1206
#   Model Full Name_Toyota Prius: 4745.2765
#   Model Full Name_Toyota Rav4: 3308.5608
#   Model Full Name_Toyota Sienna: 7655.1957
#   Model Full Name_Toyota Tacoma: 1824.4414
#   Model Full Name_Toyota Tundra: 6967.5453
#   Model Full Name_Toyota Venza: 3368.6695
#   Model Full Name_Volkswagen Arteon: -4355.5635
#   Model Full Name_Volkswagen Atlas: -309.2361
#   Model Full Name_Volkswagen Golf-gti: -4368.5987
#   Model Full Name_Volkswagen Id-4: -4823.8517
#   Model Full Name_Volkswagen Jetta: -376.2621
#   Model Full Name_Volkswagen Passat: -1886.4678
#   Model Full Name_Volkswagen Tiguan: 1774.9006
#   Model Full Name_Volvo Xc40: 1577.5662
#   Model Full Name_Volvo Xc60: 613.4250
#   Model Full Name_Volvo Xc90: -31.6237
#
# Intercept: 51452.0482

# %% [markdown]
# #### Functional and Experiental Unaggregated Ridge

# %%
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.9118
#   RMSE: 2611.1601
#
# Alpha: 1.0
#   R^2: 0.9104
#   RMSE: 2631.7941
#
# Alpha: 10.0
#   R^2: 0.8974
#   RMSE: 2815.9590
#
# Alpha: 100
#   R^2: 0.8510
#   RMSE: 3393.9230
#
# Alpha: 200
#   R^2: 0.8286
#   RMSE: 3640.3930
#
# Alpha: 300
#   R^2: 0.8157
#   RMSE: 3774.7758
#
# Alpha: 500
#   R^2: 0.8008
#   RMSE: 3924.4103
#
# Alpha: 1000
#   R^2: 0.7833
#   RMSE: 4092.7527
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.9118
# Best RMSE: 2611.1601
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 54.9404
#   Curb Weight (lbs): -0.8939
#   Combined MPG: 16.6959
#   Fuel Capacity (gallons): 50.7800
#   Age: -1623.9290
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 0.0000
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#   Topic_0_Weighted: -0.0000
#   Topic_2_Weighted: -0.0000
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: 0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#   Model Full Name_Acura Tlx: -0.0000
#   Model Full Name_Alfa-romeo Giulia: -0.0000
#   Model Full Name_Alfa-romeo Stelvio: -0.0000
#   Model Full Name_Audi A4: 0.0000
#   Model Full Name_Audi A6: -0.0000
#   Model Full Name_Audi Q3: -0.0000
#   Model Full Name_Audi Q5: -0.0000
#   Model Full Name_Audi Q7: -0.0000
#   Model Full Name_Bmw 3-series: 0.0000
#   Model Full Name_Bmw 5-series: -0.0000
#   Model Full Name_Bmw X3: -0.0000
#   Model Full Name_Bmw X5: -0.0000
#   Model Full Name_Buick Enclave: -0.0000
#   Model Full Name_Buick Encore: -0.0000
#   Model Full Name_Buick Encore-gx: -0.0000
#   Model Full Name_Cadillac Ct4: 0.0000
#   Model Full Name_Cadillac Xt5: -0.0000
#   Model Full Name_Chevrolet Blazer: 0.0000
#   Model Full Name_Chevrolet Camaro: -0.0000
#   Model Full Name_Chevrolet Colorado: 0.0000
#   Model Full Name_Chevrolet Corvette: 0.0000
#   Model Full Name_Chevrolet Equinox: -0.0000
#   Model Full Name_Chevrolet Impala: -0.0000
#   Model Full Name_Chevrolet Malibu: -0.0000
#   Model Full Name_Chevrolet Silverado-1500: -0.0000
#   Model Full Name_Chevrolet Ss: 0.0000
#   Model Full Name_Chevrolet Suburban: 0.0000
#   Model Full Name_Chevrolet Tahoe: 0.0000
#   Model Full Name_Chevrolet Trailblazer: 0.0000
#   Model Full Name_Chevrolet Traverse: -0.0000
#   Model Full Name_Chevrolet Trax: -0.0000
#   Model Full Name_Chrysler 200: -0.0000
#   Model Full Name_Chrysler 300: -0.0000
#   Model Full Name_Chrysler Pacifica: -0.0000
#   Model Full Name_Dodge Challenger: 0.0000
#   Model Full Name_Dodge Charger: 0.0000
#   Model Full Name_Dodge Durango: -0.0000
#   Model Full Name_Fiat 500x: -0.0000
#   Model Full Name_Ford Bronco: 0.0000
#   Model Full Name_Ford Bronco-sport: 0.0000
#   Model Full Name_Ford Escape: -0.0000
#   Model Full Name_Ford Expedition: -0.0000
#   Model Full Name_Ford Explorer: -0.0000
#   Model Full Name_Ford F150: -0.0000
#   Model Full Name_Ford Focus: 0.0000
#   Model Full Name_Ford Fusion: -0.0000
#   Model Full Name_Ford Maverick: -0.0000
#   Model Full Name_Ford Mustang: 0.0000
#   Model Full Name_Ford Ranger: 0.0000
#   Model Full Name_Ford Taurus: -0.0000
#   Model Full Name_Genesis G70: -0.0000
#   Model Full Name_Genesis G80: -0.0000
#   Model Full Name_Genesis Gv80: 0.0000
#   Model Full Name_Gmc Acadia: -0.0000
#   Model Full Name_Gmc Canyon: 0.0000
#   Model Full Name_Gmc Hummer-ev: 0.0000
#   Model Full Name_Gmc Sierra-1500: 0.0000
#   Model Full Name_Gmc Terrain: 0.0000
#   Model Full Name_Gmc Yukon-xl: 0.0000
#   Model Full Name_Honda Accord: 0.0000
#   Model Full Name_Honda Insight: -0.0000
#   Model Full Name_Honda Odyssey: -0.0000
#   Model Full Name_Honda Passport: -0.0000
#   Model Full Name_Honda Pilot: -0.0000
#   Model Full Name_Honda Ridgeline: 0.0000
#   Model Full Name_Hyundai Azera: -0.0000
#   Model Full Name_Hyundai Elantra: -0.0000
#   Model Full Name_Hyundai Genesis: -0.0000
#   Model Full Name_Hyundai Ioniq-5: -0.0000
#   Model Full Name_Hyundai Ioniq-6: 0.0000
#   Model Full Name_Hyundai Palisade: -0.0000
#   Model Full Name_Hyundai Sonata: -0.0000
#   Model Full Name_Hyundai Tucson: -0.0000
#   Model Full Name_Hyundai Venue: -0.0000
#   Model Full Name_Infiniti Q50: -0.0000
#   Model Full Name_Infiniti Qx60: -0.0000
#   Model Full Name_Infiniti Qx80: -0.0000
#   Model Full Name_Jaguar E-pace: -0.0000
#   Model Full Name_Jaguar F-pace: 0.0000
#   Model Full Name_Jaguar I-pace: -0.0000
#   Model Full Name_Jeep Cherokee: -0.0000
#   Model Full Name_Jeep Compass: -0.0000
#   Model Full Name_Jeep Gladiator: 0.0000
#   Model Full Name_Jeep Grand-wagoneer: 0.0000
#   Model Full Name_Jeep Renegade: -0.0000
#   Model Full Name_Jeep Wagoneer: 0.0000
#   Model Full Name_Jeep Wrangler: 0.0000
#   Model Full Name_Kia Cadenza: -0.0000
#   Model Full Name_Kia Carnival: 0.0000
#   Model Full Name_Kia Ev6: 0.0000
#   Model Full Name_Kia K5: -0.0000
#   Model Full Name_Kia K900: -0.0000
#   Model Full Name_Kia Optima: -0.0000
#   Model Full Name_Kia Sedona: -0.0000
#   Model Full Name_Kia Seltos: -0.0000
#   Model Full Name_Kia Sorento: 0.0000
#   Model Full Name_Kia Sportage: 0.0000
#   Model Full Name_Kia Stinger: -0.0000
#   Model Full Name_Kia Telluride: -0.0000
#   Model Full Name_Land-rover Discovery: -0.0000
#   Model Full Name_Land-rover Range-rover-evoque: -0.0000
#   Model Full Name_Lexus Es: 0.0000
#   Model Full Name_Lexus Gx: 0.0000
#   Model Full Name_Lexus Nx: 0.0000
#   Model Full Name_Lexus Rx: 0.0000
#   Model Full Name_Lexus Ux: 0.0000
#   Model Full Name_Mazda Cx-5: -0.0000
#   Model Full Name_Mazda Cx-50: 0.0000
#   Model Full Name_Mazda Cx-9: -0.0000
#   Model Full Name_Mazda Mazda6: 0.0000
#   Model Full Name_Mazda Mx-5-miata: 0.0000
#   Model Full Name_Mercedes-benz A-class: 0.0000
#   Model Full Name_Mercedes-benz C-class: 0.0000
#   Model Full Name_Mercedes-benz E-class: 0.0000
#   Model Full Name_Mercedes-benz Glc: -0.0000
#   Model Full Name_Mercedes-benz Gle: 0.0000
#   Model Full Name_Mini Countryman: 0.0000
#   Model Full Name_Mitsubishi Outlander: 0.0000
#   Model Full Name_Nissan Altima: -0.0000
#   Model Full Name_Nissan Ariya: 0.0000
#   Model Full Name_Nissan Armada: -0.0000
#   Model Full Name_Nissan Frontier: 0.0000
#   Model Full Name_Nissan Kicks: -0.0000
#   Model Full Name_Nissan Leaf: -0.0000
#   Model Full Name_Nissan Maxima: -0.0000
#   Model Full Name_Nissan Murano: -0.0000
#   Model Full Name_Nissan Pathfinder: -0.0000
#   Model Full Name_Nissan Quest: -0.0000
#   Model Full Name_Nissan Rogue: 0.0000
#   Model Full Name_Nissan Titan: -0.0000
#   Model Full Name_Porsche Cayenne: 0.0000
#   Model Full Name_Porsche Macan: -0.0000
#   Model Full Name_Subaru Ascent: -0.0000
#   Model Full Name_Subaru Brz: -0.0000
#   Model Full Name_Subaru Crosstrek: -0.0000
#   Model Full Name_Subaru Forester: 0.0000
#   Model Full Name_Subaru Legacy: 0.0000
#   Model Full Name_Subaru Outback: 0.0000
#   Model Full Name_Subaru Solterra: 0.0000
#   Model Full Name_Tesla Model-3: 0.0000
#   Model Full Name_Tesla Model-s: 0.0000
#   Model Full Name_Tesla Model-x: 0.0000
#   Model Full Name_Tesla Model-y: 0.0000
#   Model Full Name_Toyota 4runner: 0.0000
#   Model Full Name_Toyota Avalon: -0.0000
#   Model Full Name_Toyota Camry: 0.0000
#   Model Full Name_Toyota Corolla: 0.0000
#   Model Full Name_Toyota Crown: 0.0000
#   Model Full Name_Toyota Highlander: 0.0000
#   Model Full Name_Toyota Land-cruiser: 0.0000
#   Model Full Name_Toyota Prius: -0.0000
#   Model Full Name_Toyota Rav4: 0.0000
#   Model Full Name_Toyota Sienna: 0.0000
#   Model Full Name_Toyota Tacoma: 0.0000
#   Model Full Name_Toyota Tundra: 0.0000
#   Model Full Name_Toyota Venza: 0.0000
#   Model Full Name_Volkswagen Arteon: -0.0000
#   Model Full Name_Volkswagen Atlas: -0.0000
#   Model Full Name_Volkswagen Golf-gti: -0.0000
#   Model Full Name_Volkswagen Id-4: -0.0000
#   Model Full Name_Volkswagen Jetta: 0.0000
#   Model Full Name_Volkswagen Passat: -0.0000
#   Model Full Name_Volkswagen Tiguan: 0.0000
#   Model Full Name_Volvo Xc40: 0.0000
#   Model Full Name_Volvo Xc60: -0.0000
#   Model Full Name_Volvo Xc90: -0.0000
#
# Intercept: 18759.0061

# %% [markdown]
# ### Functional and Experiental Aggregated

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Car Brand', 'Car Model', 'Year', 'Review',
#        'Rating', 'Value Rating', 'Performance Rating', 'Quality Rating',
#        'Comfort Rating', 'Reliability Rating', 'Styling Rating',
#        'Vehicle Class', 'Model Full Name', 'Horsepower (hp)',
#        'Curb Weight (lbs)', 'Combined MPG', 'Fuel Capacity (gallons)',
#        'Drivetrain', 'Recommended Fuel', 'Average MSRP Price ($)',
#        'Average KBB Fair Price ($)', 'Review_Topics', 'Topic_0', 'Topic_1',
#        'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_6', 'Topic_7',
#        'Topic_8', 'Topic_9', 'Sentiment Score', 'Depreciated Value',
#        'Sentiment Bin', 'Weighted Sentiment Score', 'Topic_0_Weighted',
#        'Topic_2_Weighted', 'Topic_3_Weighted', 'Topic_4_Weighted',
#        'Topic_5_Weighted', 'Topic_7_Weighted', 'Topic_8_Weighted',
#        'Topic_9_Weighted', 'Age'],
#       dtype='object')

# %%
car_data_encoded_agg
# Out:
#     Model Full Name  Year  Horsepower (hp)  Curb Weight (lbs)  Combined MPG  \
# 0         Acura Rdx  2010            240.0             3931.0          19.0
# 1         Acura Rdx  2013            273.0             3838.0          22.0
# 2         Acura Rdx  2019            272.0             3783.0          24.0
# 3         Acura Tlx  2015            206.0             3483.0          28.0
# 4         Acura Tlx  2021            272.0             3709.0          25.0
# ..              ...   ...              ...                ...           ...
# 321      Volvo Xc40  2019            187.0             3574.0          27.0
# 322      Volvo Xc60  2010            235.0             4012.0          21.0
# 323      Volvo Xc60  2018            316.0             4074.0          23.0
# 324      Volvo Xc90  2010            235.0             4751.0          17.0
# 325      Volvo Xc90  2016            250.0             4293.0          22.0
#
#      Fuel Capacity (gallons)   Age  Average KBB Fair Price ($)  \
# 0                       18.0  14.0                      7210.0
# 1                       16.0  11.0                     10589.0
# 2                       17.1   5.0                     23046.5
# 3                       17.2   9.0                     11905.5
# 4                       15.9   3.0                     29701.0
# ..                       ...   ...                         ...
# 321                     14.2   5.0                     18941.0
# 322                     18.5  14.0                      7055.0
# 323                     18.8   6.0                     23469.0
# 324                     21.1  14.0                      6471.0
# 325                     18.8   8.0                     15411.5
#
#      Car Brand_alfa-romeo  Car Brand_audi  ...  Vehicle Class_electric-suv  \
# 0                   False           False  ...                       False
# 1                   False           False  ...                       False
# 2                   False           False  ...                       False
# 3                   False           False  ...                       False
# 4                   False           False  ...                       False
# ..                    ...             ...  ...                         ...
# 321                 False           False  ...                       False
# 322                 False           False  ...                       False
# 323                 False           False  ...                       False
# 324                 False           False  ...                       False
# 325                 False           False  ...                       False
#
#      Vehicle Class_full-size  Vehicle Class_full-size-truck  \
# 0                      False                          False
# 1                      False                          False
# 2                      False                          False
# 3                      False                          False
# 4                      False                          False
# ..                       ...                            ...
# 321                    False                          False
# 322                    False                          False
# 323                    False                          False
# 324                    False                          False
# 325                    False                          False
#
#      Vehicle Class_hybrid-car  Vehicle Class_hybrid-suv  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
# ..                        ...                       ...
# 321                     False                     False
# 322                     False                     False
# 323                     False                     False
# 324                     False                     False
# 325                     False                     False
#
#      Vehicle Class_luxury-hybrid-suv  Vehicle Class_mid-size  \
# 0                              False                   False
# 1                              False                   False
# 2                              False                   False
# 3                              False                    True
# 4                              False                    True
# ..                               ...                     ...
# 321                            False                   False
# 322                            False                   False
# 323                            False                   False
# 324                            False                   False
# 325                            False                   False
#
#      Vehicle Class_mid-size-suv  Vehicle Class_mid-size-truck  \
# 0                          True                         False
# 1                          True                         False
# 2                          True                         False
# 3                         False                         False
# 4                         False                         False
# ..                          ...                           ...
# 321                       False                         False
# 322                        True                         False
# 323                        True                         False
# 324                       False                         False
# 325                       False                         False
#
#      Vehicle Class_minivan
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ..                     ...
# 321                  False
# 322                  False
# 323                  False
# 324                  False
# 325                  False
#
# [326 rows x 221 columns]

# %%
car_data_encoded_agg.columns
# Out:
# Index(['Model Full Name', 'Year', 'Horsepower (hp)', 'Curb Weight (lbs)',
#        'Combined MPG', 'Fuel Capacity (gallons)', 'Age',
#        'Average KBB Fair Price ($)', 'Car Brand_alfa-romeo', 'Car Brand_audi',
#        ...
#        'Vehicle Class_electric-suv', 'Vehicle Class_full-size',
#        'Vehicle Class_full-size-truck', 'Vehicle Class_hybrid-car',
#        'Vehicle Class_hybrid-suv', 'Vehicle Class_luxury-hybrid-suv',
#        'Vehicle Class_mid-size', 'Vehicle Class_mid-size-suv',
#        'Vehicle Class_mid-size-truck', 'Vehicle Class_minivan'],
#       dtype='object', length=221)

# %%
#aggregated
aggregated_data = df.groupby(['Model Full Name', 'Year']).agg({
    'Horsepower (hp)': 'mean',
    'Curb Weight (lbs)': 'mean',
    'Combined MPG': 'mean',
    'Fuel Capacity (gallons)': 'mean',
    'Age': 'mean',
    'Average KBB Fair Price ($)': 'mean',
    'Vehicle Class': 'first',
    'Car Brand': 'first',
    #'Car Model': 'first',
    'Topic_0_Weighted': 'mean',
    'Topic_2_Weighted': 'mean', 
    'Topic_3_Weighted': 'mean', 
    'Topic_4_Weighted': 'mean',
    'Topic_5_Weighted': 'mean', 
    'Topic_7_Weighted': 'mean', 
    'Topic_8_Weighted': 'mean',
    'Topic_9_Weighted': 'mean',
    'Drivetrain': 'first'
}).reset_index()

car_data_encoded_agg = pd.get_dummies(aggregated_data, columns=['Car Brand', 'Drivetrain', 'Vehicle Class'], drop_first=True)


X = car_data_encoded_agg.drop(columns=['Average KBB Fair Price ($)','Model Full Name'])
y_price = car_data_encoded_agg['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.6418
#
# RMSE: 5125.4296
#
# Model Coefficients:
#   Year: 1054.7543
#   Horsepower (hp): 41.3409
#   Curb Weight (lbs): -1.1459
#   Combined MPG: -39.4635
#   Fuel Capacity (gallons): 286.1528
#   Age: -1054.7543
#   Topic_0_Weighted: -10652.3721
#   Topic_2_Weighted: -18371.5924
#   Topic_3_Weighted: 3694.2316
#   Topic_4_Weighted: 17846.6242
#   Topic_5_Weighted: -5344.4536
#   Topic_7_Weighted: -5219.5138
#   Topic_8_Weighted: 1886.8826
#   Topic_9_Weighted: 3623.3385
#   Car Brand_alfa-romeo: -4781.3345
#   Car Brand_audi: -1394.1298
#   Car Brand_bmw: -503.4102
#   Car Brand_buick: -403.8515
#   Car Brand_cadillac: -1767.0756
#   Car Brand_chevrolet: 2673.1271
#   Car Brand_chrysler: -1338.8401
#   Car Brand_dodge: 2374.7856
#   Car Brand_fiat: -3997.7462
#   Car Brand_ford: -396.2822
#   Car Brand_genesis: 936.0639
#   Car Brand_gmc: 1598.7437
#   Car Brand_honda: 417.2032
#   Car Brand_hyundai: -2226.9507
#   Car Brand_infiniti: -5729.8487
#   Car Brand_jaguar: -5189.8643
#   Car Brand_jeep: 939.6090
#   Car Brand_kia: -2037.6115
#   Car Brand_land-rover: -4681.6993
#   Car Brand_lexus: 4825.5611
#   Car Brand_mazda: 3251.4077
#   Car Brand_mercedes-benz: 537.7676
#   Car Brand_mini: 7227.5392
#   Car Brand_mitsubishi: -2521.3607
#   Car Brand_nissan: -1558.2385
#   Car Brand_porsche: 5264.2144
#   Car Brand_subaru: -1110.9331
#   Car Brand_tesla: -4312.2410
#   Car Brand_toyota: 4052.0047
#   Car Brand_volkswagen: -949.9922
#   Car Brand_volvo: 449.7769
#   Drivetrain_4WD: 1994.5868
#   Drivetrain_AWD: -1909.0357
#   Drivetrain_FWD: -4358.7291
#   Drivetrain_RWD: -881.7475
#   Vehicle Class_compact-suv: 1194.9132
#   Vehicle Class_electric-car: 13242.4019
#   Vehicle Class_electric-suv: 11422.0256
#   Vehicle Class_full-size: 17.5871
#   Vehicle Class_full-size-truck: -4291.4817
#   Vehicle Class_hybrid-car: 3350.2915
#   Vehicle Class_hybrid-suv: -2061.1567
#   Vehicle Class_luxury-hybrid-suv: 4896.6215
#   Vehicle Class_mid-size: 3474.9160
#   Vehicle Class_mid-size-suv: 1105.3662
#   Vehicle Class_mid-size-truck: 1417.0548
#   Vehicle Class_minivan: 3632.8787
#
# Intercept: -2109252.1341

# %% [markdown]
# #### Functional and Experiental Aggregated lasso

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6419
#   RMSE: 5124.5463
#
# Alpha: 1.0
#   R^2: 0.6430
#   RMSE: 5116.3409
#
# Alpha: 10.0
#   R^2: 0.6538
#   RMSE: 5038.6480
#
# Alpha: 100
#   R^2: 0.7050
#   RMSE: 4650.9941
#
# Alpha: 200
#   R^2: 0.7189
#   RMSE: 4539.8598
#
# Alpha: 300
#   R^2: 0.7179
#   RMSE: 4548.0935
#
# Alpha: 500
#   R^2: 0.7157
#   RMSE: 4566.2031
#
# Alpha: 1000
#   R^2: 0.6996
#   RMSE: 4693.6665
#
# Best Alpha based on RMSE: 200
# Best R^2: 0.7189
# Best RMSE: 4539.8598
#
# Model Coefficients for the Best Alpha:
#   Year: 8730.2168
#   Horsepower (hp): 3471.9758
#   Curb Weight (lbs): -0.0000
#   Combined MPG: 0.0000
#   Fuel Capacity (gallons): 16.8687
#   Age: -135.8829
#   Topic_0_Weighted: -0.0000
#   Topic_2_Weighted: -73.3415
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 60.6928
#   Topic_5_Weighted: -0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#   Car Brand_alfa-romeo: -169.6145
#   Car Brand_audi: -0.0000
#   Car Brand_bmw: -0.0000
#   Car Brand_buick: -71.4522
#   Car Brand_cadillac: -0.0000
#   Car Brand_chevrolet: 572.6347
#   Car Brand_chrysler: -0.0000
#   Car Brand_dodge: 17.9530
#   Car Brand_fiat: -93.4372
#   Car Brand_ford: 0.0000
#   Car Brand_genesis: 0.0000
#   Car Brand_gmc: 405.1380
#   Car Brand_honda: 0.0000
#   Car Brand_hyundai: -65.8096
#   Car Brand_infiniti: -243.3627
#   Car Brand_jaguar: -256.6293
#   Car Brand_jeep: 151.9540
#   Car Brand_kia: -68.3007
#   Car Brand_land-rover: -174.6323
#   Car Brand_lexus: 667.3681
#   Car Brand_mazda: 261.9097
#   Car Brand_mercedes-benz: 0.0000
#   Car Brand_mini: 163.8353
#   Car Brand_mitsubishi: -0.0000
#   Car Brand_nissan: -81.5244
#   Car Brand_porsche: 83.6801
#   Car Brand_subaru: -0.0000
#   Car Brand_tesla: -0.0000
#   Car Brand_toyota: 1007.9814
#   Car Brand_volkswagen: -0.0000
#   Car Brand_volvo: 0.0000
#   Drivetrain_4WD: 836.3662
#   Drivetrain_AWD: -87.4739
#   Drivetrain_FWD: -917.1651
#   Drivetrain_RWD: 431.9415
#   Vehicle Class_compact-suv: -283.9166
#   Vehicle Class_electric-car: 703.5313
#   Vehicle Class_electric-suv: 722.4590
#   Vehicle Class_full-size: -344.5007
#   Vehicle Class_full-size-truck: -269.7872
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -264.4032
#   Vehicle Class_luxury-hybrid-suv: 350.2253
#   Vehicle Class_mid-size: 304.9458
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 61.5050
#   Vehicle Class_minivan: 0.0000
#
# Intercept: 16689.6011
# /Users/TimmyRen/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.016e+08, tolerance: 3.792e+06
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# #### Functional and Experiental Aggregated Ridge

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6423
#   RMSE: 5121.7153
#
# Alpha: 1.0
#   R^2: 0.6467
#   RMSE: 5089.9815
#
# Alpha: 10.0
#   R^2: 0.6768
#   RMSE: 4868.0279
#
# Alpha: 100
#   R^2: 0.7497
#   RMSE: 4284.0240
#
# Alpha: 200
#   R^2: 0.7496
#   RMSE: 4285.2552
#
# Alpha: 300
#   R^2: 0.7290
#   RMSE: 4457.7894
#
# Alpha: 500
#   R^2: 0.6702
#   RMSE: 4917.4849
#
# Alpha: 1000
#   R^2: 0.5272
#   RMSE: 5888.2697
#
# Best Alpha based on RMSE: 100
# Best R^2: 0.7497
# Best RMSE: 4284.0240
#
# Model Coefficients for the Best Alpha:
#   Year: 8066.8338
#   Horsepower (hp): 3543.5767
#   Curb Weight (lbs): 0.0000
#   Combined MPG: 25.4894
#   Fuel Capacity (gallons): 0.0000
#   Age: -18.1410
#   Topic_0_Weighted: -0.0000
#   Topic_2_Weighted: -0.0000
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: -0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#   Car Brand_alfa-romeo: -0.0000
#   Car Brand_audi: -0.0000
#   Car Brand_bmw: -0.0000
#   Car Brand_buick: -0.0000
#   Car Brand_cadillac: -0.0000
#   Car Brand_chevrolet: 0.0000
#   Car Brand_chrysler: -0.0000
#   Car Brand_dodge: 0.0000
#   Car Brand_fiat: -0.0000
#   Car Brand_ford: -0.0000
#   Car Brand_genesis: 0.0000
#   Car Brand_gmc: 0.0000
#   Car Brand_honda: -0.0000
#   Car Brand_hyundai: -0.0000
#   Car Brand_infiniti: -0.0000
#   Car Brand_jaguar: -0.0000
#   Car Brand_jeep: 0.0000
#   Car Brand_kia: -0.0000
#   Car Brand_land-rover: -0.0000
#   Car Brand_lexus: 0.0000
#   Car Brand_mazda: 0.0000
#   Car Brand_mercedes-benz: 0.0000
#   Car Brand_mini: 0.0000
#   Car Brand_mitsubishi: -0.0000
#   Car Brand_nissan: -0.0000
#   Car Brand_porsche: 0.0000
#   Car Brand_subaru: -0.0000
#   Car Brand_tesla: 0.0000
#   Car Brand_toyota: 0.0000
#   Car Brand_volkswagen: -0.0000
#   Car Brand_volvo: -0.0000
#   Drivetrain_4WD: 293.3781
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 96.2926
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#
# Intercept: 16757.9875

# %% [markdown]
# # All Feature Model

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'Car Brand', 'Car Model', 'Year', 'Review',
#        'Rating', 'Value Rating', 'Performance Rating', 'Quality Rating',
#        'Comfort Rating', 'Reliability Rating', 'Styling Rating',
#        'Vehicle Class', 'Model Full Name', 'Horsepower (hp)',
#        'Curb Weight (lbs)', 'Combined MPG', 'Fuel Capacity (gallons)',
#        'Drivetrain', 'Recommended Fuel', 'Average MSRP Price ($)',
#        'Average KBB Fair Price ($)', 'Review_Topics', 'Topic_0',
#        'Topic_1', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_6',
#        'Topic_7', 'Topic_8', 'Topic_9', 'Sentiment Score',
#        'Depreciated Value', 'Sentiment Bin', 'Weighted Sentiment Score',
#        'Topic_0_Weighted', 'Topic_2_Weighted', 'Topic_3_Weighted',
#        'Topic_4_Weighted', 'Topic_5_Weighted', 'Topic_7_Weighted',
#        'Topic_8_Weighted', 'Topic_9_Weighted', 'Age'], dtype=object)

# %% [markdown]
# ## Results

# %%
results_df = pd.DataFrame(results_list).round({"R^2": 2, "RMSE": 2})
print("\nResults Summary:")
results_df
# Out:
# Results Summary:
#                             Division Title         Model Type  Best Alpha  \
# 0                  Functional Unaggregated  Linear Regression         NaN
# 1                  Functional Unaggregated              Lasso         0.1
# 2                  Functional Unaggregated              Ridge         0.1
# 3                    Functional Aggregated  Linear Regression         NaN
# 4                    Functional Aggregated              Lasso       100.0
# 5                    Functional Aggregated              Ridge      1000.0
# 6   Functional & Experiential Unaggregated  Linear Regression         NaN
# 7   Functional & Experiential Unaggregated              Lasso         0.1
# 8   Functional & Experiential Unaggregated              Ridge         0.1
# 9     Functional & Experiential Aggregated  Linear Regression         NaN
# 10    Functional & Experiential Aggregated              Lasso       200.0
# 11    Functional & Experiential Aggregated              Ridge       100.0
#
#      R^2     RMSE
# 0   0.78  4123.80
# 1   0.78  4123.79
# 2   0.78  4123.80
# 3   0.64  5149.06
# 4   0.66  4981.95
# 5   0.67  4953.31
# 6   0.91  2610.30
# 7   0.91  2611.29
# 8   0.91  2611.16
# 9   0.64  5125.43
# 10  0.72  4539.86
# 11  0.75  4284.02

# %%
car_data_encoded
# Out:
#        Unnamed: 0     id      Car Brand Car Model  Year  \
# 0               0      0          honda    accord  2010
# 1               1      1          honda    accord  2010
# 2               2      2          honda    accord  2010
# 3               3      3          honda    accord  2010
# 4               4      4          honda    accord  2010
# ...           ...    ...            ...       ...   ...
# 15255       15255  15261  mercedes-benz   a-class  2019
# 15256       15256  15262  mercedes-benz   a-class  2019
# 15257       15257  15263  mercedes-benz   a-class  2019
# 15258       15258  15264  mercedes-benz   a-class  2019
# 15259       15259  15265  mercedes-benz   a-class  2019
#
#                                                   Review  Rating  \
# 0      I've driven my LX over 13 years and the only t...     5.0
# 1      I have this car for 10 years have given me no ...     5.0
# 2      My 2012 Honda Accord is great, It handles grea...     5.0
# 3      My sibling has this car. I may be a computer p...     5.0
# 4      I've had this car for 7 years, it's dependable...     5.0
# ...                                                  ...     ...
# 15255  I just traded in my 2016 Mercedes GLA 250 for ...     5.0
# 15256  Great car, fun to drive and very quick. I had ...     5.0
# 15257  Awesome car. Really smooth drive satisfying lo...     5.0
# 15258  I got this car just because I have always boug...     1.0
# 15259                         I love this car! Thank You     5.0
#
#        Value Rating  Performance Rating  Quality Rating  ...  \
# 0               5.0                 5.0             5.0  ...
# 1               5.0                 5.0             5.0  ...
# 2               4.0                 5.0             5.0  ...
# 3               5.0                 5.0             5.0  ...
# 4               5.0                 5.0             5.0  ...
# ...             ...                 ...             ...  ...
# 15255           5.0                 5.0             5.0  ...
# 15256           4.5                 4.0             5.0  ...
# 15257           5.0                 3.0             5.0  ...
# 15258           2.0                 1.0             2.0  ...
# 15259           5.0                 5.0             5.0  ...
#
#        Vehicle Class_electric-suv  Vehicle Class_full-size  \
# 0                           False                    False
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                           False                    False
# ...                           ...                      ...
# 15255                       False                    False
# 15256                       False                    False
# 15257                       False                    False
# 15258                       False                    False
# 15259                       False                    False
#
#        Vehicle Class_full-size-truck  Vehicle Class_hybrid-car  \
# 0                              False                     False
# 1                              False                     False
# 2                              False                     False
# 3                              False                     False
# 4                              False                     False
# ...                              ...                       ...
# 15255                          False                     False
# 15256                          False                     False
# 15257                          False                     False
# 15258                          False                     False
# 15259                          False                     False
#
#        Vehicle Class_hybrid-suv  Vehicle Class_luxury-hybrid-suv  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ...                         ...                              ...
# 15255                     False                            False
# 15256                     False                            False
# 15257                     False                            False
# 15258                     False                            False
# 15259                     False                            False
#
#        Vehicle Class_mid-size Vehicle Class_mid-size-suv  \
# 0                        True                      False
# 1                        True                      False
# 2                        True                      False
# 3                        True                      False
# 4                        True                      False
# ...                       ...                        ...
# 15255                    True                      False
# 15256                    True                      False
# 15257                    True                      False
# 15258                    True                      False
# 15259                    True                      False
#
#        Vehicle Class_mid-size-truck  Vehicle Class_minivan
# 0                             False                  False
# 1                             False                  False
# 2                             False                  False
# 3                             False                  False
# 4                             False                  False
# ...                             ...                    ...
# 15255                         False                  False
# 15256                         False                  False
# 15257                         False                  False
# 15258                         False                  False
# 15259                         False                  False
#
# [15260 rows x 226 columns]
