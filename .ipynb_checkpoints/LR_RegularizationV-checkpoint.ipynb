# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
#from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
current_year = datetime.now().year
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nehab\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = pd.read_csv('final_cleaned.csv', index_col = False)
car_data_encoded = pd.get_dummies(df, columns=['Model Full Name', 'Drivetrain', 'Vehicle Class'], drop_first=True)

# %%
results_list = []

# %% [markdown]
# # Functional

# %%
functional_features = [
    'Horsepower (hp)', 'Curb Weight (lbs)', 'Combined MPG', 'Fuel Capacity (gallons)', 'Age'
] + [col for col in car_data_encoded.columns if col.startswith('Drivetrain_')]

vehicle_class_features = [col for col in car_data_encoded.columns if col.startswith('Vehicle Class_')]

functional_features += vehicle_class_features

features = functional_features

# %% [markdown]
# ### Functional Unaggregated

# %%
#unaggregated

y_price = car_data_encoded['Average KBB Fair Price ($)']
X = car_data_encoded[features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional Unaggregated"
model_type = "Linear Regression"

# Append the results to the list as a dictionary
results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.7800
#
# RMSE: 4123.7972
#
# Model Coefficients:
#   Horsepower (hp): 47.0750
#   Curb Weight (lbs): -2.1557
#   Combined MPG: -7.0564
#   Fuel Capacity (gallons): 185.2962
#   Age: -1750.4193
#   Drivetrain_4WD: 4185.8522
#   Drivetrain_AWD: -854.1422
#   Drivetrain_FWD: -2477.9903
#   Drivetrain_RWD: 578.9442
#   Vehicle Class_compact-suv: -935.3245
#   Vehicle Class_electric-car: 3351.7157
#   Vehicle Class_electric-suv: 4715.5914
#   Vehicle Class_full-size: -1152.8683
#   Vehicle Class_full-size-truck: -1012.8441
#   Vehicle Class_hybrid-car: 559.6436
#   Vehicle Class_hybrid-suv: -3184.6762
#   Vehicle Class_luxury-hybrid-suv: 3100.9584
#   Vehicle Class_mid-size: 1234.1979
#   Vehicle Class_mid-size-suv: 967.6763
#   Vehicle Class_mid-size-truck: 2313.9656
#   Vehicle Class_minivan: 1583.3936
#
# Intercept: 25117.5797

# %% [markdown]
# #### Functional Unaggregated Lasso

# %%
y_price = car_data_encoded['Average KBB Fair Price ($)']
X = car_data_encoded[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Unaggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.7800
#   RMSE: 4123.7895
#
# Alpha: 1.0
#   R^2: 0.7800
#   RMSE: 4123.7285
#
# Alpha: 10.0
#   R^2: 0.7800
#   RMSE: 4123.9118
#
# Alpha: 100
#   R^2: 0.7746
#   RMSE: 4174.3339
#
# Alpha: 200
#   R^2: 0.7663
#   RMSE: 4250.4461
#
# Alpha: 300
#   R^2: 0.7549
#   RMSE: 4352.8012
#
# Alpha: 500
#   R^2: 0.7404
#   RMSE: 4479.5823
#
# Alpha: 1000
#   R^2: 0.7124
#   RMSE: 4715.1785
#
# Best Alpha based on RMSE: 1.0
# Best R^2: 0.7800
# Best RMSE: 4123.7285
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 3238.6874
#   Curb Weight (lbs): -1622.0267
#   Combined MPG: -93.9673
#   Fuel Capacity (gallons): 805.3588
#   Age: -6890.2770
#   Drivetrain_4WD: 1338.3041
#   Drivetrain_AWD: -341.3202
#   Drivetrain_FWD: -1205.0900
#   Drivetrain_RWD: 197.7946
#   Vehicle Class_compact-suv: -369.6838
#   Vehicle Class_electric-car: 460.0448
#   Vehicle Class_electric-suv: 507.4761
#   Vehicle Class_full-size: -387.8504
#   Vehicle Class_full-size-truck: -215.2602
#   Vehicle Class_hybrid-car: 101.2008
#   Vehicle Class_hybrid-suv: -434.5650
#   Vehicle Class_luxury-hybrid-suv: 466.6954
#   Vehicle Class_mid-size: 500.9340
#   Vehicle Class_mid-size-suv: 342.4660
#   Vehicle Class_mid-size-truck: 480.6673
#   Vehicle Class_minivan: 292.1965
#
# Intercept: 13738.4505

# %% [markdown]
# #### Functional Unaggregated Ridge

# %%
y_price = car_data_encoded['Average KBB Fair Price ($)']
X = car_data_encoded[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)


alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    Ridge_model = Ridge(alpha=alpha)
    Ridge_model.fit(X_train, y_train)
    y_pred = Ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Unaggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.7800
#   RMSE: 4123.7960
#
# Alpha: 1.0
#   R^2: 0.7800
#   RMSE: 4123.7857
#
# Alpha: 10.0
#   R^2: 0.7800
#   RMSE: 4123.6896
#
# Alpha: 100
#   R^2: 0.7801
#   RMSE: 4123.4380
#
# Alpha: 200
#   R^2: 0.7799
#   RMSE: 4124.5054
#
# Alpha: 300
#   R^2: 0.7797
#   RMSE: 4126.7869
#
# Alpha: 500
#   R^2: 0.7789
#   RMSE: 4134.3816
#
# Alpha: 1000
#   R^2: 0.7754
#   RMSE: 4166.5322
#
# Best Alpha based on RMSE: 100
# Best R^2: 0.7801
# Best RMSE: 4123.4380
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 2357.4999
#   Curb Weight (lbs): 0.0000
#   Combined MPG: 0.0000
#   Fuel Capacity (gallons): 0.0000
#   Age: -5871.9075
#   Drivetrain_4WD: 223.6079
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -159.4827
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 0.0000
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#
# Intercept: 13731.4896

# %% [markdown]
# ### Functional Aggregated

# %%
#aggregated
aggregated_data = df.groupby(['Model Full Name', 'Year']).agg({
    'Horsepower (hp)': 'mean',
    'Curb Weight (lbs)': 'mean',
    'Combined MPG': 'mean',
    'Fuel Capacity (gallons)': 'mean',
    'Age': 'mean',
    'Average KBB Fair Price ($)': 'mean',
    'Vehicle Class': 'first',
    'Car Brand': 'first',
    'Car Model': 'first',
    'Drivetrain': 'first'
}).reset_index()

car_data_encoded_agg = pd.get_dummies(aggregated_data, columns=['Car Brand', 'Car Model', 'Drivetrain', 'Vehicle Class'], drop_first=True)

y_price = car_data_encoded_agg['Average KBB Fair Price ($)']
X = car_data_encoded_agg[functional_features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print("Model Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional Aggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.6385
#
# RMSE: 5149.0639
# Model Coefficients:
#   Horsepower (hp): 45.7558
#   Curb Weight (lbs): -0.8214
#   Combined MPG: 11.3679
#   Fuel Capacity (gallons): 190.6051
#   Age: -2057.9485
#   Drivetrain_4WD: 3148.6491
#   Drivetrain_AWD: -2380.2253
#   Drivetrain_FWD: -3474.6153
#   Drivetrain_RWD: -453.2229
#   Vehicle Class_compact-suv: -229.2713
#   Vehicle Class_electric-car: 6718.1756
#   Vehicle Class_electric-suv: 4723.7591
#   Vehicle Class_full-size: -673.6605
#   Vehicle Class_full-size-truck: -3125.2154
#   Vehicle Class_hybrid-car: 1138.7061
#   Vehicle Class_hybrid-suv: -2870.1388
#   Vehicle Class_luxury-hybrid-suv: 5894.6217
#   Vehicle Class_mid-size: 2429.0707
#   Vehicle Class_mid-size-suv: 1234.6862
#   Vehicle Class_mid-size-truck: 1678.9081
#   Vehicle Class_minivan: 2773.7374
#
# Intercept: 23573.2972

# %% [markdown]
# #### Functional Aggregated Lasso

# %%
y_price = car_data_encoded_agg['Average KBB Fair Price ($)']
X = car_data_encoded_agg[functional_features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Aggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6385
#   RMSE: 5148.8350
#
# Alpha: 1.0
#   R^2: 0.6388
#   RMSE: 5146.7798
#
# Alpha: 10.0
#   R^2: 0.6416
#   RMSE: 5126.6812
#
# Alpha: 100
#   R^2: 0.6641
#   RMSE: 4962.9833
#
# Alpha: 200
#   R^2: 0.6814
#   RMSE: 4833.7407
#
# Alpha: 300
#   R^2: 0.6900
#   RMSE: 4768.1244
#
# Alpha: 500
#   R^2: 0.6955
#   RMSE: 4725.7224
#
# Alpha: 1000
#   R^2: 0.6996
#   RMSE: 4693.6620
#
# Best Alpha based on RMSE: 1000
# Best R^2: 0.6996
# Best RMSE: 4693.6620
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 3543.5295
#   Curb Weight (lbs): 0.0000
#   Combined MPG: 25.3977
#   Fuel Capacity (gallons): 0.0000
#   Age: -8084.9927
#   Drivetrain_4WD: 293.3834
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 96.3568
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#
# Intercept: 16757.9873

# %% [markdown]
# #### Functional Aggregated Ridge

# %%
y_price = car_data_encoded_agg['Average KBB Fair Price ($)']
X = car_data_encoded_agg[functional_features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Aggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6388
#   RMSE: 5146.6787
#
# Alpha: 1.0
#   R^2: 0.6417
#   RMSE: 5125.7161
#
# Alpha: 10.0
#   R^2: 0.6652
#   RMSE: 4954.7213
#
# Alpha: 100
#   R^2: 0.7084
#   RMSE: 4624.1261
#
# Alpha: 200
#   R^2: 0.6595
#   RMSE: 4997.2424
#
# Alpha: 300
#   R^2: 0.5992
#   RMSE: 5421.3697
#
# Alpha: 500
#   R^2: 0.4933
#   RMSE: 6095.5715
#
# Alpha: 1000
#   R^2: 0.3239
#   RMSE: 7041.4219
#
# Best Alpha based on RMSE: 100
# Best R^2: 0.7084
# Best RMSE: 4624.1261
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 3543.5295
#   Curb Weight (lbs): 0.0000
#   Combined MPG: 25.3977
#   Fuel Capacity (gallons): 0.0000
#   Age: -8084.9927
#   Drivetrain_4WD: 293.3834
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 96.3568
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#
# Intercept: 16757.9873

# %% [markdown]
# # Functional and Experiential

# %% [markdown]
# ### Functional and Experiental Unaggregated

# %%
selected_topics = ['Topic_0', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_7', 'Topic_8', 'Topic_9']

for topic in selected_topics:
    car_data_encoded[f'{topic}_Weighted'] = car_data_encoded[topic] * car_data_encoded['Sentiment Score']

weighted_topic_features = [f'{topic}_Weighted' for topic in selected_topics]
features = functional_features + weighted_topic_features + [col for col in car_data_encoded.columns if col.startswith('Model Full Name_')]

X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.9119
#
# RMSE: 2610.2972
#
# Model Coefficients:
#   Horsepower (hp): 5.6205
#   Curb Weight (lbs): -4.1024
#   Combined MPG: -39.8881
#   Fuel Capacity (gallons): -70.7159
#   Age: -1818.9150
#   Drivetrain_4WD: 408.1054
#   Drivetrain_AWD: -1565.4764
#   Drivetrain_FWD: -4207.0753
#   Drivetrain_RWD: -2462.8245
#   Vehicle Class_compact-suv: 3181807109257.7056
#   Vehicle Class_electric-car: -715044531176.8585
#   Vehicle Class_electric-suv: 7210183252136.6016
#   Vehicle Class_full-size: 2926079233543.4614
#   Vehicle Class_full-size-truck: -1887711719589.7280
#   Vehicle Class_hybrid-car: 11643799989635.1094
#   Vehicle Class_hybrid-suv: -779796829386.9764
#   Vehicle Class_luxury-hybrid-suv: 340421695847.9497
#   Vehicle Class_mid-size: 49960159987.5021
#   Vehicle Class_mid-size-suv: 2592475688014.8296
#   Vehicle Class_mid-size-truck: 1182986181354.1604
#   Vehicle Class_minivan: 5435048661774.5166
#   Topic_0_Weighted: -7599.1789
#   Topic_2_Weighted: -1092.6203
#   Topic_3_Weighted: 5602.0576
#   Topic_4_Weighted: -1684.8179
#   Topic_5_Weighted: -3175.9684
#   Topic_7_Weighted: -639.9902
#   Topic_8_Weighted: 716.7104
#   Topic_9_Weighted: -86.9965
#   Model Full Name_Acura Tlx: 2542515527225.1641
#   Model Full Name_Alfa-romeo Giulia: 2542515527329.2524
#   Model Full Name_Alfa-romeo Stelvio: -2780.3993
#   Model Full Name_Audi A4: 2542515527684.7783
#   Model Full Name_Audi A6: 2542515528328.5537
#   Model Full Name_Audi Q3: -589331424841.3795
#   Model Full Name_Audi Q5: 2252053992037.4707
#   Model Full Name_Audi Q7: 2592475691596.3320
#   Model Full Name_Bmw 3-series: 2542515527072.3125
#   Model Full Name_Bmw 5-series: -333603545474.8263
#   Model Full Name_Bmw X3: -589331422165.7705
#   Model Full Name_Bmw X5: 5803.1619
#   Model Full Name_Buick Enclave: 2592475691107.8716
#   Model Full Name_Buick Encore: -589331428334.2793
#   Model Full Name_Buick Encore-gx: -589331429100.4629
#   Model Full Name_Cadillac Ct4: 2542515529886.0776
#   Model Full Name_Cadillac Xt5: 1243.2863
#   Model Full Name_Chevrolet Blazer: -451.8249
#   Model Full Name_Chevrolet Camaro: 2542515529364.3340
#   Model Full Name_Chevrolet Colorado: 1409489503199.7458
#   Model Full Name_Chevrolet Corvette: 2542515546216.8472
#   Model Full Name_Chevrolet Equinox: -589331424134.6740
#   Model Full Name_Chevrolet Impala: -333603545483.3817
#   Model Full Name_Chevrolet Malibu: 2542515524450.6821
#   Model Full Name_Chevrolet Silverado-1500: 4480187406297.4746
#   Model Full Name_Chevrolet Ss: -333603532616.6632
#   Model Full Name_Chevrolet Suburban: 2592475698256.9507
#   Model Full Name_Chevrolet Tahoe: 2592475700584.0098
#   Model Full Name_Chevrolet Trailblazer: -589331425174.9506
#   Model Full Name_Chevrolet Traverse: 2592475688645.4194
#   Model Full Name_Chevrolet Trax: -589331432087.2357
#   Model Full Name_Chrysler 200: 2542515523846.4565
#   Model Full Name_Chrysler 300: -333603544245.2687
#   Model Full Name_Chrysler Pacifica: -2842572976291.8545
#   Model Full Name_Dodge Challenger: 2542515532984.0527
#   Model Full Name_Dodge Charger: -333603544492.8506
#   Model Full Name_Dodge Durango: 2592475690370.6646
#   Model Full Name_Fiat 500x: -589331432214.7332
#   Model Full Name_Ford Bronco: 13813.7667
#   Model Full Name_Ford Bronco-sport: -589331427246.3021
#   Model Full Name_Ford Escape: -589331428573.0779
#   Model Full Name_Ford Expedition: 2592475693876.7222
#   Model Full Name_Ford Explorer: 3372272516057.5151
#   Model Full Name_Ford F150: 4480187407144.2275
#   Model Full Name_Ford Focus: 3307520216306.5039
#   Model Full Name_Ford Fusion: 2542515525676.5518
#   Model Full Name_Ford Maverick: 1409489505601.9905
#   Model Full Name_Ford Mustang: 2542515533271.0220
#   Model Full Name_Ford Ranger: 1409489502990.1387
#   Model Full Name_Ford Taurus: -333603542367.1686
#   Model Full Name_Genesis G70: 2542515525421.1445
#   Model Full Name_Genesis G80: -333603543962.2161
#   Model Full Name_Genesis Gv80: 11347.8445
#   Model Full Name_Gmc Acadia: 209.5765
#   Model Full Name_Gmc Canyon: 1409489504500.5037
#   Model Full Name_Gmc Hummer-ev: -4617707521314.0791
#   Model Full Name_Gmc Sierra-1500: 4480187410107.6260
#   Model Full Name_Gmc Terrain: -589331424932.6785
#   Model Full Name_Gmc Yukon-xl: -333603534207.4288
#   Model Full Name_Honda Accord: 2542515526984.3501
#   Model Full Name_Honda Insight: -9051324306580.9805
#   Model Full Name_Honda Odyssey: -2842572970198.2271
#   Model Full Name_Honda Passport: -533.2433
#   Model Full Name_Honda Pilot: 146.4313
#   Model Full Name_Honda Ridgeline: 1409489510048.7783
#   Model Full Name_Hyundai Azera: -333603546845.5394
#   Model Full Name_Hyundai Elantra: -9051324309229.3730
#   Model Full Name_Hyundai Genesis: -333603547305.7520
#   Model Full Name_Hyundai Ioniq-5: -4617707563873.6348
#   Model Full Name_Hyundai Ioniq-6: 3307520239206.4590
#   Model Full Name_Hyundai Palisade: 2217.3329
#   Model Full Name_Hyundai Sonata: 2542515524762.0459
#   Model Full Name_Hyundai Tucson: -589331428151.6582
#   Model Full Name_Hyundai Venue: -589331433092.6857
#   Model Full Name_Infiniti Q50: 2542515526186.1655
#   Model Full Name_Infiniti Qx60: 2252053991881.6729
#   Model Full Name_Infiniti Qx80: -333603540626.4117
#   Model Full Name_Jaguar E-pace: -589331423943.9216
#   Model Full Name_Jaguar F-pace: -1744.6685
#   Model Full Name_Jaguar I-pace: -4617707557775.0527
#   Model Full Name_Jeep Cherokee: -589331430116.6296
#   Model Full Name_Jeep Compass: -589331429327.8743
#   Model Full Name_Jeep Gladiator: 1409489518221.0947
#   Model Full Name_Jeep Grand-wagoneer: 2592475719029.1162
#   Model Full Name_Jeep Renegade: -589331433371.1863
#   Model Full Name_Jeep Wagoneer: 2592475701882.0249
#   Model Full Name_Jeep Wrangler: -589331419720.3976
#   Model Full Name_Kia Cadenza: -333603549315.9047
#   Model Full Name_Kia Carnival: -2842572965702.2607
#   Model Full Name_Kia Ev6: -4617707559483.1299
#   Model Full Name_Kia K5: 2542515522759.4126
#   Model Full Name_Kia K900: -333603546748.1793
#   Model Full Name_Kia Optima: 2542515524079.1558
#   Model Full Name_Kia Sedona: -2842572972981.0205
#   Model Full Name_Kia Seltos: -589331433640.8964
#   Model Full Name_Kia Sorento: -222.4860
#   Model Full Name_Kia Sportage: -589331427450.8474
#   Model Full Name_Kia Stinger: -333603547808.7716
#   Model Full Name_Kia Telluride: 2764.7861
#   Model Full Name_Land-rover Discovery: 2592475681846.9438
#   Model Full Name_Land-rover Range-rover-evoque: -589331423253.5483
#   Model Full Name_Lexus Es: 2542515531446.8457
#   Model Full Name_Lexus Gx: 2592475700154.9150
#   Model Full Name_Lexus Nx: 2252053995268.8696
#   Model Full Name_Lexus Rx: 2252054000105.8574
#   Model Full Name_Lexus Ux: 2252053989472.0708
#   Model Full Name_Mazda Cx-5: -589331424635.2178
#   Model Full Name_Mazda Cx-50: -589331418099.7065
#   Model Full Name_Mazda Cx-9: 740.4660
#   Model Full Name_Mazda Mazda6: 2542515526134.8745
#   Model Full Name_Mazda Mx-5-miata: 2542515522569.1138
#   Model Full Name_Mercedes-benz A-class: 2542515525824.1401
#   Model Full Name_Mercedes-benz C-class: 2542515530582.9292
#   Model Full Name_Mercedes-benz E-class: -333603543955.9551
#   Model Full Name_Mercedes-benz Glc: -589331424111.2355
#   Model Full Name_Mercedes-benz Gle: 9676.9411
#   Model Full Name_Mini Countryman: -589331424971.3337
#   Model Full Name_Mitsubishi Outlander: -589331428186.8802
#   Model Full Name_Nissan Altima: 2542515523657.9580
#   Model Full Name_Nissan Ariya: -4617707538098.3125
#   Model Full Name_Nissan Armada: 2592475690653.2085
#   Model Full Name_Nissan Frontier: 1409489505560.2695
#   Model Full Name_Nissan Kicks: -589331434397.5927
#   Model Full Name_Nissan Leaf: 3307520217938.9961
#   Model Full Name_Nissan Maxima: -333603548663.9825
#   Model Full Name_Nissan Murano: -3322.8572
#   Model Full Name_Nissan Pathfinder: -2584.9254
#   Model Full Name_Nissan Quest: -2842572972784.3145
#   Model Full Name_Nissan Rogue: -589331425984.9272
#   Model Full Name_Nissan Titan: 4480187411129.4287
#   Model Full Name_Porsche Cayenne: 9903.1211
#   Model Full Name_Porsche Macan: -589331419902.7996
#   Model Full Name_Subaru Ascent: -1671.4986
#   Model Full Name_Subaru Brz: 2542515521405.6587
#   Model Full Name_Subaru Crosstrek: 3372272510148.4307
#   Model Full Name_Subaru Forester: -589331426549.5714
#   Model Full Name_Subaru Legacy: 2542515523169.4976
#   Model Full Name_Subaru Outback: -4434.8313
#   Model Full Name_Subaru Solterra: -4617707543180.7539
#   Model Full Name_Tesla Model-3: 3307520224004.1172
#   Model Full Name_Tesla Model-s: 3307520234239.8687
#   Model Full Name_Tesla Model-x: -4617707555949.2852
#   Model Full Name_Tesla Model-y: -4617707555732.9619
#   Model Full Name_Toyota 4runner: 11189.8445
#   Model Full Name_Toyota Avalon: -333603544334.1215
#   Model Full Name_Toyota Camry: 2542515527346.8540
#   Model Full Name_Toyota Corolla: 2542515523057.2285
#   Model Full Name_Toyota Crown: 2542515542165.3662
#   Model Full Name_Toyota Highlander: 5131.3234
#   Model Full Name_Toyota Land-cruiser: -333603521285.1392
#   Model Full Name_Toyota Prius: -9051324301793.0840
#   Model Full Name_Toyota Rav4: -589331422226.0044
#   Model Full Name_Toyota Sienna: -2842572964587.0117
#   Model Full Name_Toyota Tacoma: 1409489507450.7742
#   Model Full Name_Toyota Tundra: 4480187417113.6387
#   Model Full Name_Toyota Venza: 3370.0554
#   Model Full Name_Volkswagen Arteon: -333603548782.7396
#   Model Full Name_Volkswagen Atlas: 2592475689192.6968
#   Model Full Name_Volkswagen Golf-gti: 2542515521926.9365
#   Model Full Name_Volkswagen Id-4: -4617707560864.2373
#   Model Full Name_Volkswagen Jetta: -9051324307019.3906
#   Model Full Name_Volkswagen Passat: 2542515524522.9546
#   Model Full Name_Volkswagen Tiguan: -589331423760.4637
#   Model Full Name_Volvo Xc40: -589331423932.7123
#   Model Full Name_Volvo Xc60: 738.6872
#   Model Full Name_Volvo Xc90: 2592475689483.0513
#
# Intercept: -2592475637227.2358

# %% [markdown]
# #### Functional and Experiental Unaggregated Lasso

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# C:\Users\nehab\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.742e+09, tolerance: 1.017e+08
#   model = cd_fast.enet_coordinate_descent(
# Alpha: 0.1
#   R^2: 0.9119
#   RMSE: 2610.3225
#
# Alpha: 1.0
#   R^2: 0.9118
#   RMSE: 2610.8747
#
# Alpha: 10.0
#   R^2: 0.9107
#   RMSE: 2626.7807
#
# Alpha: 100
#   R^2: 0.8844
#   RMSE: 2989.6112
#
# Alpha: 200
#   R^2: 0.8487
#   RMSE: 3420.3871
#
# Alpha: 300
#   R^2: 0.8170
#   RMSE: 3761.3364
#
# Alpha: 500
#   R^2: 0.7720
#   RMSE: 4197.8319
#
# Alpha: 1000
#   R^2: 0.7293
#   RMSE: 4574.4934
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.9119
# Best RMSE: 2610.3225
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 389.8549
#   Curb Weight (lbs): -3090.7731
#   Combined MPG: -580.8696
#   Fuel Capacity (gallons): -301.9682
#   Age: -7163.7914
#   Drivetrain_4WD: 131.2370
#   Drivetrain_AWD: -632.5114
#   Drivetrain_FWD: -2054.6870
#   Drivetrain_RWD: -827.5845
#   Vehicle Class_compact-suv: -2283.6561
#   Vehicle Class_electric-car: 79.3001
#   Vehicle Class_electric-suv: 707.1642
#   Vehicle Class_full-size: 857.7148
#   Vehicle Class_full-size-truck: 304.0813
#   Vehicle Class_hybrid-car: -1156.4370
#   Vehicle Class_hybrid-suv: -517.4764
#   Vehicle Class_luxury-hybrid-suv: 215.4117
#   Vehicle Class_mid-size: -852.1838
#   Vehicle Class_mid-size-suv: -367.1674
#   Vehicle Class_mid-size-truck: -313.9692
#   Vehicle Class_minivan: 316.6921
#   Topic_0_Weighted: -119.3538
#   Topic_2_Weighted: -18.2167
#   Topic_3_Weighted: 94.7667
#   Topic_4_Weighted: -31.7876
#   Topic_5_Weighted: -55.3067
#   Topic_7_Weighted: -11.4531
#   Topic_8_Weighted: 12.3337
#   Topic_9_Weighted: -1.6175
#   Model Full Name_Acura Tlx: 16.7088
#   Model Full Name_Alfa-romeo Giulia: 20.0087
#   Model Full Name_Alfa-romeo Stelvio: -167.0389
#   Model Full Name_Audi A4: 55.1390
#   Model Full Name_Audi A6: 118.8722
#   Model Full Name_Audi Q3: 71.5027
#   Model Full Name_Audi Q5: -206.7575
#   Model Full Name_Audi Q7: 214.4611
#   Model Full Name_Bmw 3-series: 7.6954
#   Model Full Name_Bmw 5-series: -327.3537
#   Model Full Name_Bmw X3: 409.4875
#   Model Full Name_Bmw X5: 578.8577
#   Model Full Name_Buick Enclave: 162.6064
#   Model Full Name_Buick Encore: -131.7731
#   Model Full Name_Buick Encore-gx: -122.3663
#   Model Full Name_Cadillac Ct4: 77.3988
#   Model Full Name_Cadillac Xt5: 72.2324
#   Model Full Name_Chevrolet Blazer: -27.4314
#   Model Full Name_Chevrolet Camaro: 196.8422
#   Model Full Name_Chevrolet Colorado: -250.6513
#   Model Full Name_Chevrolet Corvette: 1926.1706
#   Model Full Name_Chevrolet Equinox: 169.7367
#   Model Full Name_Chevrolet Impala: -214.2427
#   Model Full Name_Chevrolet Malibu: -262.3604
#   Model Full Name_Chevrolet Silverado-1500: -391.7960
#   Model Full Name_Chevrolet Ss: 469.3995
#   Model Full Name_Chevrolet Suburban: 710.9077
#   Model Full Name_Chevrolet Tahoe: 1132.5794
#   Model Full Name_Chevrolet Trailblazer: 43.8488
#   Model Full Name_Chevrolet Traverse: -34.2265
#   Model Full Name_Chevrolet Trax: -393.4266
#   Model Full Name_Chrysler 200: -266.4858
#   Model Full Name_Chrysler 300: -196.3661
#   Model Full Name_Chrysler Pacifica: -317.4329
#   Model Full Name_Dodge Challenger: 317.1701
#   Model Full Name_Dodge Charger: -203.8635
#   Model Full Name_Dodge Durango: 79.0977
#   Model Full Name_Fiat 500x: -282.3348
#   Model Full Name_Ford Bronco: 723.1591
#   Model Full Name_Ford Bronco-sport: -23.8789
#   Model Full Name_Ford Escape: -253.4310
#   Model Full Name_Ford Expedition: 399.3650
#   Model Full Name_Ford Explorer: 148.2679
#   Model Full Name_Ford F150: -283.2211
#   Model Full Name_Ford Focus: -378.6421
#   Model Full Name_Ford Fusion: -111.2515
#   Model Full Name_Ford Maverick: -27.7449
#   Model Full Name_Ford Mustang: 538.0027
#   Model Full Name_Ford Ranger: -268.0152
#   Model Full Name_Ford Taurus: -26.0942
#   Model Full Name_Genesis G70: -68.4350
#   Model Full Name_Genesis G80: -122.5625
#   Model Full Name_Genesis Gv80: 388.6237
#   Model Full Name_Gmc Acadia: 16.7435
#   Model Full Name_Gmc Canyon: -144.2972
#   Model Full Name_Gmc Hummer-ev: 570.7674
#   Model Full Name_Gmc Sierra-1500: 3.7650
#   Model Full Name_Gmc Terrain: 100.3435
#   Model Full Name_Gmc Yukon-xl: 1415.2376
#   Model Full Name_Honda Accord: 0.0000
#   Model Full Name_Honda Insight: -0.0000
#   Model Full Name_Honda Odyssey: 87.3786
#   Model Full Name_Honda Passport: -30.6459
#   Model Full Name_Honda Pilot: 11.1727
#   Model Full Name_Honda Ridgeline: 329.0402
#   Model Full Name_Hyundai Azera: -415.5703
#   Model Full Name_Hyundai Elantra: -316.4260
#   Model Full Name_Hyundai Genesis: -457.8354
#   Model Full Name_Hyundai Ioniq-5: -203.5609
#   Model Full Name_Hyundai Ioniq-6: 210.6510
#   Model Full Name_Hyundai Palisade: 133.2114
#   Model Full Name_Hyundai Sonata: -257.3997
#   Model Full Name_Hyundai Tucson: -210.9913
#   Model Full Name_Hyundai Venue: -275.3865
#   Model Full Name_Infiniti Q50: -49.1180
#   Model Full Name_Infiniti Qx60: -168.1981
#   Model Full Name_Infiniti Qx80: 76.0424
#   Model Full Name_Jaguar E-pace: 39.1826
#   Model Full Name_Jaguar F-pace: -103.7165
#   Model Full Name_Jaguar I-pace: -36.6999
#   Model Full Name_Jeep Cherokee: -241.1344
#   Model Full Name_Jeep Compass: -332.5109
#   Model Full Name_Jeep Gladiator: 693.8631
#   Model Full Name_Jeep Grand-wagoneer: 906.5950
#   Model Full Name_Jeep Renegade: -437.5675
#   Model Full Name_Jeep Wagoneer: 528.6105
#   Model Full Name_Jeep Wrangler: 536.0895
#   Model Full Name_Kia Cadenza: -484.4960
#   Model Full Name_Kia Carnival: 193.0166
#   Model Full Name_Kia Ev6: -111.3840
#   Model Full Name_Kia K5: -201.8008
#   Model Full Name_Kia K900: -174.7720
#   Model Full Name_Kia Optima: -302.2489
#   Model Full Name_Kia Sedona: -165.7344
#   Model Full Name_Kia Seltos: -374.6241
#   Model Full Name_Kia Sorento: -23.3423
#   Model Full Name_Kia Sportage: -143.1899
#   Model Full Name_Kia Stinger: -355.4343
#   Model Full Name_Kia Telluride: 164.8391
#   Model Full Name_Land-rover Discovery: -210.1520
#   Model Full Name_Land-rover Range-rover-evoque: 169.8732
#   Model Full Name_Lexus Es: 463.7342
#   Model Full Name_Lexus Gx: 664.8253
#   Model Full Name_Lexus Nx: 45.2080
#   Model Full Name_Lexus Rx: 474.7463
#   Model Full Name_Lexus Ux: -175.6000
#   Model Full Name_Mazda Cx-5: 127.4324
#   Model Full Name_Mazda Cx-50: 145.1068
#   Model Full Name_Mazda Cx-9: 61.2110
#   Model Full Name_Mazda Mazda6: -72.0905
#   Model Full Name_Mazda Mx-5-miata: -374.4651
#   Model Full Name_Mercedes-benz A-class: -33.5857
#   Model Full Name_Mercedes-benz C-class: 316.7515
#   Model Full Name_Mercedes-benz E-class: -169.9605
#   Model Full Name_Mercedes-benz Glc: 120.8194
#   Model Full Name_Mercedes-benz Gle: 637.8698
#   Model Full Name_Mini Countryman: 75.3423
#   Model Full Name_Mitsubishi Outlander: -200.3016
#   Model Full Name_Nissan Altima: -343.0209
#   Model Full Name_Nissan Ariya: 334.9808
#   Model Full Name_Nissan Armada: 127.2088
#   Model Full Name_Nissan Frontier: -37.3765
#   Model Full Name_Nissan Kicks: -494.5664
#   Model Full Name_Nissan Leaf: -208.6923
#   Model Full Name_Nissan Maxima: -572.0299
#   Model Full Name_Nissan Murano: -284.7958
#   Model Full Name_Nissan Pathfinder: -247.6575
#   Model Full Name_Nissan Quest: -105.3591
#   Model Full Name_Nissan Rogue: 14.7180
#   Model Full Name_Nissan Titan: 91.4693
#   Model Full Name_Porsche Cayenne: 875.8141
#   Model Full Name_Porsche Macan: 364.8510
#   Model Full Name_Subaru Ascent: -101.0326
#   Model Full Name_Subaru Brz: -308.9531
#   Model Full Name_Subaru Crosstrek: -396.1924
#   Model Full Name_Subaru Forester: -44.2148
#   Model Full Name_Subaru Legacy: -349.6487
#   Model Full Name_Subaru Outback: -463.2095
#   Model Full Name_Subaru Solterra: 242.9184
#   Model Full Name_Tesla Model-3: 190.7023
#   Model Full Name_Tesla Model-s: 812.6366
#   Model Full Name_Tesla Model-x: 36.2353
#   Model Full Name_Tesla Model-y: 52.8503
#   Model Full Name_Toyota 4runner: 675.0298
#   Model Full Name_Toyota Avalon: -237.2704
#   Model Full Name_Toyota Camry: 36.9224
#   Model Full Name_Toyota Corolla: -398.7394
#   Model Full Name_Toyota Crown: 274.5398
#   Model Full Name_Toyota Highlander: 524.2045
#   Model Full Name_Toyota Land-cruiser: 1224.2423
#   Model Full Name_Toyota Prius: 415.4601
#   Model Full Name_Toyota Rav4: 404.3781
#   Model Full Name_Toyota Sienna: 628.1656
#   Model Full Name_Toyota Tacoma: 107.8819
#   Model Full Name_Toyota Tundra: 678.6217
#   Model Full Name_Toyota Venza: 274.2202
#   Model Full Name_Volkswagen Arteon: -271.4404
#   Model Full Name_Volkswagen Atlas: 8.9007
#   Model Full Name_Volkswagen Golf-gti: -310.6392
#   Model Full Name_Volkswagen Id-4: -146.1078
#   Model Full Name_Volkswagen Jetta: -45.5180
#   Model Full Name_Volkswagen Passat: -224.7366
#   Model Full Name_Volkswagen Tiguan: 199.7868
#   Model Full Name_Volvo Xc40: 77.3260
#   Model Full Name_Volvo Xc60: 62.0476
#   Model Full Name_Volvo Xc90: 34.8120
#
# Intercept: 13727.1155

# %% [markdown]
# #### Functional and Experiental Unaggregated Ridge

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.9119
#   RMSE: 2610.2977
#
# Alpha: 1.0
#   R^2: 0.9119
#   RMSE: 2610.3006
#
# Alpha: 10.0
#   R^2: 0.9119
#   RMSE: 2610.4060
#
# Alpha: 100
#   R^2: 0.9114
#   RMSE: 2616.8996
#
# Alpha: 200
#   R^2: 0.9105
#   RMSE: 2630.3706
#
# Alpha: 300
#   R^2: 0.9094
#   RMSE: 2646.5772
#
# Alpha: 500
#   R^2: 0.9069
#   RMSE: 2682.0127
#
# Alpha: 1000
#   R^2: 0.9003
#   RMSE: 2775.6619
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.9119
# Best RMSE: 2610.2977
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 2182.5473
#   Curb Weight (lbs): 0.0000
#   Combined MPG: 0.0000
#   Fuel Capacity (gallons): 0.0000
#   Age: -5889.8643
#   Drivetrain_4WD: 284.2387
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -166.5648
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 0.0000
#   Vehicle Class_full-size: 0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#   Topic_0_Weighted: 0.0000
#   Topic_2_Weighted: -0.0000
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: 0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#   Model Full Name_Acura Tlx: 0.0000
#   Model Full Name_Alfa-romeo Giulia: -0.0000
#   Model Full Name_Alfa-romeo Stelvio: -0.0000
#   Model Full Name_Audi A4: -0.0000
#   Model Full Name_Audi A6: -0.0000
#   Model Full Name_Audi Q3: -0.0000
#   Model Full Name_Audi Q5: -0.0000
#   Model Full Name_Audi Q7: -0.0000
#   Model Full Name_Bmw 3-series: 0.0000
#   Model Full Name_Bmw 5-series: -0.0000
#   Model Full Name_Bmw X3: -0.0000
#   Model Full Name_Bmw X5: -0.0000
#   Model Full Name_Buick Enclave: -0.0000
#   Model Full Name_Buick Encore: -0.0000
#   Model Full Name_Buick Encore-gx: -0.0000
#   Model Full Name_Cadillac Ct4: 0.0000
#   Model Full Name_Cadillac Xt5: -0.0000
#   Model Full Name_Chevrolet Blazer: 0.0000
#   Model Full Name_Chevrolet Camaro: -0.0000
#   Model Full Name_Chevrolet Colorado: 0.0000
#   Model Full Name_Chevrolet Corvette: 521.8624
#   Model Full Name_Chevrolet Equinox: -0.0000
#   Model Full Name_Chevrolet Impala: -0.0000
#   Model Full Name_Chevrolet Malibu: -0.0000
#   Model Full Name_Chevrolet Silverado-1500: -0.0000
#   Model Full Name_Chevrolet Ss: 0.0000
#   Model Full Name_Chevrolet Suburban: 0.0000
#   Model Full Name_Chevrolet Tahoe: 0.0000
#   Model Full Name_Chevrolet Trailblazer: -0.0000
#   Model Full Name_Chevrolet Traverse: -0.0000
#   Model Full Name_Chevrolet Trax: -0.0000
#   Model Full Name_Chrysler 200: -0.0000
#   Model Full Name_Chrysler 300: -0.0000
#   Model Full Name_Chrysler Pacifica: -0.0000
#   Model Full Name_Dodge Challenger: 0.0000
#   Model Full Name_Dodge Charger: 0.0000
#   Model Full Name_Dodge Durango: -0.0000
#   Model Full Name_Fiat 500x: -0.0000
#   Model Full Name_Ford Bronco: 0.0000
#   Model Full Name_Ford Bronco-sport: 0.0000
#   Model Full Name_Ford Escape: -0.0000
#   Model Full Name_Ford Expedition: -0.0000
#   Model Full Name_Ford Explorer: -0.0000
#   Model Full Name_Ford F150: -0.0000
#   Model Full Name_Ford Focus: -0.0000
#   Model Full Name_Ford Fusion: -0.0000
#   Model Full Name_Ford Maverick: 0.0000
#   Model Full Name_Ford Mustang: 0.0000
#   Model Full Name_Ford Ranger: 0.0000
#   Model Full Name_Ford Taurus: -0.0000
#   Model Full Name_Genesis G70: -0.0000
#   Model Full Name_Genesis G80: -0.0000
#   Model Full Name_Genesis Gv80: 0.0000
#   Model Full Name_Gmc Acadia: -0.0000
#   Model Full Name_Gmc Canyon: 0.0000
#   Model Full Name_Gmc Hummer-ev: 0.0000
#   Model Full Name_Gmc Sierra-1500: 0.0000
#   Model Full Name_Gmc Terrain: -0.0000
#   Model Full Name_Gmc Yukon-xl: 0.0000
#   Model Full Name_Honda Accord: 0.0000
#   Model Full Name_Honda Insight: -0.0000
#   Model Full Name_Honda Odyssey: -0.0000
#   Model Full Name_Honda Passport: -0.0000
#   Model Full Name_Honda Pilot: -0.0000
#   Model Full Name_Honda Ridgeline: 0.0000
#   Model Full Name_Hyundai Azera: -0.0000
#   Model Full Name_Hyundai Elantra: -0.0000
#   Model Full Name_Hyundai Genesis: -0.0000
#   Model Full Name_Hyundai Ioniq-5: -0.0000
#   Model Full Name_Hyundai Ioniq-6: 0.0000
#   Model Full Name_Hyundai Palisade: 0.0000
#   Model Full Name_Hyundai Sonata: -0.0000
#   Model Full Name_Hyundai Tucson: -0.0000
#   Model Full Name_Hyundai Venue: -0.0000
#   Model Full Name_Infiniti Q50: -0.0000
#   Model Full Name_Infiniti Qx60: -0.0000
#   Model Full Name_Infiniti Qx80: -0.0000
#   Model Full Name_Jaguar E-pace: -0.0000
#   Model Full Name_Jaguar F-pace: 0.0000
#   Model Full Name_Jaguar I-pace: -0.0000
#   Model Full Name_Jeep Cherokee: -0.0000
#   Model Full Name_Jeep Compass: -0.0000
#   Model Full Name_Jeep Gladiator: 0.0000
#   Model Full Name_Jeep Grand-wagoneer: 0.0000
#   Model Full Name_Jeep Renegade: -0.0000
#   Model Full Name_Jeep Wagoneer: 0.0000
#   Model Full Name_Jeep Wrangler: 0.0000
#   Model Full Name_Kia Cadenza: -0.0000
#   Model Full Name_Kia Carnival: 0.0000
#   Model Full Name_Kia Ev6: 0.0000
#   Model Full Name_Kia K5: -0.0000
#   Model Full Name_Kia K900: -0.0000
#   Model Full Name_Kia Optima: -0.0000
#   Model Full Name_Kia Sedona: -0.0000
#   Model Full Name_Kia Seltos: -0.0000
#   Model Full Name_Kia Sorento: 0.0000
#   Model Full Name_Kia Sportage: -0.0000
#   Model Full Name_Kia Stinger: -0.0000
#   Model Full Name_Kia Telluride: 0.0000
#   Model Full Name_Land-rover Discovery: -0.0000
#   Model Full Name_Land-rover Range-rover-evoque: -0.0000
#   Model Full Name_Lexus Es: 0.0000
#   Model Full Name_Lexus Gx: 0.0000
#   Model Full Name_Lexus Nx: 0.0000
#   Model Full Name_Lexus Rx: 0.0000
#   Model Full Name_Lexus Ux: 0.0000
#   Model Full Name_Mazda Cx-5: -0.0000
#   Model Full Name_Mazda Cx-50: 0.0000
#   Model Full Name_Mazda Cx-9: -0.0000
#   Model Full Name_Mazda Mazda6: -0.0000
#   Model Full Name_Mazda Mx-5-miata: 0.0000
#   Model Full Name_Mercedes-benz A-class: 0.0000
#   Model Full Name_Mercedes-benz C-class: 0.0000
#   Model Full Name_Mercedes-benz E-class: 0.0000
#   Model Full Name_Mercedes-benz Glc: -0.0000
#   Model Full Name_Mercedes-benz Gle: 0.0000
#   Model Full Name_Mini Countryman: 0.0000
#   Model Full Name_Mitsubishi Outlander: -0.0000
#   Model Full Name_Nissan Altima: -0.0000
#   Model Full Name_Nissan Ariya: 0.0000
#   Model Full Name_Nissan Armada: -0.0000
#   Model Full Name_Nissan Frontier: 0.0000
#   Model Full Name_Nissan Kicks: -0.0000
#   Model Full Name_Nissan Leaf: -0.0000
#   Model Full Name_Nissan Maxima: -0.0000
#   Model Full Name_Nissan Murano: -0.0000
#   Model Full Name_Nissan Pathfinder: -0.0000
#   Model Full Name_Nissan Quest: -0.0000
#   Model Full Name_Nissan Rogue: -0.0000
#   Model Full Name_Nissan Titan: -0.0000
#   Model Full Name_Porsche Cayenne: 0.0000
#   Model Full Name_Porsche Macan: -0.0000
#   Model Full Name_Subaru Ascent: -0.0000
#   Model Full Name_Subaru Brz: -0.0000
#   Model Full Name_Subaru Crosstrek: -0.0000
#   Model Full Name_Subaru Forester: -0.0000
#   Model Full Name_Subaru Legacy: -0.0000
#   Model Full Name_Subaru Outback: -0.0000
#   Model Full Name_Subaru Solterra: 0.0000
#   Model Full Name_Tesla Model-3: 0.0000
#   Model Full Name_Tesla Model-s: 0.0000
#   Model Full Name_Tesla Model-x: 0.0000
#   Model Full Name_Tesla Model-y: 0.0000
#   Model Full Name_Toyota 4runner: 0.0000
#   Model Full Name_Toyota Avalon: 0.0000
#   Model Full Name_Toyota Camry: 0.0000
#   Model Full Name_Toyota Corolla: 0.0000
#   Model Full Name_Toyota Crown: 0.0000
#   Model Full Name_Toyota Highlander: 0.0000
#   Model Full Name_Toyota Land-cruiser: 0.0000
#   Model Full Name_Toyota Prius: 0.0000
#   Model Full Name_Toyota Rav4: 0.0000
#   Model Full Name_Toyota Sienna: 0.0000
#   Model Full Name_Toyota Tacoma: 0.0000
#   Model Full Name_Toyota Tundra: 0.0000
#   Model Full Name_Toyota Venza: 0.0000
#   Model Full Name_Volkswagen Arteon: -0.0000
#   Model Full Name_Volkswagen Atlas: -0.0000
#   Model Full Name_Volkswagen Golf-gti: -0.0000
#   Model Full Name_Volkswagen Id-4: 0.0000
#   Model Full Name_Volkswagen Jetta: -0.0000
#   Model Full Name_Volkswagen Passat: -0.0000
#   Model Full Name_Volkswagen Tiguan: -0.0000
#   Model Full Name_Volvo Xc40: -0.0000
#   Model Full Name_Volvo Xc60: 0.0000
#   Model Full Name_Volvo Xc90: -0.0000
#
# Intercept: 13732.4364

# %% [markdown]
# ### Functional and Experiental Aggregated

# %%
#aggregated
selected_topics = ['Topic_0', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_7', 'Topic_8', 'Topic_9']

for topic in selected_topics:
    df[f'{topic}_Weighted'] = df[topic] * df['Sentiment Score']

df = pd.get_dummies(df, columns=['Drivetrain','Car Model', 'Car Brand', 'Vehicle Class'], drop_first=True)

aggregation_dict = {
    feature: 'mean' if feature != 'Drivetrain' or feature != 'Car Brand' or feature != 'Vehicle Class' or feature != 'Car Model' else 'first'
    for feature in functional_features + [f'{topic}_Weighted' for topic in selected_topics] + ['Sentiment Score', 'Average KBB Fair Price ($)']
}
aggregated_data = df.groupby(['Model Full Name', 'Year']).agg(aggregation_dict).reset_index()

car_data_encoded = aggregated_data



weighted_topic_features = [f'{topic}_Weighted' for topic in selected_topics]
features = functional_features + weighted_topic_features + [col for col in car_data_encoded.columns if col.startswith('Model Full Name_')]

X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.6470
#
# RMSE: 5088.1908
#
# Model Coefficients:
#   Horsepower (hp): 44.9353
#   Curb Weight (lbs): -0.7144
#   Combined MPG: 3.8321
#   Fuel Capacity (gallons): 91.3450
#   Age: -2089.2104
#   Drivetrain_4WD: 2942.7200
#   Drivetrain_AWD: -2071.4461
#   Drivetrain_FWD: -2715.7629
#   Drivetrain_RWD: -5.8770
#   Vehicle Class_compact-suv: 211.6559
#   Vehicle Class_electric-car: 6447.1981
#   Vehicle Class_electric-suv: 5062.8956
#   Vehicle Class_full-size: -1104.0260
#   Vehicle Class_full-size-truck: -1284.0530
#   Vehicle Class_hybrid-car: 764.9949
#   Vehicle Class_hybrid-suv: -3033.5552
#   Vehicle Class_luxury-hybrid-suv: 5664.2482
#   Vehicle Class_mid-size: 2191.8208
#   Vehicle Class_mid-size-suv: 939.7780
#   Vehicle Class_mid-size-truck: 3492.4755
#   Vehicle Class_minivan: 1924.3700
#   Topic_0_Weighted: -81750.3118
#   Topic_2_Weighted: -166701.4937
#   Topic_3_Weighted: 203352.7398
#   Topic_4_Weighted: 42828.8157
#   Topic_5_Weighted: -40744.1437
#   Topic_7_Weighted: -133470.6638
#   Topic_8_Weighted: 71093.5622
#   Topic_9_Weighted: -92685.2303
#
# Intercept: 26910.2004

# %% [markdown]
# #### Functional and Experiental Aggregated lasso

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6470
#   RMSE: 5087.9646
#
# Alpha: 1.0
#   R^2: 0.6473
#   RMSE: 5085.5279
#
# Alpha: 10.0
#   R^2: 0.6505
#   RMSE: 5062.5979
#
# Alpha: 100
#   R^2: 0.6766
#   RMSE: 4870.0405
#
# Alpha: 200
#   R^2: 0.6940
#   RMSE: 4736.7433
#
# Alpha: 300
#   R^2: 0.7022
#   RMSE: 4672.9310
#
# Alpha: 500
#   R^2: 0.7027
#   RMSE: 4669.4612
#
# Alpha: 1000
#   R^2: 0.6996
#   RMSE: 4693.6620
#
# Best Alpha based on RMSE: 500
# Best R^2: 0.7027
# Best RMSE: 4669.4612
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 3563.3705
#   Curb Weight (lbs): 0.0000
#   Combined MPG: 511.1445
#   Fuel Capacity (gallons): 0.0000
#   Age: -8347.3837
#   Drivetrain_4WD: 749.1527
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -277.1480
#   Drivetrain_RWD: 121.2650
#   Vehicle Class_compact-suv: -170.2542
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 83.0012
#   Vehicle Class_full-size: -0.2334
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -24.5466
#   Vehicle Class_luxury-hybrid-suv: 219.8765
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#   Topic_0_Weighted: 0.0000
#   Topic_2_Weighted: -242.6313
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: 0.0000
#   Topic_7_Weighted: -306.6600
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: -0.0000
#
# Intercept: 16720.3183

# %% [markdown]
# #### Functional and Experiental Aggregated Ridge

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your input features

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 200, 300, 500, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6470
#   RMSE: 5087.7660
#
# Alpha: 1.0
#   R^2: 0.6475
#   RMSE: 5084.2992
#
# Alpha: 10.0
#   R^2: 0.6492
#   RMSE: 5071.8508
#
# Alpha: 100
#   R^2: 0.6333
#   RMSE: 5185.3411
#
# Alpha: 200
#   R^2: 0.6125
#   RMSE: 5330.9658
#
# Alpha: 300
#   R^2: 0.5855
#   RMSE: 5513.2996
#
# Alpha: 500
#   R^2: 0.5255
#   RMSE: 5898.7645
#
# Alpha: 1000
#   R^2: 0.3960
#   RMSE: 6655.5024
#
# Best Alpha based on RMSE: 10.0
# Best R^2: 0.6492
# Best RMSE: 5071.8508
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 3543.5295
#   Curb Weight (lbs): 0.0000
#   Combined MPG: 25.3977
#   Fuel Capacity (gallons): 0.0000
#   Age: -8084.9927
#   Drivetrain_4WD: 293.3834
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Vehicle Class_compact-suv: -0.0000
#   Vehicle Class_electric-car: 0.0000
#   Vehicle Class_electric-suv: 96.3568
#   Vehicle Class_full-size: -0.0000
#   Vehicle Class_full-size-truck: -0.0000
#   Vehicle Class_hybrid-car: -0.0000
#   Vehicle Class_hybrid-suv: -0.0000
#   Vehicle Class_luxury-hybrid-suv: 0.0000
#   Vehicle Class_mid-size: 0.0000
#   Vehicle Class_mid-size-suv: 0.0000
#   Vehicle Class_mid-size-truck: 0.0000
#   Vehicle Class_minivan: -0.0000
#   Topic_0_Weighted: 0.0000
#   Topic_2_Weighted: -0.0000
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: 0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#
# Intercept: 16757.9873

# %% [markdown]
# # All Feature Model

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'Year', 'Review', 'Rating', 'Value Rating',
#        'Performance Rating', 'Quality Rating', 'Comfort Rating',
#        'Reliability Rating', 'Styling Rating', 'Model Full Name',
#        'Horsepower (hp)', 'Curb Weight (lbs)', 'Combined MPG',
#        'Fuel Capacity (gallons)', 'Recommended Fuel',
#        'Average MSRP Price ($)', 'Average KBB Fair Price ($)',
#        'Review_Topics', 'Topic_0', 'Topic_1', 'Topic_2', 'Topic_3',
#        'Topic_4', 'Topic_5', 'Topic_6', 'Topic_7', 'Topic_8', 'Topic_9',
#        'Sentiment Score', 'Depreciated Value', 'Sentiment Bin',
#        'Weighted Sentiment Score', 'Topic_0_Weighted', 'Topic_2_Weighted',
#        'Topic_3_Weighted', 'Topic_4_Weighted', 'Topic_5_Weighted',
#        'Topic_7_Weighted', 'Topic_8_Weighted', 'Topic_9_Weighted', 'Age',
#        'Drivetrain_4WD', 'Drivetrain_AWD', 'Drivetrain_FWD',
#        'Drivetrain_RWD', 'Car Model_3-series', 'Car Model_300',
#        'Car Model_4runner', 'Car Model_5-series', 'Car Model_500x',
#        'Car Model_a-class', 'Car Model_a4', 'Car Model_a6',
#        'Car Model_acadia', 'Car Model_accord', 'Car Model_altima',
#        'Car Model_ariya', 'Car Model_armada', 'Car Model_arteon',
#        'Car Model_ascent', 'Car Model_atlas', 'Car Model_avalon',
#        'Car Model_azera', 'Car Model_blazer', 'Car Model_bronco',
#        'Car Model_bronco-sport', 'Car Model_brz', 'Car Model_c-class',
#        'Car Model_cadenza', 'Car Model_camaro', 'Car Model_camry',
#        'Car Model_canyon', 'Car Model_carnival', 'Car Model_cayenne',
#        'Car Model_challenger', 'Car Model_charger', 'Car Model_cherokee',
#        'Car Model_colorado', 'Car Model_compass', 'Car Model_corolla',
#        'Car Model_corvette', 'Car Model_countryman',
#        'Car Model_crosstrek', 'Car Model_crown', 'Car Model_ct4',
#        'Car Model_cx-5', 'Car Model_cx-50', 'Car Model_cx-9',
#        'Car Model_discovery', 'Car Model_durango', 'Car Model_e-class',
#        'Car Model_e-pace', 'Car Model_elantra', 'Car Model_enclave',
#        'Car Model_encore', 'Car Model_encore-gx', 'Car Model_equinox',
#        'Car Model_es', 'Car Model_escape', 'Car Model_ev6',
#        'Car Model_expedition', 'Car Model_explorer', 'Car Model_f-pace',
#        'Car Model_f150', 'Car Model_focus', 'Car Model_forester',
#        'Car Model_frontier', 'Car Model_fusion', 'Car Model_g70',
#        'Car Model_g80', 'Car Model_genesis', 'Car Model_giulia',
#        'Car Model_gladiator', 'Car Model_glc', 'Car Model_gle',
#        'Car Model_golf-gti', 'Car Model_grand-wagoneer', 'Car Model_gv80',
#        'Car Model_gx', 'Car Model_highlander', 'Car Model_hummer-ev',
#        'Car Model_i-pace', 'Car Model_id-4', 'Car Model_impala',
#        'Car Model_insight', 'Car Model_ioniq-5', 'Car Model_ioniq-6',
#        'Car Model_jetta', 'Car Model_k5', 'Car Model_k900',
#        'Car Model_kicks', 'Car Model_land-cruiser', 'Car Model_leaf',
#        'Car Model_legacy', 'Car Model_macan', 'Car Model_malibu',
#        'Car Model_maverick', 'Car Model_maxima', 'Car Model_mazda6',
#        'Car Model_model-3', 'Car Model_model-s', 'Car Model_model-x',
#        'Car Model_model-y', 'Car Model_murano', 'Car Model_mustang',
#        'Car Model_mx-5-miata', 'Car Model_nx', 'Car Model_odyssey',
#        'Car Model_optima', 'Car Model_outback', 'Car Model_outlander',
#        'Car Model_pacifica', 'Car Model_palisade', 'Car Model_passat',
#        'Car Model_passport', 'Car Model_pathfinder', 'Car Model_pilot',
#        'Car Model_prius', 'Car Model_q3', 'Car Model_q5', 'Car Model_q50',
#        'Car Model_q7', 'Car Model_quest', 'Car Model_qx60',
#        'Car Model_qx80', 'Car Model_range-rover-evoque',
#        'Car Model_ranger', 'Car Model_rav4', 'Car Model_rdx',
#        'Car Model_renegade', 'Car Model_ridgeline', 'Car Model_rogue',
#        'Car Model_rx', 'Car Model_sedona', 'Car Model_seltos',
#        'Car Model_sienna', 'Car Model_sierra-1500',
#        'Car Model_silverado-1500', 'Car Model_solterra',
#        'Car Model_sonata', 'Car Model_sorento', 'Car Model_sportage',
#        'Car Model_ss', 'Car Model_stelvio', 'Car Model_stinger',
#        'Car Model_suburban', 'Car Model_tacoma', 'Car Model_tahoe',
#        'Car Model_taurus', 'Car Model_telluride', 'Car Model_terrain',
#        'Car Model_tiguan', 'Car Model_titan', 'Car Model_tlx',
#        'Car Model_trailblazer', 'Car Model_traverse', 'Car Model_trax',
#        'Car Model_tucson', 'Car Model_tundra', 'Car Model_ux',
#        'Car Model_venue', 'Car Model_venza', 'Car Model_wagoneer',
#        'Car Model_wrangler', 'Car Model_x3', 'Car Model_x5',
#        'Car Model_xc40', 'Car Model_xc60', 'Car Model_xc90',
#        'Car Model_xt5', 'Car Model_yukon-xl', 'Car Brand_alfa-romeo',
#        'Car Brand_audi', 'Car Brand_bmw', 'Car Brand_buick',
#        'Car Brand_cadillac', 'Car Brand_chevrolet', 'Car Brand_chrysler',
#        'Car Brand_dodge', 'Car Brand_fiat', 'Car Brand_ford',
#        'Car Brand_genesis', 'Car Brand_gmc', 'Car Brand_honda',
#        'Car Brand_hyundai', 'Car Brand_infiniti', 'Car Brand_jaguar',
#        'Car Brand_jeep', 'Car Brand_kia', 'Car Brand_land-rover',
#        'Car Brand_lexus', 'Car Brand_mazda', 'Car Brand_mercedes-benz',
#        'Car Brand_mini', 'Car Brand_mitsubishi', 'Car Brand_nissan',
#        'Car Brand_porsche', 'Car Brand_subaru', 'Car Brand_tesla',
#        'Car Brand_toyota', 'Car Brand_volkswagen', 'Car Brand_volvo',
#        'Vehicle Class_compact-suv', 'Vehicle Class_electric-car',
#        'Vehicle Class_electric-suv', 'Vehicle Class_full-size',
#        'Vehicle Class_full-size-truck', 'Vehicle Class_hybrid-car',
#        'Vehicle Class_hybrid-suv', 'Vehicle Class_luxury-hybrid-suv',
#        'Vehicle Class_mid-size', 'Vehicle Class_mid-size-suv',
#        'Vehicle Class_mid-size-truck', 'Vehicle Class_minivan'],
#       dtype=object)

# %% [markdown]
# ## Results

# %%
results_df = pd.DataFrame(results_list).round({"R^2": 2, "RMSE": 2})
print("\nResults Summary:")
results_df
# Out:
# Results Summary:
#                             Division Title         Model Type  Best Alpha  \
# 0                  Functional Unaggregated  Linear Regression         NaN
# 1                  Functional Unaggregated              Lasso         1.0
# 2                  Functional Unaggregated              Ridge       100.0
# 3                    Functional Aggregated  Linear Regression         NaN
# 4                    Functional Aggregated              Lasso      1000.0
# 5                    Functional Aggregated              Ridge       100.0
# 6   Functional & Experiential Unaggregated  Linear Regression         NaN
# 7   Functional & Experiential Unaggregated              Lasso         0.1
# 8   Functional & Experiential Unaggregated              Ridge         0.1
# 9     Functional & Experiential Aggregated  Linear Regression         NaN
# 10    Functional & Experiential Aggregated              Lasso       500.0
# 11    Functional & Experiential Aggregated              Ridge        10.0
#
#      R^2     RMSE
# 0   0.78  4123.80
# 1   0.78  4123.73
# 2   0.78  4123.44
# 3   0.64  5149.06
# 4   0.70  4693.66
# 5   0.71  4624.13
# 6   0.91  2610.30
# 7   0.91  2610.32
# 8   0.91  2610.30
# 9   0.65  5088.19
# 10  0.70  4669.46
# 11  0.65  5071.85

# %%
car_data_encoded
# Out:
#     Model Full Name  Year  Horsepower (hp)  Curb Weight (lbs)  Combined MPG  \
# 0         Acura Rdx  2010            240.0             3931.0          19.0
# 1         Acura Rdx  2013            273.0             3838.0          22.0
# 2         Acura Rdx  2019            272.0             3783.0          24.0
# 3         Acura Tlx  2015            206.0             3483.0          28.0
# 4         Acura Tlx  2021            272.0             3709.0          25.0
# ..              ...   ...              ...                ...           ...
# 321      Volvo Xc40  2019            187.0             3574.0          27.0
# 322      Volvo Xc60  2010            235.0             4012.0          21.0
# 323      Volvo Xc60  2018            316.0             4074.0          23.0
# 324      Volvo Xc90  2010            235.0             4751.0          17.0
# 325      Volvo Xc90  2016            250.0             4293.0          22.0
#
#      Fuel Capacity (gallons)   Age  Drivetrain_4WD  Drivetrain_AWD  \
# 0                       18.0  14.0             0.0             1.0
# 1                       16.0  11.0             0.0             1.0
# 2                       17.1   5.0             0.0             0.0
# 3                       17.2   9.0             0.0             0.0
# 4                       15.9   3.0             0.0             0.0
# ..                       ...   ...             ...             ...
# 321                     14.2   5.0             0.0             0.0
# 322                     18.5  14.0             0.0             0.0
# 323                     18.8   6.0             0.0             1.0
# 324                     21.1  14.0             0.0             1.0
# 325                     18.8   8.0             0.0             1.0
#
#      Drivetrain_FWD  ...  Topic_0_Weighted  Topic_2_Weighted  \
# 0               0.0  ...          0.010983          0.008371
# 1               0.0  ...          0.014091          0.006550
# 2               1.0  ...          0.009899          0.004513
# 3               1.0  ...          0.018985          0.007476
# 4               1.0  ...          0.016929          0.002959
# ..              ...  ...               ...               ...
# 321             1.0  ...          0.020192          0.001120
# 322             0.0  ...          0.012794          0.006283
# 323             0.0  ...          0.007880          0.000921
# 324             0.0  ...          0.008383          0.004934
# 325             0.0  ...          0.018290          0.002961
#
#      Topic_3_Weighted  Topic_4_Weighted  Topic_5_Weighted  Topic_7_Weighted  \
# 0            0.007901          0.007013          0.000398          0.001676
# 1            0.005801          0.010964          0.000553          0.005570
# 2           -0.000620          0.002953          0.001104          0.002835
# 3            0.004036          0.008199          0.000478          0.008157
# 4            0.005005          0.005594          0.000507          0.006455
# ..                ...               ...               ...               ...
# 321          0.001512          0.001359          0.000159          0.008877
# 322          0.007155          0.009381          0.000846          0.002356
# 323         -0.000955          0.005646          0.000010          0.003236
# 324          0.010953          0.008031          0.001703          0.001079
# 325          0.002503          0.006061          0.000085          0.002675
#
#      Topic_8_Weighted  Topic_9_Weighted  Sentiment Score  \
# 0            0.010811          0.009977         0.552172
# 1            0.006619          0.007627         0.499811
# 2            0.003356          0.007962         0.321741
# 3            0.001749          0.010193         0.633109
# 4            0.001271          0.003832         0.675924
# ..                ...               ...              ...
# 321          0.003691          0.028231         0.698563
# 322          0.005801          0.010385         0.613741
# 323          0.000951          0.003517         0.281155
# 324          0.006141          0.003632         0.557620
# 325          0.007689          0.004785         0.547714
#
#      Average KBB Fair Price ($)
# 0                        7210.0
# 1                       10589.0
# 2                       23046.5
# 3                       11905.5
# 4                       29701.0
# ..                          ...
# 321                     18941.0
# 322                      7055.0
# 323                     23469.0
# 324                      6471.0
# 325                     15411.5
#
# [326 rows x 33 columns]
