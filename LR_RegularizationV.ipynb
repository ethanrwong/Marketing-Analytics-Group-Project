# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
#from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
current_year = datetime.now().year
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nehab\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = pd.read_csv('final_cleaned.csv', index_col = False)
car_data_encoded = pd.get_dummies(df, columns=['Model Full Name', 'Drivetrain'], drop_first=True)

# %%
results_list = []

# %% [markdown]
# # Functional

# %%
functional_features = [
    'Horsepower (hp)', 'Curb Weight (lbs)', 'Combined MPG', 'Fuel Capacity (gallons)', 'Age'
] + [col for col in car_data_encoded.columns if col.startswith('Drivetrain_')]
features = functional_features

# %% [markdown]
# ### Unaggregated

# %%
#unaggregated

y_price = car_data_encoded['Average KBB Fair Price ($)']
X = car_data_encoded[features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)


price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional Unaggregated"
model_type = "Linear Regression"

# Append the results to the list as a dictionary
results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.7588
#
# RMSE: 4318.3028
#
# Model Coefficients:
#   Horsepower (hp): 48.6318
#   Curb Weight (lbs): -2.1142
#   Combined MPG: 31.0233
#   Fuel Capacity (gallons): 184.6320
#   Age: -1722.8755
#   Drivetrain_4WD: 3729.0607
#   Drivetrain_AWD: -423.9212
#   Drivetrain_FWD: -1954.2304
#   Drivetrain_RWD: 763.4948
#
# Intercept: 23434.2587

# %% [markdown]
# #### Lasso

# %%
y_price = car_data_encoded['Average KBB Fair Price ($)']
X = car_data_encoded[features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.001, 0.01, 0.1, 1.0, 10.0]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Unaggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.001
#   R^2: 0.7588
#   RMSE: 4318.3027
#
# Alpha: 0.01
#   R^2: 0.7588
#   RMSE: 4318.3015
#
# Alpha: 0.1
#   R^2: 0.7588
#   RMSE: 4318.2905
#
# Alpha: 1.0
#   R^2: 0.7588
#   RMSE: 4318.1830
#
# Alpha: 10.0
#   R^2: 0.7589
#   RMSE: 4317.3874
#
# Best Alpha based on RMSE: 10.0
# Best R^2: 0.7589
# Best RMSE: 4317.3874
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 48.9345
#   Curb Weight (lbs): -2.1108
#   Combined MPG: 31.0625
#   Fuel Capacity (gallons): 184.1724
#   Age: -1720.6839
#   Drivetrain_4WD: 3629.9590
#   Drivetrain_AWD: -374.4815
#   Drivetrain_FWD: -1915.5861
#   Drivetrain_RWD: 677.7930
#
# Intercept: 23332.3001

# %% [markdown]
# #### Ridge

# %%
y_price = car_data_encoded['Average KBB Fair Price ($)']
X = car_data_encoded[features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.0001, 0.001, 0.01, 0.1, 1.0]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    Ridge_model = Ridge(alpha=alpha)
    Ridge_model.fit(X_train, y_train)
    y_pred = Ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Unaggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.0001
#   R^2: 0.7588
#   RMSE: 4318.3028
#
# Alpha: 0.001
#   R^2: 0.7588
#   RMSE: 4318.3028
#
# Alpha: 0.01
#   R^2: 0.7588
#   RMSE: 4318.3026
#
# Alpha: 0.1
#   R^2: 0.7588
#   RMSE: 4318.3006
#
# Alpha: 1.0
#   R^2: 0.7588
#   RMSE: 4318.2809
#
# Best Alpha based on RMSE: 1.0
# Best R^2: 0.7588
# Best RMSE: 4318.2809
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 48.9345
#   Curb Weight (lbs): -2.1108
#   Combined MPG: 31.0625
#   Fuel Capacity (gallons): 184.1724
#   Age: -1720.6839
#   Drivetrain_4WD: 3629.9590
#   Drivetrain_AWD: -374.4815
#   Drivetrain_FWD: -1915.5861
#   Drivetrain_RWD: 677.7930
#
# Intercept: 23332.3001

# %% [markdown]
# ### Aggregated

# %%
#aggregated
aggregated_data = df.groupby(['Model Full Name']).agg({
    'Horsepower (hp)': 'mean',
    'Curb Weight (lbs)': 'mean',
    'Combined MPG': 'mean',
    'Fuel Capacity (gallons)': 'mean',
    'Age': 'mean',
    'Average KBB Fair Price ($)': 'mean',
    'Drivetrain': 'first'
}).reset_index()

car_data_encoded_agg = pd.get_dummies(aggregated_data, columns=['Model Full Name', 'Drivetrain'], drop_first=True)

y_price = car_data_encoded_agg['Average KBB Fair Price ($)']
X = car_data_encoded_agg[functional_features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print("Model Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional Aggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.6676
#
# RMSE: 5500.9378
# Model Coefficients:
#   Horsepower (hp): 43.6321
#   Curb Weight (lbs): -0.3676
#   Combined MPG: 68.7316
#   Fuel Capacity (gallons): 230.0007
#   Age: -1975.5590
#   Drivetrain_4WD: 3691.9952
#   Drivetrain_AWD: -1794.9761
#   Drivetrain_FWD: -1417.8011
#   Drivetrain_RWD: -891.4719
#
# Intercept: 18283.2862

# %% [markdown]
# #### Lasso

# %%
y_price = car_data_encoded_agg['Average KBB Fair Price ($)']
X = car_data_encoded_agg[functional_features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Aggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6676
#   RMSE: 5500.6065
#
# Alpha: 1.0
#   R^2: 0.6680
#   RMSE: 5497.6274
#
# Alpha: 10.0
#   R^2: 0.6715
#   RMSE: 5468.1091
#
# Alpha: 100
#   R^2: 0.6834
#   RMSE: 5368.0047
#
# Alpha: 1000
#   R^2: 0.7023
#   RMSE: 5205.9640
#
# Best Alpha based on RMSE: 1000
# Best R^2: 0.7023
# Best RMSE: 5205.9640
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 49.4808
#   Curb Weight (lbs): 0.6178
#   Combined MPG: 60.9700
#   Fuel Capacity (gallons): 71.4483
#   Age: -1914.5963
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: -0.0000
#
# Intercept: 15130.8722

# %% [markdown]
# #### Ridge

# %%
y_price = car_data_encoded_agg['Average KBB Fair Price ($)']
X = car_data_encoded_agg[functional_features]

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional Aggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6679
#   RMSE: 5498.2777
#
# Alpha: 1.0
#   R^2: 0.6705
#   RMSE: 5476.4569
#
# Alpha: 10.0
#   R^2: 0.6834
#   RMSE: 5368.2621
#
# Alpha: 100
#   R^2: 0.6948
#   RMSE: 5270.6930
#
# Alpha: 1000
#   R^2: 0.6432
#   RMSE: 5699.3143
#
# Best Alpha based on RMSE: 100
# Best R^2: 0.6948
# Best RMSE: 5270.6930
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 49.4808
#   Curb Weight (lbs): 0.6178
#   Combined MPG: 60.9700
#   Fuel Capacity (gallons): 71.4483
#   Age: -1914.5963
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: -0.0000
#
# Intercept: 15130.8722

# %% [markdown]
# # Functional and Experiential

# %% [markdown]
# ### Unaggregated

# %%
selected_topics = ['Topic_0', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_7', 'Topic_8', 'Topic_9']

for topic in selected_topics:
    car_data_encoded[f'{topic}_Weighted'] = car_data_encoded[topic] * car_data_encoded['Sentiment Score']

weighted_topic_features = [f'{topic}_Weighted' for topic in selected_topics]
features = functional_features + weighted_topic_features + [col for col in car_data_encoded.columns if col.startswith('Model Full Name_')]

X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.9119
#
# RMSE: 2610.2974
#
# Model Coefficients:
#   Horsepower (hp): 5.6206
#   Curb Weight (lbs): -4.1024
#   Combined MPG: -39.8883
#   Fuel Capacity (gallons): -70.7150
#   Age: -1818.9153
#   Drivetrain_4WD: 408.0925
#   Drivetrain_AWD: -1565.4814
#   Drivetrain_FWD: -4207.0753
#   Drivetrain_RWD: -2462.8216
#   Topic_0_Weighted: -7599.1892
#   Topic_2_Weighted: -1092.6125
#   Topic_3_Weighted: 5602.0659
#   Topic_4_Weighted: -1684.7965
#   Topic_5_Weighted: -3175.9618
#   Topic_7_Weighted: -639.9738
#   Topic_8_Weighted: 716.6864
#   Topic_9_Weighted: -86.9938
#   Model Full Name_Acura Tlx: -802.1584
#   Model Full Name_Alfa-romeo Giulia: -698.0654
#   Model Full Name_Alfa-romeo Stelvio: -2780.3955
#   Model Full Name_Audi A4: -342.5302
#   Model Full Name_Audi A6: 301.2338
#   Model Full Name_Audi Q3: -3598.4843
#   Model Full Name_Audi Q5: -129.4084
#   Model Full Name_Audi Q7: 3581.5054
#   Model Full Name_Bmw 3-series: -954.9996
#   Model Full Name_Bmw 5-series: 53.8052
#   Model Full Name_Bmw X3: -922.8784
#   Model Full Name_Bmw X5: 5803.1581
#   Model Full Name_Buick Enclave: 3093.0315
#   Model Full Name_Buick Encore: -7091.3778
#   Model Full Name_Buick Encore-gx: -7857.5564
#   Model Full Name_Cadillac Ct4: 1858.7757
#   Model Full Name_Cadillac Xt5: 1243.2861
#   Model Full Name_Chevrolet Blazer: -451.8172
#   Model Full Name_Chevrolet Camaro: 1337.0147
#   Model Full Name_Chevrolet Colorado: -3460.9109
#   Model Full Name_Chevrolet Corvette: 18189.5113
#   Model Full Name_Chevrolet Equinox: -2891.7762
#   Model Full Name_Chevrolet Impala: 45.2601
#   Model Full Name_Chevrolet Malibu: -3576.6255
#   Model Full Name_Chevrolet Silverado-1500: -1307.0905
#   Model Full Name_Chevrolet Ss: 12911.9481
#   Model Full Name_Chevrolet Suburban: 10242.1158
#   Model Full Name_Chevrolet Tahoe: 12569.1823
#   Model Full Name_Chevrolet Trailblazer: -3932.0478
#   Model Full Name_Chevrolet Traverse: 630.5909
#   Model Full Name_Chevrolet Trax: -10844.3322
#   Model Full Name_Chrysler 200: -4180.8528
#   Model Full Name_Chrysler 300: 1283.3596
#   Model Full Name_Chrysler Pacifica: -2532.1792
#   Model Full Name_Dodge Challenger: 4956.7382
#   Model Full Name_Dodge Charger: 1035.7877
#   Model Full Name_Dodge Durango: 2355.8304
#   Model Full Name_Fiat 500x: -10971.8419
#   Model Full Name_Ford Bronco: 13813.7661
#   Model Full Name_Ford Bronco-sport: -6003.3846
#   Model Full Name_Ford Escape: -7330.1817
#   Model Full Name_Ford Expedition: 5861.8831
#   Model Full Name_Ford Explorer: -1344.2894
#   Model Full Name_Ford F150: -460.3438
#   Model Full Name_Ford Focus: -2885.1543
#   Model Full Name_Ford Fusion: -2350.7555
#   Model Full Name_Ford Maverick: -1058.6725
#   Model Full Name_Ford Mustang: 5243.7062
#   Model Full Name_Ford Ranger: -3670.5114
#   Model Full Name_Ford Taurus: 3161.4582
#   Model Full Name_Genesis G70: -2606.1593
#   Model Full Name_Genesis G80: 1566.4230
#   Model Full Name_Genesis Gv80: 11347.8498
#   Model Full Name_Gmc Acadia: 209.5765
#   Model Full Name_Gmc Canyon: -2160.1495
#   Model Full Name_Gmc Hummer-ev: 42807.6689
#   Model Full Name_Gmc Sierra-1500: 2503.0555
#   Model Full Name_Gmc Terrain: -3689.7835
#   Model Full Name_Gmc Yukon-xl: 11321.1911
#   Model Full Name_Honda Accord: -1042.9627
#   Model Full Name_Honda Insight: -4960.6540
#   Model Full Name_Honda Odyssey: 3561.4529
#   Model Full Name_Honda Passport: -533.2451
#   Model Full Name_Honda Pilot: 146.4325
#   Model Full Name_Honda Ridgeline: 3388.1163
#   Model Full Name_Hyundai Azera: -1316.9094
#   Model Full Name_Hyundai Elantra: -7609.0339
#   Model Full Name_Hyundai Genesis: -1777.1254
#   Model Full Name_Hyundai Ioniq-5: 248.1613
#   Model Full Name_Hyundai Ioniq-6: 20014.7908
#   Model Full Name_Hyundai Palisade: 2217.3251
#   Model Full Name_Hyundai Sonata: -3265.2655
#   Model Full Name_Hyundai Tucson: -6908.7615
#   Model Full Name_Hyundai Venue: -11849.7859
#   Model Full Name_Infiniti Q50: -1841.1470
#   Model Full Name_Infiniti Qx60: -285.2104
#   Model Full Name_Infiniti Qx80: 4902.2077
#   Model Full Name_Jaguar E-pace: -2701.0327
#   Model Full Name_Jaguar F-pace: -1744.6467
#   Model Full Name_Jaguar I-pace: 6346.7116
#   Model Full Name_Jeep Cherokee: -8873.7323
#   Model Full Name_Jeep Compass: -8084.9783
#   Model Full Name_Jeep Gladiator: 11560.4321
#   Model Full Name_Jeep Grand-wagoneer: 31014.2719
#   Model Full Name_Jeep Renegade: -12128.2970
#   Model Full Name_Jeep Wagoneer: 13867.1747
#   Model Full Name_Jeep Wrangler: 1522.4985
#   Model Full Name_Kia Cadenza: -3787.2804
#   Model Full Name_Kia Carnival: 8057.4156
#   Model Full Name_Kia Ev6: 4638.6681
#   Model Full Name_Kia K5: -5267.8922
#   Model Full Name_Kia K900: -1219.5560
#   Model Full Name_Kia Optima: -3948.1538
#   Model Full Name_Kia Sedona: 778.6613
#   Model Full Name_Kia Seltos: -12397.9909
#   Model Full Name_Kia Sorento: -222.4811
#   Model Full Name_Kia Sportage: -6207.9506
#   Model Full Name_Kia Stinger: -2280.1338
#   Model Full Name_Kia Telluride: 2764.7737
#   Model Full Name_Land-rover Discovery: -6167.9001
#   Model Full Name_Land-rover Range-rover-evoque: -2010.6553
#   Model Full Name_Lexus Es: 3419.5227
#   Model Full Name_Lexus Gx: 12140.0819
#   Model Full Name_Lexus Nx: 3101.9977
#   Model Full Name_Lexus Rx: 7938.9798
#   Model Full Name_Lexus Ux: -2694.8015
#   Model Full Name_Mazda Cx-5: -3392.3202
#   Model Full Name_Mazda Cx-50: 3143.2000
#   Model Full Name_Mazda Cx-9: 740.4640
#   Model Full Name_Mazda Mazda6: -1892.4316
#   Model Full Name_Mazda Mx-5-miata: -5458.1960
#   Model Full Name_Mercedes-benz A-class: -2203.1641
#   Model Full Name_Mercedes-benz C-class: 2555.6179
#   Model Full Name_Mercedes-benz E-class: 1572.6825
#   Model Full Name_Mercedes-benz Glc: -2868.3429
#   Model Full Name_Mercedes-benz Gle: 9676.9439
#   Model Full Name_Mini Countryman: -3728.4332
#   Model Full Name_Mitsubishi Outlander: -6943.9781
#   Model Full Name_Nissan Altima: -4369.3523
#   Model Full Name_Nissan Ariya: 26023.4746
#   Model Full Name_Nissan Armada: 2638.3740
#   Model Full Name_Nissan Frontier: -1100.3831
#   Model Full Name_Nissan Kicks: -13154.6922
#   Model Full Name_Nissan Leaf: -1252.6562
#   Model Full Name_Nissan Maxima: -3135.3514
#   Model Full Name_Nissan Murano: -3322.8522
#   Model Full Name_Nissan Pathfinder: -2584.9233
#   Model Full Name_Nissan Quest: 975.3661
#   Model Full Name_Nissan Rogue: -4742.0299
#   Model Full Name_Nissan Titan: 3524.8543
#   Model Full Name_Porsche Cayenne: 9903.1219
#   Model Full Name_Porsche Macan: 1340.0773
#   Model Full Name_Subaru Ascent: -1671.4890
#   Model Full Name_Subaru Brz: -6621.6493
#   Model Full Name_Subaru Crosstrek: -7253.3576
#   Model Full Name_Subaru Forester: -5306.6710
#   Model Full Name_Subaru Legacy: -4857.8072
#   Model Full Name_Subaru Outback: -4434.8186
#   Model Full Name_Subaru Solterra: 20941.0512
#   Model Full Name_Tesla Model-3: 4812.4494
#   Model Full Name_Tesla Model-s: 15048.1972
#   Model Full Name_Tesla Model-x: 8172.5102
#   Model Full Name_Tesla Model-y: 8388.8352
#   Model Full Name_Toyota 4runner: 11189.8496
#   Model Full Name_Toyota Avalon: 1194.5093
#   Model Full Name_Toyota Camry: -680.4575
#   Model Full Name_Toyota Corolla: -4970.0815
#   Model Full Name_Toyota Crown: 14138.0554
#   Model Full Name_Toyota Highlander: 5131.3227
#   Model Full Name_Toyota Land-cruiser: 24243.4865
#   Model Full Name_Toyota Prius: -172.7541
#   Model Full Name_Toyota Rav4: -983.1048
#   Model Full Name_Toyota Sienna: 9172.6700
#   Model Full Name_Toyota Tacoma: 790.1241
#   Model Full Name_Toyota Tundra: 9509.0613
#   Model Full Name_Toyota Venza: 3370.0597
#   Model Full Name_Volkswagen Arteon: -3254.1004
#   Model Full Name_Volkswagen Atlas: 1177.8672
#   Model Full Name_Volkswagen Golf-gti: -6100.3872
#   Model Full Name_Volkswagen Id-4: 3257.5661
#   Model Full Name_Volkswagen Jetta: -5399.0518
#   Model Full Name_Volkswagen Passat: -3504.3591
#   Model Full Name_Volkswagen Tiguan: -2517.5665
#   Model Full Name_Volvo Xc40: -2689.8106
#   Model Full Name_Volvo Xc60: 738.6906
#   Model Full Name_Volvo Xc90: 1468.2265
#
# Intercept: 50787.5305

# %% [markdown]
# #### Lasso

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.9118
#   RMSE: 2611.6903
#
# Alpha: 1.0
#   R^2: 0.9078
#   RMSE: 2669.6840
#
# Alpha: 10.0
#   R^2: 0.8637
#   RMSE: 3245.9577
#
# Alpha: 100
#   R^2: 0.7569
#   RMSE: 4334.8105
#
# Alpha: 1000
#   R^2: 0.7281
#   RMSE: 4584.6565
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.9118
# Best RMSE: 2611.6903
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 7.2497
#   Curb Weight (lbs): -4.0376
#   Combined MPG: -37.1475
#   Fuel Capacity (gallons): -46.3838
#   Age: -1817.2866
#   Drivetrain_4WD: 459.7536
#   Drivetrain_AWD: -1538.5852
#   Drivetrain_FWD: -4217.1825
#   Drivetrain_RWD: -2336.3824
#   Topic_0_Weighted: -6987.1901
#   Topic_2_Weighted: -735.9657
#   Topic_3_Weighted: 5012.3151
#   Topic_4_Weighted: -1298.8123
#   Topic_5_Weighted: -2833.2141
#   Topic_7_Weighted: -485.4700
#   Topic_8_Weighted: 370.0426
#   Topic_9_Weighted: -0.0000
#   Model Full Name_Acura Tlx: -586.1320
#   Model Full Name_Alfa-romeo Giulia: -670.2321
#   Model Full Name_Alfa-romeo Stelvio: -2686.8654
#   Model Full Name_Audi A4: -92.3178
#   Model Full Name_Audi A6: 317.9367
#   Model Full Name_Audi Q3: -3381.5941
#   Model Full Name_Audi Q5: -88.4533
#   Model Full Name_Audi Q7: 3433.6005
#   Model Full Name_Bmw 3-series: -831.3087
#   Model Full Name_Bmw 5-series: 0.0000
#   Model Full Name_Bmw X3: -837.5738
#   Model Full Name_Bmw X5: 5545.6392
#   Model Full Name_Buick Enclave: 3017.1847
#   Model Full Name_Buick Encore: -6638.7153
#   Model Full Name_Buick Encore-gx: -7384.0406
#   Model Full Name_Cadillac Ct4: 1754.0404
#   Model Full Name_Cadillac Xt5: 1194.7760
#   Model Full Name_Chevrolet Blazer: -243.8655
#   Model Full Name_Chevrolet Camaro: 1178.1899
#   Model Full Name_Chevrolet Colorado: -3259.1198
#   Model Full Name_Chevrolet Corvette: 17889.3614
#   Model Full Name_Chevrolet Equinox: -2604.3753
#   Model Full Name_Chevrolet Impala: 244.8797
#   Model Full Name_Chevrolet Malibu: -3233.2732
#   Model Full Name_Chevrolet Silverado-1500: -1433.9223
#   Model Full Name_Chevrolet Ss: 12571.3935
#   Model Full Name_Chevrolet Suburban: 9824.7429
#   Model Full Name_Chevrolet Tahoe: 12264.6756
#   Model Full Name_Chevrolet Trailblazer: -3591.3843
#   Model Full Name_Chevrolet Traverse: 526.8755
#   Model Full Name_Chevrolet Trax: -10371.2077
#   Model Full Name_Chrysler 200: -3871.6898
#   Model Full Name_Chrysler 300: 1192.5646
#   Model Full Name_Chrysler Pacifica: -2493.8069
#   Model Full Name_Dodge Challenger: 4913.8921
#   Model Full Name_Dodge Charger: 1043.5921
#   Model Full Name_Dodge Durango: 2123.2972
#   Model Full Name_Fiat 500x: -10520.1969
#   Model Full Name_Ford Bronco: 13796.5079
#   Model Full Name_Ford Bronco-sport: -5453.7053
#   Model Full Name_Ford Escape: -7016.3235
#   Model Full Name_Ford Expedition: 5500.8248
#   Model Full Name_Ford Explorer: -1371.7699
#   Model Full Name_Ford F150: -609.4350
#   Model Full Name_Ford Focus: -2514.9809
#   Model Full Name_Ford Fusion: -2127.1803
#   Model Full Name_Ford Maverick: -831.6263
#   Model Full Name_Ford Mustang: 5271.9082
#   Model Full Name_Ford Ranger: -3417.7065
#   Model Full Name_Ford Taurus: 3196.5203
#   Model Full Name_Genesis G70: -2500.9265
#   Model Full Name_Genesis G80: 1350.2512
#   Model Full Name_Genesis Gv80: 11108.7326
#   Model Full Name_Gmc Acadia: 239.7700
#   Model Full Name_Gmc Canyon: -1959.3374
#   Model Full Name_Gmc Hummer-ev: 40984.4769
#   Model Full Name_Gmc Sierra-1500: 2279.3120
#   Model Full Name_Gmc Terrain: -3404.4776
#   Model Full Name_Gmc Yukon-xl: 10844.8072
#   Model Full Name_Honda Accord: -762.3080
#   Model Full Name_Honda Insight: -4620.4131
#   Model Full Name_Honda Odyssey: 3570.9707
#   Model Full Name_Honda Passport: -515.2469
#   Model Full Name_Honda Pilot: 103.8717
#   Model Full Name_Honda Ridgeline: 3317.4516
#   Model Full Name_Hyundai Azera: -1219.1885
#   Model Full Name_Hyundai Elantra: -7154.2328
#   Model Full Name_Hyundai Genesis: -1980.6413
#   Model Full Name_Hyundai Ioniq-5: 0.0000
#   Model Full Name_Hyundai Ioniq-6: 18619.3058
#   Model Full Name_Hyundai Palisade: 2216.3593
#   Model Full Name_Hyundai Sonata: -3045.4653
#   Model Full Name_Hyundai Tucson: -6585.0334
#   Model Full Name_Hyundai Venue: -11259.3871
#   Model Full Name_Infiniti Q50: -1835.8314
#   Model Full Name_Infiniti Qx60: -241.8669
#   Model Full Name_Infiniti Qx80: 4400.1588
#   Model Full Name_Jaguar E-pace: -2393.9302
#   Model Full Name_Jaguar F-pace: -1487.2491
#   Model Full Name_Jaguar I-pace: 5887.0921
#   Model Full Name_Jeep Cherokee: -8569.7556
#   Model Full Name_Jeep Compass: -7756.8799
#   Model Full Name_Jeep Gladiator: 11399.8791
#   Model Full Name_Jeep Grand-wagoneer: 30279.7542
#   Model Full Name_Jeep Renegade: -11761.8401
#   Model Full Name_Jeep Wagoneer: 13462.2010
#   Model Full Name_Jeep Wrangler: 1591.3190
#   Model Full Name_Kia Cadenza: -3706.9147
#   Model Full Name_Kia Carnival: 8006.2485
#   Model Full Name_Kia Ev6: 4408.3016
#   Model Full Name_Kia K5: -4880.4219
#   Model Full Name_Kia K900: -1423.4891
#   Model Full Name_Kia Optima: -3681.8862
#   Model Full Name_Kia Sedona: 766.0167
#   Model Full Name_Kia Seltos: -12078.8745
#   Model Full Name_Kia Sorento: 0.0000
#   Model Full Name_Kia Sportage: -5851.3204
#   Model Full Name_Kia Stinger: -2223.2607
#   Model Full Name_Kia Telluride: 2765.5006
#   Model Full Name_Land-rover Discovery: -6243.0284
#   Model Full Name_Land-rover Range-rover-evoque: -1927.6549
#   Model Full Name_Lexus Es: 3552.1329
#   Model Full Name_Lexus Gx: 11881.1222
#   Model Full Name_Lexus Nx: 3285.3251
#   Model Full Name_Lexus Rx: 7928.1202
#   Model Full Name_Lexus Ux: -2175.6262
#   Model Full Name_Mazda Cx-5: -3041.5952
#   Model Full Name_Mazda Cx-50: 3156.8558
#   Model Full Name_Mazda Cx-9: 779.6739
#   Model Full Name_Mazda Mazda6: -1601.7776
#   Model Full Name_Mazda Mx-5-miata: -5099.8515
#   Model Full Name_Mercedes-benz A-class: -1734.4661
#   Model Full Name_Mercedes-benz C-class: 2591.3854
#   Model Full Name_Mercedes-benz E-class: 1556.6813
#   Model Full Name_Mercedes-benz Glc: -2833.0293
#   Model Full Name_Mercedes-benz Gle: 9463.1319
#   Model Full Name_Mini Countryman: -3205.8632
#   Model Full Name_Mitsubishi Outlander: -6640.2242
#   Model Full Name_Nissan Altima: -4104.4280
#   Model Full Name_Nissan Ariya: 25650.8068
#   Model Full Name_Nissan Armada: 2264.4929
#   Model Full Name_Nissan Frontier: -881.4732
#   Model Full Name_Nissan Kicks: -12572.2012
#   Model Full Name_Nissan Leaf: -1123.3046
#   Model Full Name_Nissan Maxima: -3075.9012
#   Model Full Name_Nissan Murano: -3308.5406
#   Model Full Name_Nissan Pathfinder: -2583.5481
#   Model Full Name_Nissan Quest: 972.4710
#   Model Full Name_Nissan Rogue: -4426.5841
#   Model Full Name_Nissan Titan: 3177.8721
#   Model Full Name_Porsche Cayenne: 9736.8125
#   Model Full Name_Porsche Macan: 1195.6052
#   Model Full Name_Subaru Ascent: -1637.6693
#   Model Full Name_Subaru Brz: -6358.3037
#   Model Full Name_Subaru Crosstrek: -6996.3193
#   Model Full Name_Subaru Forester: -5021.6635
#   Model Full Name_Subaru Legacy: -4634.1086
#   Model Full Name_Subaru Outback: -4222.5533
#   Model Full Name_Subaru Solterra: 20425.2140
#   Model Full Name_Tesla Model-3: 4550.0973
#   Model Full Name_Tesla Model-s: 14672.6221
#   Model Full Name_Tesla Model-x: 8083.6674
#   Model Full Name_Tesla Model-y: 8160.3792
#   Model Full Name_Toyota 4runner: 10991.9657
#   Model Full Name_Toyota Avalon: 1305.9787
#   Model Full Name_Toyota Camry: -402.2398
#   Model Full Name_Toyota Corolla: -4499.9387
#   Model Full Name_Toyota Crown: 14025.1071
#   Model Full Name_Toyota Highlander: 5109.2975
#   Model Full Name_Toyota Land-cruiser: 23797.1123
#   Model Full Name_Toyota Prius: 84.8675
#   Model Full Name_Toyota Rav4: -754.3187
#   Model Full Name_Toyota Sienna: 9197.6529
#   Model Full Name_Toyota Tacoma: 971.6383
#   Model Full Name_Toyota Tundra: 9242.5386
#   Model Full Name_Toyota Venza: 3546.1498
#   Model Full Name_Volkswagen Arteon: -3124.4698
#   Model Full Name_Volkswagen Atlas: 1196.6509
#   Model Full Name_Volkswagen Golf-gti: -5732.8085
#   Model Full Name_Volkswagen Id-4: 2981.3492
#   Model Full Name_Volkswagen Jetta: -4961.3289
#   Model Full Name_Volkswagen Passat: -3295.6861
#   Model Full Name_Volkswagen Tiguan: -2251.2482
#   Model Full Name_Volvo Xc40: -2285.2399
#   Model Full Name_Volvo Xc60: 755.2235
#   Model Full Name_Volvo Xc90: 1462.6327
#
# Intercept: 49495.8805

# %% [markdown]
# #### Ridge

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Unaggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.9117
#   RMSE: 2612.2637
#
# Alpha: 1.0
#   R^2: 0.9092
#   RMSE: 2649.4697
#
# Alpha: 10.0
#   R^2: 0.8938
#   RMSE: 2865.3707
#
# Alpha: 100
#   R^2: 0.8438
#   RMSE: 3474.7130
#
# Alpha: 1000
#   R^2: 0.7739
#   RMSE: 4181.1080
#
# Best Alpha based on RMSE: 0.1
# Best R^2: 0.9117
# Best RMSE: 2612.2637
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 54.9404
#   Curb Weight (lbs): -0.8939
#   Combined MPG: 16.6959
#   Fuel Capacity (gallons): 50.7800
#   Age: -1623.9290
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: 0.0000
#   Topic_0_Weighted: -0.0000
#   Topic_2_Weighted: -0.0000
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: 0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#   Model Full Name_Acura Tlx: -0.0000
#   Model Full Name_Alfa-romeo Giulia: -0.0000
#   Model Full Name_Alfa-romeo Stelvio: -0.0000
#   Model Full Name_Audi A4: 0.0000
#   Model Full Name_Audi A6: -0.0000
#   Model Full Name_Audi Q3: -0.0000
#   Model Full Name_Audi Q5: -0.0000
#   Model Full Name_Audi Q7: -0.0000
#   Model Full Name_Bmw 3-series: 0.0000
#   Model Full Name_Bmw 5-series: -0.0000
#   Model Full Name_Bmw X3: -0.0000
#   Model Full Name_Bmw X5: -0.0000
#   Model Full Name_Buick Enclave: -0.0000
#   Model Full Name_Buick Encore: -0.0000
#   Model Full Name_Buick Encore-gx: -0.0000
#   Model Full Name_Cadillac Ct4: 0.0000
#   Model Full Name_Cadillac Xt5: -0.0000
#   Model Full Name_Chevrolet Blazer: 0.0000
#   Model Full Name_Chevrolet Camaro: -0.0000
#   Model Full Name_Chevrolet Colorado: 0.0000
#   Model Full Name_Chevrolet Corvette: 0.0000
#   Model Full Name_Chevrolet Equinox: -0.0000
#   Model Full Name_Chevrolet Impala: -0.0000
#   Model Full Name_Chevrolet Malibu: -0.0000
#   Model Full Name_Chevrolet Silverado-1500: -0.0000
#   Model Full Name_Chevrolet Ss: 0.0000
#   Model Full Name_Chevrolet Suburban: 0.0000
#   Model Full Name_Chevrolet Tahoe: 0.0000
#   Model Full Name_Chevrolet Trailblazer: 0.0000
#   Model Full Name_Chevrolet Traverse: -0.0000
#   Model Full Name_Chevrolet Trax: -0.0000
#   Model Full Name_Chrysler 200: -0.0000
#   Model Full Name_Chrysler 300: -0.0000
#   Model Full Name_Chrysler Pacifica: -0.0000
#   Model Full Name_Dodge Challenger: 0.0000
#   Model Full Name_Dodge Charger: 0.0000
#   Model Full Name_Dodge Durango: -0.0000
#   Model Full Name_Fiat 500x: -0.0000
#   Model Full Name_Ford Bronco: 0.0000
#   Model Full Name_Ford Bronco-sport: 0.0000
#   Model Full Name_Ford Escape: -0.0000
#   Model Full Name_Ford Expedition: -0.0000
#   Model Full Name_Ford Explorer: -0.0000
#   Model Full Name_Ford F150: -0.0000
#   Model Full Name_Ford Focus: 0.0000
#   Model Full Name_Ford Fusion: -0.0000
#   Model Full Name_Ford Maverick: -0.0000
#   Model Full Name_Ford Mustang: 0.0000
#   Model Full Name_Ford Ranger: 0.0000
#   Model Full Name_Ford Taurus: -0.0000
#   Model Full Name_Genesis G70: -0.0000
#   Model Full Name_Genesis G80: -0.0000
#   Model Full Name_Genesis Gv80: 0.0000
#   Model Full Name_Gmc Acadia: -0.0000
#   Model Full Name_Gmc Canyon: 0.0000
#   Model Full Name_Gmc Hummer-ev: 0.0000
#   Model Full Name_Gmc Sierra-1500: 0.0000
#   Model Full Name_Gmc Terrain: 0.0000
#   Model Full Name_Gmc Yukon-xl: 0.0000
#   Model Full Name_Honda Accord: 0.0000
#   Model Full Name_Honda Insight: -0.0000
#   Model Full Name_Honda Odyssey: -0.0000
#   Model Full Name_Honda Passport: -0.0000
#   Model Full Name_Honda Pilot: -0.0000
#   Model Full Name_Honda Ridgeline: 0.0000
#   Model Full Name_Hyundai Azera: -0.0000
#   Model Full Name_Hyundai Elantra: -0.0000
#   Model Full Name_Hyundai Genesis: -0.0000
#   Model Full Name_Hyundai Ioniq-5: -0.0000
#   Model Full Name_Hyundai Ioniq-6: 0.0000
#   Model Full Name_Hyundai Palisade: -0.0000
#   Model Full Name_Hyundai Sonata: -0.0000
#   Model Full Name_Hyundai Tucson: -0.0000
#   Model Full Name_Hyundai Venue: -0.0000
#   Model Full Name_Infiniti Q50: -0.0000
#   Model Full Name_Infiniti Qx60: -0.0000
#   Model Full Name_Infiniti Qx80: -0.0000
#   Model Full Name_Jaguar E-pace: -0.0000
#   Model Full Name_Jaguar F-pace: 0.0000
#   Model Full Name_Jaguar I-pace: -0.0000
#   Model Full Name_Jeep Cherokee: -0.0000
#   Model Full Name_Jeep Compass: -0.0000
#   Model Full Name_Jeep Gladiator: 0.0000
#   Model Full Name_Jeep Grand-wagoneer: 0.0000
#   Model Full Name_Jeep Renegade: -0.0000
#   Model Full Name_Jeep Wagoneer: 0.0000
#   Model Full Name_Jeep Wrangler: 0.0000
#   Model Full Name_Kia Cadenza: -0.0000
#   Model Full Name_Kia Carnival: 0.0000
#   Model Full Name_Kia Ev6: 0.0000
#   Model Full Name_Kia K5: -0.0000
#   Model Full Name_Kia K900: -0.0000
#   Model Full Name_Kia Optima: -0.0000
#   Model Full Name_Kia Sedona: -0.0000
#   Model Full Name_Kia Seltos: -0.0000
#   Model Full Name_Kia Sorento: 0.0000
#   Model Full Name_Kia Sportage: 0.0000
#   Model Full Name_Kia Stinger: -0.0000
#   Model Full Name_Kia Telluride: -0.0000
#   Model Full Name_Land-rover Discovery: -0.0000
#   Model Full Name_Land-rover Range-rover-evoque: -0.0000
#   Model Full Name_Lexus Es: 0.0000
#   Model Full Name_Lexus Gx: 0.0000
#   Model Full Name_Lexus Nx: 0.0000
#   Model Full Name_Lexus Rx: 0.0000
#   Model Full Name_Lexus Ux: 0.0000
#   Model Full Name_Mazda Cx-5: -0.0000
#   Model Full Name_Mazda Cx-50: 0.0000
#   Model Full Name_Mazda Cx-9: -0.0000
#   Model Full Name_Mazda Mazda6: 0.0000
#   Model Full Name_Mazda Mx-5-miata: 0.0000
#   Model Full Name_Mercedes-benz A-class: 0.0000
#   Model Full Name_Mercedes-benz C-class: 0.0000
#   Model Full Name_Mercedes-benz E-class: 0.0000
#   Model Full Name_Mercedes-benz Glc: -0.0000
#   Model Full Name_Mercedes-benz Gle: 0.0000
#   Model Full Name_Mini Countryman: 0.0000
#   Model Full Name_Mitsubishi Outlander: 0.0000
#   Model Full Name_Nissan Altima: -0.0000
#   Model Full Name_Nissan Ariya: 0.0000
#   Model Full Name_Nissan Armada: -0.0000
#   Model Full Name_Nissan Frontier: 0.0000
#   Model Full Name_Nissan Kicks: -0.0000
#   Model Full Name_Nissan Leaf: -0.0000
#   Model Full Name_Nissan Maxima: -0.0000
#   Model Full Name_Nissan Murano: -0.0000
#   Model Full Name_Nissan Pathfinder: -0.0000
#   Model Full Name_Nissan Quest: -0.0000
#   Model Full Name_Nissan Rogue: 0.0000
#   Model Full Name_Nissan Titan: -0.0000
#   Model Full Name_Porsche Cayenne: 0.0000
#   Model Full Name_Porsche Macan: -0.0000
#   Model Full Name_Subaru Ascent: -0.0000
#   Model Full Name_Subaru Brz: -0.0000
#   Model Full Name_Subaru Crosstrek: -0.0000
#   Model Full Name_Subaru Forester: 0.0000
#   Model Full Name_Subaru Legacy: 0.0000
#   Model Full Name_Subaru Outback: 0.0000
#   Model Full Name_Subaru Solterra: 0.0000
#   Model Full Name_Tesla Model-3: 0.0000
#   Model Full Name_Tesla Model-s: 0.0000
#   Model Full Name_Tesla Model-x: 0.0000
#   Model Full Name_Tesla Model-y: 0.0000
#   Model Full Name_Toyota 4runner: 0.0000
#   Model Full Name_Toyota Avalon: -0.0000
#   Model Full Name_Toyota Camry: 0.0000
#   Model Full Name_Toyota Corolla: 0.0000
#   Model Full Name_Toyota Crown: 0.0000
#   Model Full Name_Toyota Highlander: 0.0000
#   Model Full Name_Toyota Land-cruiser: 0.0000
#   Model Full Name_Toyota Prius: -0.0000
#   Model Full Name_Toyota Rav4: 0.0000
#   Model Full Name_Toyota Sienna: 0.0000
#   Model Full Name_Toyota Tacoma: 0.0000
#   Model Full Name_Toyota Tundra: 0.0000
#   Model Full Name_Toyota Venza: 0.0000
#   Model Full Name_Volkswagen Arteon: -0.0000
#   Model Full Name_Volkswagen Atlas: -0.0000
#   Model Full Name_Volkswagen Golf-gti: -0.0000
#   Model Full Name_Volkswagen Id-4: -0.0000
#   Model Full Name_Volkswagen Jetta: 0.0000
#   Model Full Name_Volkswagen Passat: -0.0000
#   Model Full Name_Volkswagen Tiguan: 0.0000
#   Model Full Name_Volvo Xc40: 0.0000
#   Model Full Name_Volvo Xc60: -0.0000
#   Model Full Name_Volvo Xc90: -0.0000
#
# Intercept: 18759.0061

# %% [markdown]
# ### Aggregated

# %%
#aggregated
selected_topics = ['Topic_0', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_7', 'Topic_8', 'Topic_9']

for topic in selected_topics:
    df[f'{topic}_Weighted'] = df[topic] * df['Sentiment Score']

df = pd.get_dummies(df, columns=['Drivetrain'], drop_first=True)

aggregation_dict = {
    feature: 'mean' if feature != 'Drivetrain' else 'first'
    for feature in functional_features + [f'{topic}_Weighted' for topic in selected_topics] + ['Sentiment Score', 'Average KBB Fair Price ($)']
}
aggregated_data = df.groupby(['Model Full Name']).agg(aggregation_dict).reset_index()

car_data_encoded = pd.get_dummies(aggregated_data, columns=['Model Full Name'], drop_first=True)

weighted_topic_features = [f'{topic}_Weighted' for topic in selected_topics]
features = functional_features + weighted_topic_features + [col for col in car_data_encoded.columns if col.startswith('Model Full Name_')]

X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

price_model = LinearRegression()
price_model.fit(X_train, y_train)
y_pred = price_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))


price_coefficients = dict(zip(X.columns, price_model.coef_))

# Print R^2 and RMSE
print(f"R^2: {r2:.4f}")
print(f"\nRMSE: {rmse:.4f}")

# Print Model Coefficients
print(f"\nModel Coefficients:")
for feature, coef in price_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept
print(f"\nIntercept: {price_model.intercept_:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Linear Regression"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": None,
    "R^2": r2,
    "RMSE": rmse
})
# Out:
# R^2: 0.7089
#
# RMSE: 5147.9545
#
# Model Coefficients:
#   Horsepower (hp): 44.6699
#   Curb Weight (lbs): -0.1154
#   Combined MPG: 63.7918
#   Fuel Capacity (gallons): 74.6505
#   Age: -1883.8054
#   Drivetrain_4WD: 4668.9724
#   Drivetrain_AWD: -676.3371
#   Drivetrain_FWD: -1527.3354
#   Drivetrain_RWD: -813.3311
#   Topic_0_Weighted: 39.2581
#   Topic_2_Weighted: -158.9767
#   Topic_3_Weighted: 233.5348
#   Topic_4_Weighted: 378.0856
#   Topic_5_Weighted: 374.8409
#   Topic_7_Weighted: -278.9404
#   Topic_8_Weighted: 122.8339
#   Topic_9_Weighted: 107.0679
#   Model Full Name_Acura Tlx: 90.4122
#   Model Full Name_Alfa-romeo Giulia: -1633.3511
#   Model Full Name_Alfa-romeo Stelvio: -2984.2098
#   Model Full Name_Audi A4: 1238.1802
#   Model Full Name_Audi A6: 37.2312
#   Model Full Name_Audi Q3: -0.0000
#   Model Full Name_Audi Q5: -346.3178
#   Model Full Name_Audi Q7: -939.7253
#   Model Full Name_Bmw 3-series: -0.0000
#   Model Full Name_Bmw 5-series: -1297.0023
#   Model Full Name_Bmw X3: -771.0912
#   Model Full Name_Bmw X5: -0.0000
#   Model Full Name_Buick Enclave: -2578.5950
#   Model Full Name_Buick Encore: -844.5693
#   Model Full Name_Buick Encore-gx: -4209.9709
#   Model Full Name_Cadillac Ct4: 3149.3234
#   Model Full Name_Cadillac Xt5: -2853.7040
#   Model Full Name_Chevrolet Blazer: 447.7501
#   Model Full Name_Chevrolet Camaro: -812.1479
#   Model Full Name_Chevrolet Colorado: 1291.0091
#   Model Full Name_Chevrolet Corvette: -0.0000
#   Model Full Name_Chevrolet Equinox: -133.8984
#   Model Full Name_Chevrolet Impala: 2372.3730
#   Model Full Name_Chevrolet Malibu: 175.2656
#   Model Full Name_Chevrolet Silverado-1500: -0.0000
#   Model Full Name_Chevrolet Ss: -0.0000
#   Model Full Name_Chevrolet Suburban: 405.0709
#   Model Full Name_Chevrolet Tahoe: 1033.5486
#   Model Full Name_Chevrolet Trailblazer: -1250.6774
#   Model Full Name_Chevrolet Traverse: -0.0000
#   Model Full Name_Chevrolet Trax: -3966.2575
#   Model Full Name_Chrysler 200: -658.4942
#   Model Full Name_Chrysler 300: 895.4147
#   Model Full Name_Chrysler Pacifica: -7042.5018
#   Model Full Name_Dodge Challenger: 6163.8860
#   Model Full Name_Dodge Charger: 0.0000
#   Model Full Name_Dodge Durango: -2846.5557
#   Model Full Name_Fiat 500x: -5289.5540
#   Model Full Name_Ford Bronco: 9356.9060
#   Model Full Name_Ford Bronco-sport: -4774.3678
#   Model Full Name_Ford Escape: -2150.2902
#   Model Full Name_Ford Expedition: -5592.8521
#   Model Full Name_Ford Explorer: -3668.6084
#   Model Full Name_Ford F150: -2002.5510
#   Model Full Name_Ford Focus: -0.3359
#   Model Full Name_Ford Fusion: -1009.0725
#   Model Full Name_Ford Maverick: -0.0000
#   Model Full Name_Ford Mustang: -0.0000
#   Model Full Name_Ford Ranger: 2160.3301
#   Model Full Name_Ford Taurus: 1259.3799
#   Model Full Name_Genesis G70: -1512.4841
#   Model Full Name_Genesis G80: -3539.6336
#   Model Full Name_Genesis Gv80: 8928.5082
#   Model Full Name_Gmc Acadia: -1204.7215
#   Model Full Name_Gmc Canyon: 2471.3642
#   Model Full Name_Gmc Hummer-ev: 1145.2169
#   Model Full Name_Gmc Sierra-1500: -51.8063
#   Model Full Name_Gmc Terrain: 157.5754
#   Model Full Name_Gmc Yukon-xl: -2235.5647
#   Model Full Name_Honda Accord: 2403.5307
#   Model Full Name_Honda Insight: -2522.8941
#   Model Full Name_Honda Odyssey: -16.9939
#   Model Full Name_Honda Passport: -2427.6828
#   Model Full Name_Honda Pilot: -3230.9031
#   Model Full Name_Honda Ridgeline: -0.0000
#   Model Full Name_Hyundai Azera: -1756.1451
#   Model Full Name_Hyundai Elantra: -602.7918
#   Model Full Name_Hyundai Genesis: -5429.4925
#   Model Full Name_Hyundai Ioniq-5: -7907.0319
#   Model Full Name_Hyundai Ioniq-6: 11319.9705
#   Model Full Name_Hyundai Palisade: 0.0000
#   Model Full Name_Hyundai Sonata: -0.0000
#   Model Full Name_Hyundai Tucson: -1737.8256
#   Model Full Name_Hyundai Venue: -3347.0788
#   Model Full Name_Infiniti Q50: -2426.3732
#   Model Full Name_Infiniti Qx60: -2603.8039
#   Model Full Name_Infiniti Qx80: -8641.6931
#   Model Full Name_Jaguar E-pace: -0.0000
#   Model Full Name_Jaguar F-pace: 663.0192
#   Model Full Name_Jaguar I-pace: -8077.4345
#   Model Full Name_Jeep Cherokee: -4028.6951
#   Model Full Name_Jeep Compass: -0.0000
#   Model Full Name_Jeep Gladiator: 3896.9371
#   Model Full Name_Jeep Grand-wagoneer: 9091.6087
#   Model Full Name_Jeep Renegade: -8777.3215
#   Model Full Name_Jeep Wagoneer: 5044.8647
#   Model Full Name_Jeep Wrangler: -396.3574
#   Model Full Name_Kia Cadenza: -5748.2863
#   Model Full Name_Kia Carnival: 0.0000
#   Model Full Name_Kia Ev6: -2996.0613
#   Model Full Name_Kia K5: -1455.6527
#   Model Full Name_Kia K900: -7695.0210
#   Model Full Name_Kia Optima: -175.8868
#   Model Full Name_Kia Sedona: -2936.9390
#   Model Full Name_Kia Seltos: -5601.5469
#   Model Full Name_Kia Sorento: 1041.1327
#   Model Full Name_Kia Sportage: 440.4784
#   Model Full Name_Kia Stinger: -2179.6902
#   Model Full Name_Kia Telluride: -1298.8277
#   Model Full Name_Land-rover Discovery: -12317.4806
#   Model Full Name_Land-rover Range-rover-evoque: 0.0000
#   Model Full Name_Lexus Es: 2659.5544
#   Model Full Name_Lexus Gx: 1967.3740
#   Model Full Name_Lexus Nx: 2987.4839
#   Model Full Name_Lexus Rx: 5223.3334
#   Model Full Name_Lexus Ux: 1984.4953
#   Model Full Name_Mazda Cx-5: 434.6947
#   Model Full Name_Mazda Cx-50: 6355.3455
#   Model Full Name_Mazda Cx-9: -2044.9624
#   Model Full Name_Mazda Mazda6: 2211.3609
#   Model Full Name_Mazda Mx-5-miata: 4292.4306
#   Model Full Name_Mercedes-benz A-class: 1363.2298
#   Model Full Name_Mercedes-benz C-class: 0.0000
#   Model Full Name_Mercedes-benz E-class: 2307.3949
#   Model Full Name_Mercedes-benz Glc: 0.0000
#   Model Full Name_Mercedes-benz Gle: 5849.5774
#   Model Full Name_Mini Countryman: 0.0000
#   Model Full Name_Mitsubishi Outlander: -2097.2156
#   Model Full Name_Nissan Altima: -530.9068
#   Model Full Name_Nissan Ariya: 15811.8330
#   Model Full Name_Nissan Armada: 0.0000
#   Model Full Name_Nissan Frontier: 5063.4099
#   Model Full Name_Nissan Kicks: -4609.6686
#   Model Full Name_Nissan Leaf: 0.0000
#   Model Full Name_Nissan Maxima: 0.0000
#   Model Full Name_Nissan Murano: -3586.5981
#   Model Full Name_Nissan Pathfinder: -5192.6061
#   Model Full Name_Nissan Quest: -2299.9513
#   Model Full Name_Nissan Rogue: 0.0000
#   Model Full Name_Nissan Titan: -5432.5771
#   Model Full Name_Porsche Cayenne: 0.0000
#   Model Full Name_Porsche Macan: -2313.6932
#   Model Full Name_Subaru Ascent: -4039.3676
#   Model Full Name_Subaru Brz: -100.9850
#   Model Full Name_Subaru Crosstrek: -2674.8970
#   Model Full Name_Subaru Forester: 0.0000
#   Model Full Name_Subaru Legacy: 322.5266
#   Model Full Name_Subaru Outback: 70.5304
#   Model Full Name_Subaru Solterra: 0.0000
#   Model Full Name_Tesla Model-3: -3204.0575
#   Model Full Name_Tesla Model-s: 0.0000
#   Model Full Name_Tesla Model-x: 6125.2445
#   Model Full Name_Tesla Model-y: -3061.6043
#   Model Full Name_Toyota 4runner: 0.0000
#   Model Full Name_Toyota Avalon: 651.0295
#   Model Full Name_Toyota Camry: 0.0000
#   Model Full Name_Toyota Corolla: 2330.0925
#   Model Full Name_Toyota Crown: 0.0000
#   Model Full Name_Toyota Highlander: 3102.0483
#   Model Full Name_Toyota Land-cruiser: 9425.5633
#   Model Full Name_Toyota Prius: 665.1714
#   Model Full Name_Toyota Rav4: 868.1088
#   Model Full Name_Toyota Sienna: 0.0000
#   Model Full Name_Toyota Tacoma: 6822.2221
#   Model Full Name_Toyota Tundra: 2409.8977
#   Model Full Name_Toyota Venza: 4095.6300
#   Model Full Name_Volkswagen Arteon: -3455.9340
#   Model Full Name_Volkswagen Atlas: 0.0000
#   Model Full Name_Volkswagen Golf-gti: -1910.7691
#   Model Full Name_Volkswagen Id-4: -6003.4005
#   Model Full Name_Volkswagen Jetta: 1207.2057
#   Model Full Name_Volkswagen Passat: -900.7217
#   Model Full Name_Volkswagen Tiguan: 0.0000
#   Model Full Name_Volvo Xc40: -314.6148
#   Model Full Name_Volvo Xc60: 322.4474
#   Model Full Name_Volvo Xc90: -6.3945
#
# Intercept: 19476.1540

# %% [markdown]
# #### lasso

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred = lasso_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Lasso"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6958
#   RMSE: 5262.2706
#
# Alpha: 1.0
#   R^2: 0.6421
#   RMSE: 5707.3696
#
# Alpha: 10.0
#   R^2: 0.6359
#   RMSE: 5757.0751
#
# Alpha: 100
#   R^2: 0.6842
#   RMSE: 5361.5088
#
# Alpha: 1000
#   R^2: 0.7023
#   RMSE: 5205.9640
#
# Best Alpha based on RMSE: 1000
# Best R^2: 0.7023
# Best RMSE: 5205.9640
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 49.4808
#   Curb Weight (lbs): 0.6178
#   Combined MPG: 60.9700
#   Fuel Capacity (gallons): 71.4483
#   Age: -1914.5963
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: -0.0000
#   Topic_0_Weighted: -0.0000
#   Topic_2_Weighted: -0.0000
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: 0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#   Model Full Name_Acura Tlx: -0.0000
#   Model Full Name_Alfa-romeo Giulia: -0.0000
#   Model Full Name_Alfa-romeo Stelvio: -0.0000
#   Model Full Name_Audi A4: 0.0000
#   Model Full Name_Audi A6: -0.0000
#   Model Full Name_Audi Q3: 0.0000
#   Model Full Name_Audi Q5: -0.0000
#   Model Full Name_Audi Q7: -0.0000
#   Model Full Name_Bmw 3-series: 0.0000
#   Model Full Name_Bmw 5-series: -0.0000
#   Model Full Name_Bmw X3: -0.0000
#   Model Full Name_Bmw X5: 0.0000
#   Model Full Name_Buick Enclave: -0.0000
#   Model Full Name_Buick Encore: -0.0000
#   Model Full Name_Buick Encore-gx: -0.0000
#   Model Full Name_Cadillac Ct4: 0.0000
#   Model Full Name_Cadillac Xt5: -0.0000
#   Model Full Name_Chevrolet Blazer: -0.0000
#   Model Full Name_Chevrolet Camaro: -0.0000
#   Model Full Name_Chevrolet Colorado: 0.0000
#   Model Full Name_Chevrolet Corvette: 0.0000
#   Model Full Name_Chevrolet Equinox: -0.0000
#   Model Full Name_Chevrolet Impala: 0.0000
#   Model Full Name_Chevrolet Malibu: 0.0000
#   Model Full Name_Chevrolet Silverado-1500: 0.0000
#   Model Full Name_Chevrolet Ss: 0.0000
#   Model Full Name_Chevrolet Suburban: -0.0000
#   Model Full Name_Chevrolet Tahoe: 0.0000
#   Model Full Name_Chevrolet Trailblazer: -0.0000
#   Model Full Name_Chevrolet Traverse: 0.0000
#   Model Full Name_Chevrolet Trax: -0.0000
#   Model Full Name_Chrysler 200: -0.0000
#   Model Full Name_Chrysler 300: 0.0000
#   Model Full Name_Chrysler Pacifica: -0.0000
#   Model Full Name_Dodge Challenger: 0.0000
#   Model Full Name_Dodge Charger: 0.0000
#   Model Full Name_Dodge Durango: -0.0000
#   Model Full Name_Fiat 500x: -0.0000
#   Model Full Name_Ford Bronco: 0.0000
#   Model Full Name_Ford Bronco-sport: 0.0000
#   Model Full Name_Ford Escape: -0.0000
#   Model Full Name_Ford Expedition: -0.0000
#   Model Full Name_Ford Explorer: -0.0000
#   Model Full Name_Ford F150: -0.0000
#   Model Full Name_Ford Focus: 0.0000
#   Model Full Name_Ford Fusion: -0.0000
#   Model Full Name_Ford Maverick: 0.0000
#   Model Full Name_Ford Mustang: 0.0000
#   Model Full Name_Ford Ranger: 0.0000
#   Model Full Name_Ford Taurus: 0.0000
#   Model Full Name_Genesis G70: -0.0000
#   Model Full Name_Genesis G80: -0.0000
#   Model Full Name_Genesis Gv80: 0.0000
#   Model Full Name_Gmc Acadia: -0.0000
#   Model Full Name_Gmc Canyon: 0.0000
#   Model Full Name_Gmc Hummer-ev: 0.0000
#   Model Full Name_Gmc Sierra-1500: 0.0000
#   Model Full Name_Gmc Terrain: 0.0000
#   Model Full Name_Gmc Yukon-xl: 0.0000
#   Model Full Name_Honda Accord: 0.0000
#   Model Full Name_Honda Insight: -0.0000
#   Model Full Name_Honda Odyssey: -0.0000
#   Model Full Name_Honda Passport: -0.0000
#   Model Full Name_Honda Pilot: -0.0000
#   Model Full Name_Honda Ridgeline: 0.0000
#   Model Full Name_Hyundai Azera: -0.0000
#   Model Full Name_Hyundai Elantra: -0.0000
#   Model Full Name_Hyundai Genesis: -0.0000
#   Model Full Name_Hyundai Ioniq-5: -0.0000
#   Model Full Name_Hyundai Ioniq-6: 0.0000
#   Model Full Name_Hyundai Palisade: 0.0000
#   Model Full Name_Hyundai Sonata: 0.0000
#   Model Full Name_Hyundai Tucson: -0.0000
#   Model Full Name_Hyundai Venue: -0.0000
#   Model Full Name_Infiniti Q50: -0.0000
#   Model Full Name_Infiniti Qx60: -0.0000
#   Model Full Name_Infiniti Qx80: -0.0000
#   Model Full Name_Jaguar E-pace: 0.0000
#   Model Full Name_Jaguar F-pace: 0.0000
#   Model Full Name_Jaguar I-pace: -0.0000
#   Model Full Name_Jeep Cherokee: -0.0000
#   Model Full Name_Jeep Compass: 0.0000
#   Model Full Name_Jeep Gladiator: 0.0000
#   Model Full Name_Jeep Grand-wagoneer: 0.0000
#   Model Full Name_Jeep Renegade: -0.0000
#   Model Full Name_Jeep Wagoneer: 0.0000
#   Model Full Name_Jeep Wrangler: 0.0000
#   Model Full Name_Kia Cadenza: -0.0000
#   Model Full Name_Kia Carnival: 0.0000
#   Model Full Name_Kia Ev6: -0.0000
#   Model Full Name_Kia K5: -0.0000
#   Model Full Name_Kia K900: -0.0000
#   Model Full Name_Kia Optima: -0.0000
#   Model Full Name_Kia Sedona: -0.0000
#   Model Full Name_Kia Seltos: -0.0000
#   Model Full Name_Kia Sorento: 0.0000
#   Model Full Name_Kia Sportage: 0.0000
#   Model Full Name_Kia Stinger: -0.0000
#   Model Full Name_Kia Telluride: -0.0000
#   Model Full Name_Land-rover Discovery: -0.0000
#   Model Full Name_Land-rover Range-rover-evoque: 0.0000
#   Model Full Name_Lexus Es: 0.0000
#   Model Full Name_Lexus Gx: 0.0000
#   Model Full Name_Lexus Nx: 0.0000
#   Model Full Name_Lexus Rx: 0.0000
#   Model Full Name_Lexus Ux: 0.0000
#   Model Full Name_Mazda Cx-5: 0.0000
#   Model Full Name_Mazda Cx-50: 0.0000
#   Model Full Name_Mazda Cx-9: -0.0000
#   Model Full Name_Mazda Mazda6: 0.0000
#   Model Full Name_Mazda Mx-5-miata: 0.0000
#   Model Full Name_Mercedes-benz A-class: 0.0000
#   Model Full Name_Mercedes-benz C-class: 0.0000
#   Model Full Name_Mercedes-benz E-class: 0.0000
#   Model Full Name_Mercedes-benz Glc: 0.0000
#   Model Full Name_Mercedes-benz Gle: 0.0000
#   Model Full Name_Mini Countryman: 0.0000
#   Model Full Name_Mitsubishi Outlander: 0.0000
#   Model Full Name_Nissan Altima: -0.0000
#   Model Full Name_Nissan Ariya: 0.0000
#   Model Full Name_Nissan Armada: 0.0000
#   Model Full Name_Nissan Frontier: 0.0000
#   Model Full Name_Nissan Kicks: -0.0000
#   Model Full Name_Nissan Leaf: 0.0000
#   Model Full Name_Nissan Maxima: 0.0000
#   Model Full Name_Nissan Murano: -0.0000
#   Model Full Name_Nissan Pathfinder: -0.0000
#   Model Full Name_Nissan Quest: -0.0000
#   Model Full Name_Nissan Rogue: 0.0000
#   Model Full Name_Nissan Titan: -0.0000
#   Model Full Name_Porsche Cayenne: 0.0000
#   Model Full Name_Porsche Macan: -0.0000
#   Model Full Name_Subaru Ascent: -0.0000
#   Model Full Name_Subaru Brz: 0.0000
#   Model Full Name_Subaru Crosstrek: -0.0000
#   Model Full Name_Subaru Forester: 0.0000
#   Model Full Name_Subaru Legacy: 0.0000
#   Model Full Name_Subaru Outback: 0.0000
#   Model Full Name_Subaru Solterra: 0.0000
#   Model Full Name_Tesla Model-3: -0.0000
#   Model Full Name_Tesla Model-s: 0.0000
#   Model Full Name_Tesla Model-x: 0.0000
#   Model Full Name_Tesla Model-y: -0.0000
#   Model Full Name_Toyota 4runner: 0.0000
#   Model Full Name_Toyota Avalon: 0.0000
#   Model Full Name_Toyota Camry: 0.0000
#   Model Full Name_Toyota Corolla: 0.0000
#   Model Full Name_Toyota Crown: 0.0000
#   Model Full Name_Toyota Highlander: 0.0000
#   Model Full Name_Toyota Land-cruiser: 0.0000
#   Model Full Name_Toyota Prius: 0.0000
#   Model Full Name_Toyota Rav4: 0.0000
#   Model Full Name_Toyota Sienna: 0.0000
#   Model Full Name_Toyota Tacoma: 0.0000
#   Model Full Name_Toyota Tundra: 0.0000
#   Model Full Name_Toyota Venza: 0.0000
#   Model Full Name_Volkswagen Arteon: -0.0000
#   Model Full Name_Volkswagen Atlas: 0.0000
#   Model Full Name_Volkswagen Golf-gti: -0.0000
#   Model Full Name_Volkswagen Id-4: -0.0000
#   Model Full Name_Volkswagen Jetta: 0.0000
#   Model Full Name_Volkswagen Passat: -0.0000
#   Model Full Name_Volkswagen Tiguan: 0.0000
#   Model Full Name_Volvo Xc40: -0.0000
#   Model Full Name_Volvo Xc60: 0.0000
#   Model Full Name_Volvo Xc90: -0.0000
#
# Intercept: 15130.8722
# C:\Users\nehab\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.459e+06, tolerance: 1.403e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\nehab\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.043e+07, tolerance: 1.403e+06
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# #### Ridge

# %%
X = car_data_encoded[features]
y_price = car_data_encoded['Average KBB Fair Price ($)']

X_train, X_test, y_train, y_test = train_test_split(X, y_price, test_size=0.2, random_state=15)

alpha_values = [0.1, 1.0, 10.0, 100, 1000]
best_rmse = float('inf')  # Initialize with a very high RMSE
best_alpha = None
best_coefficients = None
best_intercept = None

# Loop through each alpha value
for alpha in alpha_values:
    # Initialize and train the Lasso model with the current alpha
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred = ridge_model.predict(X_test)
    
    # Calculate evaluation metrics
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Print RMSE and R^2 for this alpha
    print(f"\nAlpha: {alpha}")
    print(f"  R^2: {r2:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    
    # Check if this model has the best RMSE so far
    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha
        best_r2 = r2
        best_coefficients = dict(zip(X.columns, lasso_model.coef_))
        best_intercept = lasso_model.intercept_

# Print the best alpha and its coefficients
print(f"\nBest Alpha based on RMSE: {best_alpha}")
print(f"Best R^2: {best_r2:.4f}")
print(f"Best RMSE: {best_rmse:.4f}")

# Print coefficients for the best alpha
print("\nModel Coefficients for the Best Alpha:")
for feature, coef in best_coefficients.items():
    print(f"  {feature}: {coef:.4f}")

# Print Intercept for the best alpha
print(f"\nIntercept: {best_intercept:.4f}")

division_title = "Functional & Experiential Aggregated"
model_type = "Ridge"

results_list.append({
    "Division Title": division_title,
    "Model Type": model_type,
    "Best Alpha": best_alpha,
    "R^2": best_r2,
    "RMSE": best_rmse
})
# Out:
# Alpha: 0.1
#   R^2: 0.6821
#   RMSE: 5379.0355
#
# Alpha: 1.0
#   R^2: 0.6785
#   RMSE: 5409.6371
#
# Alpha: 10.0
#   R^2: 0.6898
#   RMSE: 5314.0398
#
# Alpha: 100
#   R^2: 0.6960
#   RMSE: 5260.3338
#
# Alpha: 1000
#   R^2: 0.6432
#   RMSE: 5698.8766
#
# Best Alpha based on RMSE: 100
# Best R^2: 0.6960
# Best RMSE: 5260.3338
#
# Model Coefficients for the Best Alpha:
#   Horsepower (hp): 49.4808
#   Curb Weight (lbs): 0.6178
#   Combined MPG: 60.9700
#   Fuel Capacity (gallons): 71.4483
#   Age: -1914.5963
#   Drivetrain_4WD: 0.0000
#   Drivetrain_AWD: -0.0000
#   Drivetrain_FWD: -0.0000
#   Drivetrain_RWD: -0.0000
#   Topic_0_Weighted: -0.0000
#   Topic_2_Weighted: -0.0000
#   Topic_3_Weighted: 0.0000
#   Topic_4_Weighted: 0.0000
#   Topic_5_Weighted: 0.0000
#   Topic_7_Weighted: -0.0000
#   Topic_8_Weighted: 0.0000
#   Topic_9_Weighted: 0.0000
#   Model Full Name_Acura Tlx: -0.0000
#   Model Full Name_Alfa-romeo Giulia: -0.0000
#   Model Full Name_Alfa-romeo Stelvio: -0.0000
#   Model Full Name_Audi A4: 0.0000
#   Model Full Name_Audi A6: -0.0000
#   Model Full Name_Audi Q3: 0.0000
#   Model Full Name_Audi Q5: -0.0000
#   Model Full Name_Audi Q7: -0.0000
#   Model Full Name_Bmw 3-series: 0.0000
#   Model Full Name_Bmw 5-series: -0.0000
#   Model Full Name_Bmw X3: -0.0000
#   Model Full Name_Bmw X5: 0.0000
#   Model Full Name_Buick Enclave: -0.0000
#   Model Full Name_Buick Encore: -0.0000
#   Model Full Name_Buick Encore-gx: -0.0000
#   Model Full Name_Cadillac Ct4: 0.0000
#   Model Full Name_Cadillac Xt5: -0.0000
#   Model Full Name_Chevrolet Blazer: -0.0000
#   Model Full Name_Chevrolet Camaro: -0.0000
#   Model Full Name_Chevrolet Colorado: 0.0000
#   Model Full Name_Chevrolet Corvette: 0.0000
#   Model Full Name_Chevrolet Equinox: -0.0000
#   Model Full Name_Chevrolet Impala: 0.0000
#   Model Full Name_Chevrolet Malibu: 0.0000
#   Model Full Name_Chevrolet Silverado-1500: 0.0000
#   Model Full Name_Chevrolet Ss: 0.0000
#   Model Full Name_Chevrolet Suburban: -0.0000
#   Model Full Name_Chevrolet Tahoe: 0.0000
#   Model Full Name_Chevrolet Trailblazer: -0.0000
#   Model Full Name_Chevrolet Traverse: 0.0000
#   Model Full Name_Chevrolet Trax: -0.0000
#   Model Full Name_Chrysler 200: -0.0000
#   Model Full Name_Chrysler 300: 0.0000
#   Model Full Name_Chrysler Pacifica: -0.0000
#   Model Full Name_Dodge Challenger: 0.0000
#   Model Full Name_Dodge Charger: 0.0000
#   Model Full Name_Dodge Durango: -0.0000
#   Model Full Name_Fiat 500x: -0.0000
#   Model Full Name_Ford Bronco: 0.0000
#   Model Full Name_Ford Bronco-sport: 0.0000
#   Model Full Name_Ford Escape: -0.0000
#   Model Full Name_Ford Expedition: -0.0000
#   Model Full Name_Ford Explorer: -0.0000
#   Model Full Name_Ford F150: -0.0000
#   Model Full Name_Ford Focus: 0.0000
#   Model Full Name_Ford Fusion: -0.0000
#   Model Full Name_Ford Maverick: 0.0000
#   Model Full Name_Ford Mustang: 0.0000
#   Model Full Name_Ford Ranger: 0.0000
#   Model Full Name_Ford Taurus: 0.0000
#   Model Full Name_Genesis G70: -0.0000
#   Model Full Name_Genesis G80: -0.0000
#   Model Full Name_Genesis Gv80: 0.0000
#   Model Full Name_Gmc Acadia: -0.0000
#   Model Full Name_Gmc Canyon: 0.0000
#   Model Full Name_Gmc Hummer-ev: 0.0000
#   Model Full Name_Gmc Sierra-1500: 0.0000
#   Model Full Name_Gmc Terrain: 0.0000
#   Model Full Name_Gmc Yukon-xl: 0.0000
#   Model Full Name_Honda Accord: 0.0000
#   Model Full Name_Honda Insight: -0.0000
#   Model Full Name_Honda Odyssey: -0.0000
#   Model Full Name_Honda Passport: -0.0000
#   Model Full Name_Honda Pilot: -0.0000
#   Model Full Name_Honda Ridgeline: 0.0000
#   Model Full Name_Hyundai Azera: -0.0000
#   Model Full Name_Hyundai Elantra: -0.0000
#   Model Full Name_Hyundai Genesis: -0.0000
#   Model Full Name_Hyundai Ioniq-5: -0.0000
#   Model Full Name_Hyundai Ioniq-6: 0.0000
#   Model Full Name_Hyundai Palisade: 0.0000
#   Model Full Name_Hyundai Sonata: 0.0000
#   Model Full Name_Hyundai Tucson: -0.0000
#   Model Full Name_Hyundai Venue: -0.0000
#   Model Full Name_Infiniti Q50: -0.0000
#   Model Full Name_Infiniti Qx60: -0.0000
#   Model Full Name_Infiniti Qx80: -0.0000
#   Model Full Name_Jaguar E-pace: 0.0000
#   Model Full Name_Jaguar F-pace: 0.0000
#   Model Full Name_Jaguar I-pace: -0.0000
#   Model Full Name_Jeep Cherokee: -0.0000
#   Model Full Name_Jeep Compass: 0.0000
#   Model Full Name_Jeep Gladiator: 0.0000
#   Model Full Name_Jeep Grand-wagoneer: 0.0000
#   Model Full Name_Jeep Renegade: -0.0000
#   Model Full Name_Jeep Wagoneer: 0.0000
#   Model Full Name_Jeep Wrangler: 0.0000
#   Model Full Name_Kia Cadenza: -0.0000
#   Model Full Name_Kia Carnival: 0.0000
#   Model Full Name_Kia Ev6: -0.0000
#   Model Full Name_Kia K5: -0.0000
#   Model Full Name_Kia K900: -0.0000
#   Model Full Name_Kia Optima: -0.0000
#   Model Full Name_Kia Sedona: -0.0000
#   Model Full Name_Kia Seltos: -0.0000
#   Model Full Name_Kia Sorento: 0.0000
#   Model Full Name_Kia Sportage: 0.0000
#   Model Full Name_Kia Stinger: -0.0000
#   Model Full Name_Kia Telluride: -0.0000
#   Model Full Name_Land-rover Discovery: -0.0000
#   Model Full Name_Land-rover Range-rover-evoque: 0.0000
#   Model Full Name_Lexus Es: 0.0000
#   Model Full Name_Lexus Gx: 0.0000
#   Model Full Name_Lexus Nx: 0.0000
#   Model Full Name_Lexus Rx: 0.0000
#   Model Full Name_Lexus Ux: 0.0000
#   Model Full Name_Mazda Cx-5: 0.0000
#   Model Full Name_Mazda Cx-50: 0.0000
#   Model Full Name_Mazda Cx-9: -0.0000
#   Model Full Name_Mazda Mazda6: 0.0000
#   Model Full Name_Mazda Mx-5-miata: 0.0000
#   Model Full Name_Mercedes-benz A-class: 0.0000
#   Model Full Name_Mercedes-benz C-class: 0.0000
#   Model Full Name_Mercedes-benz E-class: 0.0000
#   Model Full Name_Mercedes-benz Glc: 0.0000
#   Model Full Name_Mercedes-benz Gle: 0.0000
#   Model Full Name_Mini Countryman: 0.0000
#   Model Full Name_Mitsubishi Outlander: 0.0000
#   Model Full Name_Nissan Altima: -0.0000
#   Model Full Name_Nissan Ariya: 0.0000
#   Model Full Name_Nissan Armada: 0.0000
#   Model Full Name_Nissan Frontier: 0.0000
#   Model Full Name_Nissan Kicks: -0.0000
#   Model Full Name_Nissan Leaf: 0.0000
#   Model Full Name_Nissan Maxima: 0.0000
#   Model Full Name_Nissan Murano: -0.0000
#   Model Full Name_Nissan Pathfinder: -0.0000
#   Model Full Name_Nissan Quest: -0.0000
#   Model Full Name_Nissan Rogue: 0.0000
#   Model Full Name_Nissan Titan: -0.0000
#   Model Full Name_Porsche Cayenne: 0.0000
#   Model Full Name_Porsche Macan: -0.0000
#   Model Full Name_Subaru Ascent: -0.0000
#   Model Full Name_Subaru Brz: 0.0000
#   Model Full Name_Subaru Crosstrek: -0.0000
#   Model Full Name_Subaru Forester: 0.0000
#   Model Full Name_Subaru Legacy: 0.0000
#   Model Full Name_Subaru Outback: 0.0000
#   Model Full Name_Subaru Solterra: 0.0000
#   Model Full Name_Tesla Model-3: -0.0000
#   Model Full Name_Tesla Model-s: 0.0000
#   Model Full Name_Tesla Model-x: 0.0000
#   Model Full Name_Tesla Model-y: -0.0000
#   Model Full Name_Toyota 4runner: 0.0000
#   Model Full Name_Toyota Avalon: 0.0000
#   Model Full Name_Toyota Camry: 0.0000
#   Model Full Name_Toyota Corolla: 0.0000
#   Model Full Name_Toyota Crown: 0.0000
#   Model Full Name_Toyota Highlander: 0.0000
#   Model Full Name_Toyota Land-cruiser: 0.0000
#   Model Full Name_Toyota Prius: 0.0000
#   Model Full Name_Toyota Rav4: 0.0000
#   Model Full Name_Toyota Sienna: 0.0000
#   Model Full Name_Toyota Tacoma: 0.0000
#   Model Full Name_Toyota Tundra: 0.0000
#   Model Full Name_Toyota Venza: 0.0000
#   Model Full Name_Volkswagen Arteon: -0.0000
#   Model Full Name_Volkswagen Atlas: 0.0000
#   Model Full Name_Volkswagen Golf-gti: -0.0000
#   Model Full Name_Volkswagen Id-4: -0.0000
#   Model Full Name_Volkswagen Jetta: 0.0000
#   Model Full Name_Volkswagen Passat: -0.0000
#   Model Full Name_Volkswagen Tiguan: 0.0000
#   Model Full Name_Volvo Xc40: -0.0000
#   Model Full Name_Volvo Xc60: 0.0000
#   Model Full Name_Volvo Xc90: -0.0000
#
# Intercept: 15130.8722

# %%
results_df = pd.DataFrame(results_list).round({"R^2": 2, "RMSE": 2})
print("\nResults Summary:")
results_df
# Out:
# Results Summary:
#                             Division Title         Model Type  Best Alpha  \
# 0                  Functional Unaggregated  Linear Regression         NaN
# 1                  Functional Unaggregated              Lasso        10.0
# 2                  Functional Unaggregated              Ridge         1.0
# 3                    Functional Aggregated  Linear Regression         NaN
# 4                    Functional Aggregated              Lasso      1000.0
# 5                    Functional Aggregated              Ridge       100.0
# 6   Functional & Experiential Unaggregated  Linear Regression         NaN
# 7   Functional & Experiential Unaggregated              Lasso         0.1
# 8   Functional & Experiential Unaggregated              Ridge         0.1
# 9     Functional & Experiential Aggregated  Linear Regression         NaN
# 10    Functional & Experiential Aggregated              Lasso      1000.0
# 11    Functional & Experiential Aggregated              Ridge       100.0
#
#      R^2     RMSE
# 0   0.76  4318.30
# 1   0.76  4317.39
# 2   0.76  4318.28
# 3   0.67  5500.94
# 4   0.70  5205.96
# 5   0.69  5270.69
# 6   0.91  2610.30
# 7   0.91  2611.69
# 8   0.91  2612.26
# 9   0.71  5147.95
# 10  0.70  5205.96
# 11  0.70  5260.33

# %%
car_data_encoded
# Out:
#      Horsepower (hp)  Curb Weight (lbs)  Combined MPG  \
# 0         262.060606        3849.206061     21.715152
# 1         224.000000        3544.636364     27.181818
# 2         280.000000        3761.000000     27.000000
# 3         280.000000        3761.000000     24.000000
# 4         202.031250        3626.937500     28.135417
# ..               ...                ...           ...
# 162       211.890625        3281.984375     25.296875
# 163       192.000000        3704.000000     22.000000
# 164       187.000000        3574.000000     27.000000
# 165       275.500000        4043.000000     22.000000
# 166       241.666667        4547.444444     19.222222
#
#      Fuel Capacity (gallons)        Age  Drivetrain_4WD  Drivetrain_AWD  \
# 0                  17.015758   9.927273             0.0        0.660606
# 1                  16.845455   7.363636             0.0        0.000000
# 2                  15.300000   7.000000             0.0        0.000000
# 3                  16.900000   6.000000             0.0        1.000000
# 4                  16.388542  11.010417             0.0        0.000000
# ..                       ...        ...             ...             ...
# 162                18.500000  11.640625             0.0        0.000000
# 163                16.050000  10.000000             0.0        0.500000
# 164                14.200000   5.000000             0.0        0.000000
# 165                18.650000  10.000000             0.0        0.500000
# 166                20.077778  11.333333             0.0        1.000000
#
#      Drivetrain_FWD  Drivetrain_RWD  Topic_0_Weighted  ...  \
# 0          0.339394             0.0          0.011670  ...
# 1          1.000000             0.0          0.018425  ...
# 2          0.000000             1.0          0.012348  ...
# 3          0.000000             0.0          0.018979  ...
# 4          1.000000             0.0          0.015253  ...
# ..              ...             ...               ...  ...
# 162        1.000000             0.0          0.010684  ...
# 163        0.500000             0.0          0.014438  ...
# 164        1.000000             0.0          0.020192  ...
# 165        0.000000             0.0          0.010337  ...
# 166        0.000000             0.0          0.012786  ...
#
#      Model Full Name_Volkswagen Arteon  Model Full Name_Volkswagen Atlas  \
# 0                                False                             False
# 1                                False                             False
# 2                                False                             False
# 3                                False                             False
# 4                                False                             False
# ..                                 ...                               ...
# 162                              False                             False
# 163                              False                             False
# 164                              False                             False
# 165                              False                             False
# 166                              False                             False
#
#      Model Full Name_Volkswagen Golf-gti  Model Full Name_Volkswagen Id-4  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
# ..                                   ...                              ...
# 162                                False                            False
# 163                                False                            False
# 164                                False                            False
# 165                                False                            False
# 166                                False                            False
#
#      Model Full Name_Volkswagen Jetta  Model Full Name_Volkswagen Passat  \
# 0                               False                              False
# 1                               False                              False
# 2                               False                              False
# 3                               False                              False
# 4                               False                              False
# ..                                ...                                ...
# 162                             False                               True
# 163                             False                              False
# 164                             False                              False
# 165                             False                              False
# 166                             False                              False
#
#      Model Full Name_Volkswagen Tiguan  Model Full Name_Volvo Xc40  \
# 0                                False                       False
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
# ..                                 ...                         ...
# 162                              False                       False
# 163                               True                       False
# 164                              False                        True
# 165                              False                       False
# 166                              False                       False
#
#      Model Full Name_Volvo Xc60  Model Full Name_Volvo Xc90
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
# ..                          ...                         ...
# 162                       False                       False
# 163                       False                       False
# 164                       False                       False
# 165                        True                       False
# 166                       False                        True
#
# [167 rows x 185 columns]
